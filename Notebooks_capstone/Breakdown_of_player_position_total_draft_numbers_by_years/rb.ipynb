# %%
import pandas as pd

# %%
a = pd.read_csv('2013_fantasyfootball_data.csv')
b = pd.read_csv('2014_fantasyfootball_data.csv')
c = pd.read_csv('2015_fantasyfootball_data.csv')
d = pd.read_csv('2016_fantasyfootball_data.csv')
e = pd.read_csv('2017_fantasyfootball_data.csv')
f = pd.read_csv('2018_fantasyfootball_data.csv')
g = pd.read_csv('2019_fantasyfootball_data.csv')

# %%
# Out:
#      pick        player_name  round  percent_selected position team  \
# 0       1    Adrian Peterson      1                73       RB  MIN
# 1       2        Doug Martin      1                73       RB  TBB
# 2       3       Arian Foster      1                74       RB  HOU
# 3       4     Calvin Johnson      1                74       WR  DET
# 4       5     Jamaal Charles      1                76       RB  KCC
# ..    ...                ...    ...               ...      ...  ...
# 319   320  Leonard Hankerson     27                 9       WR  WAS
# 320   321      Brandon Lloyd     27                 7       WR   FA
# 321   322     Scott Chandler     27                 7       TE  BUF
# 322   323      Jarius Wright     27                 5       WR  MIN
# 323   324        Davone Bess     27                 6       WR  CLE
#
#      pick_number_by_position  fantasy_points_rank_by_position  games_played  \
# ...

# %%
rb_13 = a.loc[a['position'] == 'RB']
rb_14 = b.loc[b['position'] == 'RB']
rb_15 = c.loc[c['position'] == 'RB']
rb_16 = d.loc[d['position'] == 'RB']
rb_17 = e.loc[e['position'] == 'RB']
rb_18 = f.loc[f['position'] == 'RB']
rb_19 = g.loc[g['position'] == 'RB']

# %%
rb_13.head(15)
# Out:
#     pick         player_name  round  percent_selected position team  \
# 0      1     Adrian Peterson      1                73       RB  MIN
# 1      2         Doug Martin      1                73       RB  TBB
# 2      3        Arian Foster      1                74       RB  HOU
# 4      5      Jamaal Charles      1                76       RB  KCC
# 5      6            Ray Rice      1                74       RB  BAL
# 6      7        LeSean McCoy      1                76       RB  PHI
# 7      8    Trent Richardson      1                75       RB  IND
# 8      9      Marshawn Lynch      1                75       RB  SEA
# 9     10        C.J. Spiller      1                74       RB  BUF
# 10    11          Matt Forte      1                76       RB  CHI
# 17    18       Chris Johnson      2                77       RB  TEN
# 19    20      Steven Jackson      2                78       RB  ATL
# 20    21       Alfred Morris      2                75       RB  WAS
# ...

# %%
# Out:
# 119.54761904761907

# %%
rb_13['round'].value_counts()
# Out:
# 1     10
# 2      5
# 3      5
# 7      5
# 15     5
# 17     4
# 11     4
# 12     4
# 26     4
# 18     4
# 19     4
# 16     3
# 5      3
# 13     3
# 22     3
# 4      3
# 8      3
# 9      2
# 14     2
# 20     2
# 21     2
# 25     2
# 10     1
# 6      1
# 23     1
# 24     1
# 27     1
# Name: round, dtype: int64

# %%
rb_round_13 = rb_13['round'].value_counts().to_frame()
rb_round_13.reset_index(level=0, inplace=True)
rb_round_13 = rb_round_13.sort_values(by = 'index').head(15)
rb_round_13
# Out:
#     index  round
# 0       1     10
# 1       2      5
# 2       3      5
# 15      4      3
# 12      5      3
# 23      6      1
# 3       7      5
# 16      8      3
# 17      9      2
# 22     10      1
# 6      11      4
# 7      12      4
# 13     13      3
# 18     14      2
# 4      15      5

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-3be84ff1b612> in <module>
# ----> 1 if rb_13['round'] == 1:
#       2     rb13['fpts'].sum()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
rb_round_14 = rb_14['round'].value_counts().to_frame()
rb_round_14.reset_index(level=0, inplace=True)
rb_round_14 = rb_round_14.sort_values(by = 'index').head(15)
rb_round_14
# Out:
#     index  round
# 2       1      5
# 1       2      6
# 6       3      4
# 7       4      4
# 16      5      3
# 8       6      4
# 25      7      1
# 9       8      4
# 0       9      7
# 24     10      1
# 4      11      5
# 10     13      4
# 3      14      5
# 11     15      4
# 18     16      2

# %%
rb_round_15 = rb_15['round'].value_counts().to_frame()
rb_round_15.reset_index(level=0, inplace=True)
rb_round_15 = rb_round_15.sort_values(by = 'index').head(15)
rb_round_15
# Out:
#     index  round
# 0       1      6
# 4       2      5
# 5       3      5
# 1       4      6
# 9       5      4
# 14      6      3
# 6       7      5
# 21      8      2
# 2       9      6
# 16     10      3
# 17     12      3
# 8      13      4
# 18     14      3
# 19     15      3
# 20     16      3

# %%
rb_round_16 = rb_16['round'].value_counts().to_frame()
rb_round_16.reset_index(level=0, inplace=True)
rb_round_16 = rb_round_16.sort_values(by = 'index').head(15)
rb_round_16
# Out:
#     index  round
# 0       1      6
# 6       2      4
# 12      3      3
# 7       4      4
# 1       5      5
# 2       6      5
# 3       7      5
# 13      8      3
# 14      9      3
# 15     10      3
# 9      11      4
# 11     12      3
# 10     13      4
# 25     14      2
# 18     15      3

# %%
rb_round_17 = rb_17['round'].value_counts().to_frame()
rb_round_17.reset_index(level=0, inplace=True)
rb_round_17 = rb_round_17.sort_values(by = 'index').head(15)
rb_round_17
# Out:
#     index  round
# 0       1      6
# 1       2      5
# 2       3      5
# 15      4      2
# 5       5      4
# 6       6      4
# 8       7      4
# 13      8      3
# 14      9      2
# 3      10      5
# 17     11      2
# 9      12      4
# 24     13      1
# 18     14      2
# 7      15      4

# %%
rb_round_18 = rb_18['round'].value_counts().to_frame()
rb_round_18.reset_index(level=0, inplace=True)
rb_round_18 = rb_round_18.sort_values(by = 'index').head(15)
rb_round_18
# Out:
#     index  round
# 0       1      9
# 9       2      3
# 19      3      2
# 2       4      5
# 3       5      5
# 10      6      3
# 6       7      4
# 22      8      1
# 7       9      4
# 15     10      2
# 11     11      3
# 5      12      4
# 1      13      6
# 14     14      2
# 20     15      1

# %%
rb_round_19 = rb_19['round'].value_counts().to_frame()
rb_round_19.reset_index(level=0, inplace=True)
rb_round_19 = rb_round_19.sort_values(by = 'index').head(15)
rb_round_19
# Out:
#     index  round
# 0       1      7
# 1       2      7
# 2       3      5
# 8       4      4
# 21      5      2
# 20      6      2
# 19      7      2
# 12      8      3
# 26      9      1
# 4      10      5
# 5      11      5
# 6      12      5
# 7      13      4
# 25     14      2
# 16     15      2
