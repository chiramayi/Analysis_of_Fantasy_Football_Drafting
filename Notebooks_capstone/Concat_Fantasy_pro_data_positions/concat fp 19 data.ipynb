# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
rb_19 = pd.read_csv('FantasyPros_Fantasy_Football_Statistics_RB_19.csv')
wr_19 = pd.read_csv('FantasyPros_Fantasy_Football_Statistics_WR_19.csv')
qb_19 = pd.read_csv('FantasyPros_Fantasy_Football_Statistics_QB_19.csv')
te_19 = pd.read_csv('FantasyPros_Fantasy_Football_Statistics_TE_19.csv')
k_19 = pd.read_csv('FantasyPros_Fantasy_Football_Statistics_K_19.csv')
def_19 = pd.read_csv('FantasyPros_Fantasy_Football_Statistics_DST_19.csv')

# %%
concat_19 = pd.concat([rb_19, wr_19, te_19, k_19, qb_19, def_19])

# %%
concat_19.shape
# Out:
# (1246, 38)

# %%
concat_19.head()
# Out:
#    Rank                     Player    ATT    YDS  Y/A    LG  20+    TD    REC  \
# 0   1.0  Christian McCaffrey (CAR)  287.0  1,387  4.8  84.0  6.0  15.0  116.0
# 1   2.0           Aaron Jones (GB)  236.0  1,084  4.6  56.0  5.0  16.0   49.0
# 2   3.0        Derrick Henry (TEN)  303.0  1,540  5.1  74.0  9.0  16.0   18.0
# 3   4.0      Ezekiel Elliott (DAL)  301.0  1,357  4.5  33.0  4.0  12.0   54.0
# 4   5.0          Dalvin Cook (MIN)  250.0  1,135  4.5  75.0  7.0  13.0   53.0
#
#      TGT  ... CMP  INT  SACKS  ATT.1  SACK  FR  FF DEF TD  SFTY  SPC TD
# 0  142.0  ... NaN  NaN    NaN    NaN   NaN NaN NaN    NaN   NaN     NaN
# 1   68.0  ... NaN  NaN    NaN    NaN   NaN NaN NaN    NaN   NaN     NaN
# 2   24.0  ... NaN  NaN    NaN    NaN   NaN NaN NaN    NaN   NaN     NaN
# 3   71.0  ... NaN  NaN    NaN    NaN   NaN NaN NaN    NaN   NaN     NaN
# 4   63.0  ... NaN  NaN    NaN    NaN   NaN NaN NaN    NaN   NaN     NaN
#
# [5 rows x 38 columns]

# %%
concat_19.columns
# Out:
# Index(['Rank', 'Player', 'ATT', 'YDS', 'Y/A', 'LG', '20+', 'TD', 'REC', 'TGT',
#        'YDS.1', 'Y/R', 'TD.1', 'FL', 'G', 'FPTS', 'FPTS/G', 'OWN', 'FG', 'FGA',
#        'PCT', '1-19', '20-29', '30-39', '40-49', '50+', 'XPT', 'XPA', 'CMP',
#        'INT', 'SACKS', 'ATT.1', 'SACK', 'FR', 'FF', 'DEF TD', 'SFTY',
#        'SPC TD'],
#       dtype='object')

# %%
concat_19['FantasyPointsRank'] = concat_19['FPTS'].rank(ascending = False)
concat_19 = concat_19.sort_values(by = 'FantasyPointsRank')

# %%
concat_19.shape
# Out:
# (1246, 39)

# %%
concat_19.head(10)
# Out:
#    Rank                     Player    ATT    YDS  Y/A    LG   20+    TD  \
# 0   1.0        Lamar Jackson (BAL)  401.0  3,127  7.8   NaN   NaN  36.0
# 0   1.0  Christian McCaffrey (CAR)  287.0  1,387  4.8  84.0   6.0  15.0
# 1   2.0         Dak Prescott (DAL)  596.0  4,902  8.2   NaN   NaN  30.0
# 2   3.0        Jameis Winston (NO)  626.0  5,109  8.2   NaN   NaN  33.0
# 3   4.0       Russell Wilson (SEA)  516.0  4,110  8.0   NaN   NaN  31.0
# 4   5.0       Deshaun Watson (HOU)  495.0  3,852  7.8   NaN   NaN  26.0
# 0   1.0        Michael Thomas (NO)    1.0  1,725  NaN  49.0  17.0   9.0
# 5   6.0           Josh Allen (BUF)  461.0  3,089  6.7   NaN   NaN  20.0
# 6   7.0         Kyler Murray (ARI)  542.0  3,722  6.9   NaN   NaN  20.0
# 7   8.0    Patrick Mahomes II (KC)  484.0  4,031  8.3   NaN   NaN  26.0
#
#      REC    TGT  ...   INT  SACKS  ATT.1  SACK  FR  FF  DEF TD SFTY  SPC TD  \
# 0    NaN    NaN  ...   6.0   23.0  176.0   NaN NaN NaN     NaN  NaN     NaN
# ...

# %%
concat_19.to_csv('fp_data_uncleaned.csv', index = False)
