# %%
import pandas as pd

import gc # To collect garbage values generated during running

import matplotlib.pyplot as plt

import numpy as np

import seaborn as sns

# %%
d = pd.read_csv('2017_eda_ranked_with_rounds.csv')

# %%
rb = d.loc[d['Position'] == 'RB']
wr = d.loc[d['Position'] == 'WR']

# %%
wr['performance_fp_wr'] = wr['FantasyPointsRank'].rank(ascending = True)
rb['performance_fp_rb'] = rb['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-5-ea88c15edb18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wr['performance_fp_wr'] = wr['FantasyPointsRank'].rank(ascending = True)
# <ipython-input-5-ea88c15edb18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rb['performance_fp_rb'] = rb['FantasyPointsRank'].rank(ascending = True)

# %%
te = d.loc[d['Position'] == 'TE']
te['performance_fp_te'] = te['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-6-c576e4e6ce8f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['performance_fp_te'] = te['FantasyPointsRank'].rank(ascending = True)

# %%
qb = d.loc[d['Position'] == 'QB']
qb['performance_fp_qb'] = qb['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-7-4882867569a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qb['performance_fp_qb'] = qb['FantasyPointsRank'].rank(ascending = True)

# %%
k = d.loc[d['Position'] == 'PK']
k['performance_fp_qb'] = k['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-8-d0b0a0dfd751>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['performance_fp_qb'] = k['FantasyPointsRank'].rank(ascending = True)

# %%
Def = d.loc[d['Position'] == 'Def']
Def['performance_fp_qb'] = Def['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-9-1cd933a4c506>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Def['performance_fp_qb'] = Def['FantasyPointsRank'].rank(ascending = True)

# %%
rb_50 = rb.head(50)
after_rb = rb_50[(rb_50['FantasyPointsRank'] <= 70)]
after_rb.head(50)
# Out:
#      Rank_x   Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 0         1       Bell    Le'Veon         Le'Veon Bell      1         1
# 5         6    Elliott    Ezekiel      Ezekiel Elliott      1         1
# 6         7      McCoy     LeSean         LeSean McCoy      1         1
# 7         8     Gordon     Melvin        Melvin Gordon      1         1
# 8         9    Freeman    Devonta      Devonta Freeman      1         1
# 10       11  Fournette    Leonard    Leonard Fournette      1         1
# 13       14     Gurley       Todd          Todd Gurley      2         1
# 18       19     Howard     Jordan        Jordan Howard      2         1
# 21       22  McCaffrey  Christian  Christian McCaffrey      2         1
# 25       26     Miller      Lamar         Lamar Miller      3         1
# 35       36       Hyde     Carlos          Carlos Hyde      3         1
# 43       44     Ingram       Mark          Mark Ingram      4         1
# 44       45       Hunt     Kareem          Kareem Hunt      4         1
# 91      111     Kamara      Alvin         Alvin Kamara      8         1
# 103     125    Johnson       Duke         Duke Johnson      9         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 0         469          76       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 5         448          71       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 6         442          76       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN
# 7         571          72       RB  LAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 8         532          77       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 10        541          98       RB  JAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 13        447          78       RB  LAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 18        449          72       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 21        542          98       RB  CAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 25        450          74       RB  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 35        530          75       RB  SFO  ...    NaN  NaN NaN  NaN NaN  NaN
# 43        461          80       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 44        546          97       RB  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 91        600          78       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 103       449          69       RB  CLE  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 0      NaN    NaN                4.0                2.0
# 5      NaN    NaN               44.0               10.0
# 6      NaN    NaN               23.0                7.0
# 7      NaN    NaN               18.0                5.0
# 8      NaN    NaN               53.0               13.0
# 10     NaN    NaN               27.0                8.0
# 13     NaN    NaN                1.0                1.0
# 18     NaN    NaN               48.0               12.0
# 21     NaN    NaN               47.0               11.0
# 25     NaN    NaN               59.0               16.0
# 35     NaN    NaN               36.0                9.0
# 43     NaN    NaN               21.0                6.0
# 44     NaN    NaN               12.0                4.0
# 91     NaN    NaN                9.0                3.0
# 103    NaN    NaN               56.0               15.0
#
# [15 rows x 45 columns]

# %%
wr_50 = wr.head(50)
after_wr = wr_50[(wr_50['FantasyPointsRank'] <= 70)]
after_wr.head(50)
# Out:
#      Rank_x    Player_x Unnamed: 2       Player_Name  Round  Min Pick  \
# 1         2       Brown    Antonio     Antonio Brown      1         1
# 2         3       Jones      Julio       Julio Jones      1         1
# 3         4       Evans       Mike        Mike Evans      1         1
# 4         5       Green       A.J.        A.J. Green      1         1
# 12       13      Thomas    Michael    Michael Thomas      2         1
# 20       21       Cooks    Brandin     Brandin Cooks      2         1
# 22       23     Hopkins    DeAndre   DeAndre Hopkins      2         1
# 23       24     Baldwin       Doug      Doug Baldwin      2         1
# 28       29      Thomas  Demaryius  Demaryius Thomas      3         1
# 29       30       Allen     Keenan      Keenan Allen      3         1
# 32       33     Jeffery     Alshon    Alshon Jeffery      3         1
# 34       35       Adams    Davante     Davante Adams      3         1
# 36       37        Hill     Tyreek       Tyreek Hill      4         1
# 38       39      Landry     Jarvis     Jarvis Landry      4         1
# 40       41        Tate     Golden       Golden Tate      4         1
# 47       48       Diggs     Stefon      Stefon Diggs      4         1
# 48       49  Fitzgerald      Larry  Larry Fitzgerald      5         1
# 95      115     Thielen       Adam      Adam Thielen      8         2
# 118     144       Jones     Marvin      Marvin Jones     10         4
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 1         433          77       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 2         438          77       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 3         425          72       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN
# 4         395          72       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 12        392          78       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 20        389          79       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 22        364          74       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 23        528          74       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN
# 28        502          75       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 29        532          75       WR  LAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 32        514          80       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 34        416          75       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN
# 36        468          80       WR  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 38        455          75       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 40        390          76       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
# 47        519          81       WR  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 48        415          76       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 95        563          75       WR  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 118       470          68       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_wr
# 1      NaN    NaN               17.0                2.0
# 2      NaN    NaN               30.0                4.0
# 3      NaN    NaN               64.0               17.0
# 4      NaN    NaN               45.0               11.0
# 12     NaN    NaN               32.0                6.0
# 20     NaN    NaN               46.0               12.0
# 22     NaN    NaN               14.0                1.0
# 23     NaN    NaN               49.0               13.0
# 28     NaN    NaN               68.0               20.0
# 29     NaN    NaN               24.0                3.0
# 32     NaN    NaN               65.0               18.0
# 34     NaN    NaN               51.0               14.0
# 36     NaN    NaN               39.0                8.0
# 38     NaN    NaN               37.0                7.0
# 40     NaN    NaN               57.0               15.0
# 47     NaN    NaN               66.0               19.0
# 48     NaN    NaN               31.0                5.0
# 95     NaN    NaN               41.0               10.0
# 118    NaN    NaN               40.0                9.0
#
# [19 rows x 45 columns]

# %%
te_50 = te.head(50)
after_te = te_50[(te_50['FantasyPointsRank'] <= 70)]
after_te.head(30)
# Out:
#     Rank_x    Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 14      15  Gronkowski        Rob  Rob Gronkowski      2         1       353
# 27      28       Kelce     Travis    Travis Kelce      3         1       535
# 74      85        Ertz       Zach       Zach Ertz      7         3       450
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 14          78       TE  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 27          79       TE  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 74          79       TE  PHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_te
# 14               42.0                1.0
# 27               43.0                2.0
# 74               67.0                3.0
#
# [3 rows x 45 columns]

# %%
qb_50 = qb.head(50)
after_qb = qb_50[(qb_50['FantasyPointsRank'] <= 70)]
after_qb.head(30)
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 24       25           Brady        Tom           Tom Brady      3         1
# 33       34           Brees       Drew          Drew Brees      3         1
# 42       43          Keenum       Case         Case Keenum      4         1
# 46       47            Ryan       Matt           Matt Ryan      4         1
# 51       52          Wilson    Russell      Russell Wilson      5         1
# 58       62            Carr      Derek          Derek Carr      5         1
# 60       67         Winston     Jameis      Jameis Winston      6         1
# 61       69          Newton        Cam          Cam Newton      6         1
# 68       76         Mariota     Marcus      Marcus Mariota      6         1
# 72       82         Cousins       Kirk        Kirk Cousins      7         1
# 79       92  Roethlisberger        Ben  Ben Roethlisberger      7         1
# 81       95        Prescott        Dak        Dak Prescott      7         1
# 90      109        Stafford    Matthew    Matthew Stafford      8         1
# 94      114          Rivers     Philip       Philip Rivers      8         1
# 123     149          Dalton       Andy         Andy Dalton     11         1
# 126     153         Manning        Eli         Eli Manning     11         1
# 146     175           Kizer    DeShone       DeShone Kizer     13         1
# 151     183          Taylor      Tyrod        Tyrod Taylor     13         1
# 173     210         Bortles      Blake       Blake Bortles     15         2
# 186     229           Smith       Alex          Alex Smith     16         1
# 187     230          Flacco        Joe          Joe Flacco     16         1
# 210     254            Goff      Jared          Jared Goff     18         2
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 24        491          76       QB  NEP  ...    NaN  NaN NaN  NaN  385.0
# 33        495          76       QB  NOS  ...    NaN  NaN NaN  NaN  386.0
# 42       1243           5       QB  MIN  ...    NaN  NaN NaN  NaN  325.0
# 46        472          77       QB  ATL  ...    NaN  NaN NaN  NaN  342.0
# 51        478          73       QB  SEA  ...    NaN  NaN NaN  NaN  339.0
# 58        509          73       QB  OAK  ...    NaN  NaN NaN  NaN  323.0
# 60        473          74       QB  TBB  ...    NaN  NaN NaN  NaN  282.0
# 61        479          77       QB  CAR  ...    NaN  NaN NaN  NaN  291.0
# 68        503          77       QB  TEN  ...    NaN  NaN NaN  NaN  281.0
# 72        498          74       QB  WAS  ...    NaN  NaN NaN  NaN  347.0
# 79        481          79       QB  PIT  ...    NaN  NaN NaN  NaN  360.0
# 81        533          73       QB  DAL  ...    NaN  NaN NaN  NaN  308.0
# 90        616          74       QB  DET  ...    NaN  NaN NaN  NaN  371.0
# 94        487          74       QB  LAC  ...    NaN  NaN NaN  NaN  360.0
# 123       620          71       QB  CIN  ...    NaN  NaN NaN  NaN  297.0
# 126       619          71       QB  NYG  ...    NaN  NaN NaN  NaN  352.0
# 146       666          39       QB  CLE  ...    NaN  NaN NaN  NaN  255.0
# 151       625          63       QB  BUF  ...    NaN  NaN NaN  NaN  263.0
# 173       654          47       QB  JAC  ...    NaN  NaN NaN  NaN  315.0
# 186       633          51       QB  WAS  ...    NaN  NaN NaN  NaN  341.0
# 187       635          51       QB  BAL  ...    NaN  NaN NaN  NaN  352.0
# 210       667          39       QB  LAR  ...    NaN  NaN NaN  NaN  296.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 24    8.0   35.0   25.0                5.0                3.0
# 33    8.0   20.0   33.0               13.0                8.0
# 42    7.0   22.0   40.0               22.0               13.0
# 46   12.0   24.0   32.0               25.0               14.0
# 51   11.0   43.0   95.0                2.0                1.0
# 58   13.0   20.0   23.0               33.0               18.0
# 60   11.0   33.0   33.0               38.0               19.0
# 61   16.0   35.0  139.0                3.0                2.0
# 68   15.0   27.0   60.0               29.0               17.0
# 72   13.0   41.0   49.0                8.0                5.0
# 79   14.0   21.0   28.0               16.0               10.0
# 81   13.0   32.0   57.0               15.0                9.0
# 90   10.0   47.0   29.0               10.0                6.0
# 94   10.0   18.0   18.0               11.0                7.0
# 123  12.0   39.0   38.0               28.0               16.0
# 126  13.0   31.0   12.0               50.0               20.0
# 146  22.0   38.0   77.0               58.0               22.0
# 151   4.0   46.0   84.0               26.0               15.0
# 173  13.0   24.0   57.0               20.0               12.0
# 186   5.0   35.0   60.0                6.0                4.0
# 187  13.0   27.0   25.0               52.0               21.0
# 210   7.0   25.0   28.0               19.0               11.0
#
# [22 rows x 45 columns]

# %%
rb1 = rb[(rb['FantasyPointsRank'] <= 100)]
wr1 = wr[(wr['FantasyPointsRank'] <= 100)]
te1 = te[(te['FantasyPointsRank'] <= 100)]
qb1 = qb[(qb['FantasyPointsRank'] <= 100)]
rb1
# Out:
#      Rank_x   Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 0         1       Bell    Le'Veon         Le'Veon Bell      1         1
# 5         6    Elliott    Ezekiel      Ezekiel Elliott      1         1
# 6         7      McCoy     LeSean         LeSean McCoy      1         1
# 7         8     Gordon     Melvin        Melvin Gordon      1         1
# 8         9    Freeman    Devonta      Devonta Freeman      1         1
# 10       11  Fournette    Leonard    Leonard Fournette      1         1
# 13       14     Gurley       Todd          Todd Gurley      2         1
# 16       17     Murray    DeMarco       DeMarco Murray      2         1
# 18       19     Howard     Jordan        Jordan Howard      2         1
# 21       22  McCaffrey  Christian  Christian McCaffrey      2         1
# 25       26     Miller      Lamar         Lamar Miller      3         1
# 30       31      Lynch   Marshawn       Marshawn Lynch      3         1
# 35       36       Hyde     Carlos          Carlos Hyde      3         1
# 43       44     Ingram       Mark          Mark Ingram      4         1
# 44       45       Hunt     Kareem          Kareem Hunt      4         1
# 49       50   Anderson       C.J.        C.J. Anderson      5         1
# 55       58    Coleman      Tevin        Tevin Coleman      5         2
# 83       99       Gore      Frank           Frank Gore      7         1
# 91      111     Kamara      Alvin         Alvin Kamara      8         1
# 103     125    Johnson       Duke         Duke Johnson      9         1
# 156     189     Murray   Latavius      Latavius Murray     14         1
# 180     220   McKinnon     Jerick      Jerick McKinnon     16         1
# 201     245      Lewis       Dion           Dion Lewis     17         1
# 280     324      Allen   Javorius       Javorius Allen     24         3
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 0         469          76       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 5         448          71       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 6         442          76       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN
# 7         571          72       RB  LAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 8         532          77       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 10        541          98       RB  JAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 13        447          78       RB  LAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 16        436          74       RB  TEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 18        449          72       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 21        542          98       RB  CAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 25        450          74       RB  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 30        583          85       RB  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 35        530          75       RB  SFO  ...    NaN  NaN NaN  NaN NaN  NaN
# 43        461          80       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 44        546          97       RB  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 49        462          76       RB  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 55        531          79       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 83        497          75       RB  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 91        600          78       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 103       449          69       RB  CLE  ...    NaN  NaN NaN  NaN NaN  NaN
# 156       503          66       RB  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 180       612          16       RB  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 201       571          49       RB  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 280       896           5       RB  BAL  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 0      NaN    NaN                4.0                2.0
# 5      NaN    NaN               44.0               10.0
# 6      NaN    NaN               23.0                7.0
# 7      NaN    NaN               18.0                5.0
# 8      NaN    NaN               53.0               13.0
# 10     NaN    NaN               27.0                8.0
# 13     NaN    NaN                1.0                1.0
# 16     NaN    NaN               85.5               22.0
# 18     NaN    NaN               48.0               12.0
# 21     NaN    NaN               47.0               11.0
# 25     NaN    NaN               59.0               16.0
# 30     NaN    NaN               83.0               20.0
# 35     NaN    NaN               36.0                9.0
# 43     NaN    NaN               21.0                6.0
# 44     NaN    NaN               12.0                4.0
# 49     NaN    NaN               74.0               17.0
# 55     NaN    NaN               82.0               19.0
# 83     NaN    NaN               78.0               18.0
# 91     NaN    NaN                9.0                3.0
# 103    NaN    NaN               56.0               15.0
# 156    NaN    NaN               88.0               23.0
# 180    NaN    NaN               84.0               21.0
# 201    NaN    NaN               55.0               14.0
# 280    NaN    NaN               94.0               24.0
#
# [24 rows x 45 columns]

# %%
wr1
# Out:
#      Rank_x        Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 1         2           Brown    Antonio        Antonio Brown      1         1
# 2         3           Jones      Julio          Julio Jones      1         1
# 3         4           Evans       Mike           Mike Evans      1         1
# 4         5           Green       A.J.           A.J. Green      1         1
# 12       13          Thomas    Michael       Michael Thomas      2         1
# 15       16          Bryant        Dez           Dez Bryant      2         1
# 19       20          Hilton       T.Y.          T.Y. Hilton      2         1
# 20       21           Cooks    Brandin        Brandin Cooks      2         1
# 22       23         Hopkins    DeAndre      DeAndre Hopkins      2         1
# 23       24         Baldwin       Doug         Doug Baldwin      2         1
# 28       29          Thomas  Demaryius     Demaryius Thomas      3         1
# 29       30           Allen     Keenan         Keenan Allen      3         1
# 32       33         Jeffery     Alshon       Alshon Jeffery      3         1
# 34       35           Adams    Davante        Davante Adams      3         1
# 36       37            Hill     Tyreek          Tyreek Hill      4         1
# 37       38        Crabtree    Michael     Michael Crabtree      4         1
# 38       39          Landry     Jarvis        Jarvis Landry      4         1
# 40       41            Tate     Golden          Golden Tate      4         1
# 47       48           Diggs     Stefon         Stefon Diggs      4         1
# 48       49      Fitzgerald      Larry     Larry Fitzgerald      5         1
# 95      115         Thielen       Adam         Adam Thielen      8         2
# 118     144           Jones     Marvin         Marvin Jones     10         4
# 120     146  Smith-Schuster       JuJu  JuJu Smith-Schuster     11         1
# 137     165            Kupp     Cooper          Cooper Kupp     12         4
# 196     240            Sanu    Mohamed         Mohamed Sanu     17         1
# 208     252        Anderson      Robby       Robby Anderson     18         1
# 211     255          Stills      Kenny         Kenny Stills     18         6
# 218     262        Funchess      Devin       Devin Funchess     19         2
# 219     263         Agholor     Nelson       Nelson Agholor     19         2
# 261     305         Goodwin   Marquise     Marquise Goodwin     22         4
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 1         433          77       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 2         438          77       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 3         425          72       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN
# 4         395          72       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 12        392          78       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 15        485          73       WR  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 19        386          74       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 20        389          79       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 22        364          74       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 23        528          74       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN
# 28        502          75       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 29        532          75       WR  LAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 32        514          80       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 34        416          75       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN
# 36        468          80       WR  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 37        496          75       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 38        455          75       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 40        390          76       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
# 47        519          81       WR  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 48        415          76       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 95        563          75       WR  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 118       470          68       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
# 120       724          47       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 137       571          68       WR  LAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 196       565          58       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 208       645          50       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
# 211       655          44       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 218       686          45       WR  CAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 219       696          24       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 261      1074          16       WR  SFO  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_wr
# 1      NaN    NaN               17.0                2.0
# 2      NaN    NaN               30.0                4.0
# 3      NaN    NaN               64.0               17.0
# 4      NaN    NaN               45.0               11.0
# 12     NaN    NaN               32.0                6.0
# 15     NaN    NaN               85.5               24.0
# 19     NaN    NaN               90.0               25.0
# 20     NaN    NaN               46.0               12.0
# 22     NaN    NaN               14.0                1.0
# 23     NaN    NaN               49.0               13.0
# 28     NaN    NaN               68.0               20.0
# 29     NaN    NaN               24.0                3.0
# 32     NaN    NaN               65.0               18.0
# 34     NaN    NaN               51.0               14.0
# 36     NaN    NaN               39.0                8.0
# 37     NaN    NaN               95.0               28.0
# 38     NaN    NaN               37.0                7.0
# 40     NaN    NaN               57.0               15.0
# 47     NaN    NaN               66.0               19.0
# 48     NaN    NaN               31.0                5.0
# 95     NaN    NaN               41.0               10.0
# 118    NaN    NaN               40.0                9.0
# 120    NaN    NaN               70.0               22.0
# 137    NaN    NaN               91.0               26.0
# 196    NaN    NaN               98.0               29.0
# 208    NaN    NaN               63.0               16.0
# 211    NaN    NaN               92.0               27.0
# 218    NaN    NaN               69.0               21.0
# 219    NaN    NaN               71.0               23.0
# 261    NaN    NaN               99.0               30.0
#
# [30 rows x 45 columns]

# %%
te1
# Out:
#      Rank_x    Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 14       15  Gronkowski        Rob  Rob Gronkowski      2         1       353
# 27       28       Kelce     Travis    Travis Kelce      3         1       535
# 53       54      Graham      Jimmy    Jimmy Graham      5         1       366
# 74       85        Ertz       Zach       Zach Ertz      7         3       450
# 127     154      Engram       Evan     Evan Engram     11         1       556
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 14           78       TE  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 27           79       TE  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 53           75       TE  SEA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 74           79       TE  PHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 127          75       TE  NYG  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_te
# 14     NaN               42.0                1.0
# 27     NaN               43.0                2.0
# 53     NaN               96.0                4.0
# 74     NaN               67.0                3.0
# 127    NaN               97.0                5.0
#
# [5 rows x 45 columns]

# %%
qb1
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 24       25           Brady        Tom           Tom Brady      3         1
# 33       34           Brees       Drew          Drew Brees      3         1
# 42       43          Keenum       Case         Case Keenum      4         1
# 46       47            Ryan       Matt           Matt Ryan      4         1
# 51       52          Wilson    Russell      Russell Wilson      5         1
# 58       62            Carr      Derek          Derek Carr      5         1
# 60       67         Winston     Jameis      Jameis Winston      6         1
# 61       69          Newton        Cam          Cam Newton      6         1
# 68       76         Mariota     Marcus      Marcus Mariota      6         1
# 72       82         Cousins       Kirk        Kirk Cousins      7         1
# 79       92  Roethlisberger        Ben  Ben Roethlisberger      7         1
# 81       95        Prescott        Dak        Dak Prescott      7         1
# 90      109        Stafford    Matthew    Matthew Stafford      8         1
# 94      114          Rivers     Philip       Philip Rivers      8         1
# 123     149          Dalton       Andy         Andy Dalton     11         1
# 126     153         Manning        Eli         Eli Manning     11         1
# 146     175           Kizer    DeShone       DeShone Kizer     13         1
# 151     183          Taylor      Tyrod        Tyrod Taylor     13         1
# 173     210         Bortles      Blake       Blake Bortles     15         2
# 184     224          Cutler        Jay          Jay Cutler     16         1
# 186     229           Smith       Alex          Alex Smith     16         1
# 187     230          Flacco        Joe          Joe Flacco     16         1
# 210     254            Goff      Jared          Jared Goff     18         2
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 24        491          76       QB  NEP  ...    NaN  NaN NaN  NaN  385.0
# 33        495          76       QB  NOS  ...    NaN  NaN NaN  NaN  386.0
# 42       1243           5       QB  MIN  ...    NaN  NaN NaN  NaN  325.0
# 46        472          77       QB  ATL  ...    NaN  NaN NaN  NaN  342.0
# 51        478          73       QB  SEA  ...    NaN  NaN NaN  NaN  339.0
# 58        509          73       QB  OAK  ...    NaN  NaN NaN  NaN  323.0
# 60        473          74       QB  TBB  ...    NaN  NaN NaN  NaN  282.0
# 61        479          77       QB  CAR  ...    NaN  NaN NaN  NaN  291.0
# 68        503          77       QB  TEN  ...    NaN  NaN NaN  NaN  281.0
# 72        498          74       QB  WAS  ...    NaN  NaN NaN  NaN  347.0
# 79        481          79       QB  PIT  ...    NaN  NaN NaN  NaN  360.0
# 81        533          73       QB  DAL  ...    NaN  NaN NaN  NaN  308.0
# 90        616          74       QB  DET  ...    NaN  NaN NaN  NaN  371.0
# 94        487          74       QB  LAC  ...    NaN  NaN NaN  NaN  360.0
# 123       620          71       QB  CIN  ...    NaN  NaN NaN  NaN  297.0
# 126       619          71       QB  NYG  ...    NaN  NaN NaN  NaN  352.0
# 146       666          39       QB  CLE  ...    NaN  NaN NaN  NaN  255.0
# 151       625          63       QB  BUF  ...    NaN  NaN NaN  NaN  263.0
# 173       654          47       QB  JAC  ...    NaN  NaN NaN  NaN  315.0
# 184       941          38       QB  MIA  ...    NaN  NaN NaN  NaN  266.0
# 186       633          51       QB  WAS  ...    NaN  NaN NaN  NaN  341.0
# 187       635          51       QB  BAL  ...    NaN  NaN NaN  NaN  352.0
# 210       667          39       QB  LAR  ...    NaN  NaN NaN  NaN  296.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 24    8.0   35.0   25.0                5.0                3.0
# 33    8.0   20.0   33.0               13.0                8.0
# 42    7.0   22.0   40.0               22.0               13.0
# 46   12.0   24.0   32.0               25.0               14.0
# 51   11.0   43.0   95.0                2.0                1.0
# 58   13.0   20.0   23.0               33.0               18.0
# 60   11.0   33.0   33.0               38.0               19.0
# 61   16.0   35.0  139.0                3.0                2.0
# 68   15.0   27.0   60.0               29.0               17.0
# 72   13.0   41.0   49.0                8.0                5.0
# 79   14.0   21.0   28.0               16.0               10.0
# 81   13.0   32.0   57.0               15.0                9.0
# 90   10.0   47.0   29.0               10.0                6.0
# 94   10.0   18.0   18.0               11.0                7.0
# 123  12.0   39.0   38.0               28.0               16.0
# 126  13.0   31.0   12.0               50.0               20.0
# 146  22.0   38.0   77.0               58.0               22.0
# 151   4.0   46.0   84.0               26.0               15.0
# 173  13.0   24.0   57.0               20.0               12.0
# 184  14.0   20.0   19.0               80.0               23.0
# 186   5.0   35.0   60.0                6.0                4.0
# 187  13.0   27.0   25.0               52.0               21.0
# 210   7.0   25.0   28.0               19.0               11.0
#
# [23 rows x 45 columns]

# %%
rb2 = rb[(rb['FantasyPointsRank'] <= 50)]
wr2 = wr[(wr['FantasyPointsRank'] <= 50)]
te2 = te[(te['FantasyPointsRank'] <= 50)]
qb2 = qb[(qb['FantasyPointsRank'] <= 50)]
rb2
# Out:
#     Rank_x   Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 0        1       Bell    Le'Veon         Le'Veon Bell      1         1
# 5        6    Elliott    Ezekiel      Ezekiel Elliott      1         1
# 6        7      McCoy     LeSean         LeSean McCoy      1         1
# 7        8     Gordon     Melvin        Melvin Gordon      1         1
# 10      11  Fournette    Leonard    Leonard Fournette      1         1
# 13      14     Gurley       Todd          Todd Gurley      2         1
# 18      19     Howard     Jordan        Jordan Howard      2         1
# 21      22  McCaffrey  Christian  Christian McCaffrey      2         1
# 35      36       Hyde     Carlos          Carlos Hyde      3         1
# 43      44     Ingram       Mark          Mark Ingram      4         1
# 44      45       Hunt     Kareem          Kareem Hunt      4         1
# 91     111     Kamara      Alvin         Alvin Kamara      8         1
#
#     Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 0        469          76       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 5        448          71       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 6        442          76       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN
# 7        571          72       RB  LAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 10       541          98       RB  JAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 13       447          78       RB  LAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 18       449          72       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 21       542          98       RB  CAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 35       530          75       RB  SFO  ...    NaN  NaN NaN  NaN NaN  NaN
# 43       461          80       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 44       546          97       RB  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 91       600          78       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
#
#     SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 0     NaN    NaN                4.0                2.0
# 5     NaN    NaN               44.0               10.0
# 6     NaN    NaN               23.0                7.0
# 7     NaN    NaN               18.0                5.0
# 10    NaN    NaN               27.0                8.0
# 13    NaN    NaN                1.0                1.0
# 18    NaN    NaN               48.0               12.0
# 21    NaN    NaN               47.0               11.0
# 35    NaN    NaN               36.0                9.0
# 43    NaN    NaN               21.0                6.0
# 44    NaN    NaN               12.0                4.0
# 91    NaN    NaN                9.0                3.0
#
# [12 rows x 45 columns]

# %%
wr2
# Out:
#      Rank_x    Player_x Unnamed: 2       Player_Name  Round  Min Pick  \
# 1         2       Brown    Antonio     Antonio Brown      1         1
# 2         3       Jones      Julio       Julio Jones      1         1
# 4         5       Green       A.J.        A.J. Green      1         1
# 12       13      Thomas    Michael    Michael Thomas      2         1
# 20       21       Cooks    Brandin     Brandin Cooks      2         1
# 22       23     Hopkins    DeAndre   DeAndre Hopkins      2         1
# 23       24     Baldwin       Doug      Doug Baldwin      2         1
# 29       30       Allen     Keenan      Keenan Allen      3         1
# 36       37        Hill     Tyreek       Tyreek Hill      4         1
# 38       39      Landry     Jarvis     Jarvis Landry      4         1
# 48       49  Fitzgerald      Larry  Larry Fitzgerald      5         1
# 95      115     Thielen       Adam      Adam Thielen      8         2
# 118     144       Jones     Marvin      Marvin Jones     10         4
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 1         433          77       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 2         438          77       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 4         395          72       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 12        392          78       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 20        389          79       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 22        364          74       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 23        528          74       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN
# 29        532          75       WR  LAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 36        468          80       WR  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 38        455          75       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 48        415          76       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 95        563          75       WR  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 118       470          68       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_wr
# 1      NaN    NaN               17.0                2.0
# 2      NaN    NaN               30.0                4.0
# 4      NaN    NaN               45.0               11.0
# 12     NaN    NaN               32.0                6.0
# 20     NaN    NaN               46.0               12.0
# 22     NaN    NaN               14.0                1.0
# 23     NaN    NaN               49.0               13.0
# 29     NaN    NaN               24.0                3.0
# 36     NaN    NaN               39.0                8.0
# 38     NaN    NaN               37.0                7.0
# 48     NaN    NaN               31.0                5.0
# 95     NaN    NaN               41.0               10.0
# 118    NaN    NaN               40.0                9.0
#
# [13 rows x 45 columns]

# %%
te2
# Out:
#     Rank_x    Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 14      15  Gronkowski        Rob  Rob Gronkowski      2         1       353
# 27      28       Kelce     Travis    Travis Kelce      3         1       535
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 14          78       TE  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 27          79       TE  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_te
# 14               42.0                1.0
# 27               43.0                2.0
#
# [2 rows x 45 columns]

# %%
qb2
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 24       25           Brady        Tom           Tom Brady      3         1
# 33       34           Brees       Drew          Drew Brees      3         1
# 42       43          Keenum       Case         Case Keenum      4         1
# 46       47            Ryan       Matt           Matt Ryan      4         1
# 51       52          Wilson    Russell      Russell Wilson      5         1
# 58       62            Carr      Derek          Derek Carr      5         1
# 60       67         Winston     Jameis      Jameis Winston      6         1
# 61       69          Newton        Cam          Cam Newton      6         1
# 68       76         Mariota     Marcus      Marcus Mariota      6         1
# 72       82         Cousins       Kirk        Kirk Cousins      7         1
# 79       92  Roethlisberger        Ben  Ben Roethlisberger      7         1
# 81       95        Prescott        Dak        Dak Prescott      7         1
# 90      109        Stafford    Matthew    Matthew Stafford      8         1
# 94      114          Rivers     Philip       Philip Rivers      8         1
# 123     149          Dalton       Andy         Andy Dalton     11         1
# 126     153         Manning        Eli         Eli Manning     11         1
# 151     183          Taylor      Tyrod        Tyrod Taylor     13         1
# 173     210         Bortles      Blake       Blake Bortles     15         2
# 186     229           Smith       Alex          Alex Smith     16         1
# 210     254            Goff      Jared          Jared Goff     18         2
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 24        491          76       QB  NEP  ...    NaN  NaN NaN  NaN  385.0
# 33        495          76       QB  NOS  ...    NaN  NaN NaN  NaN  386.0
# 42       1243           5       QB  MIN  ...    NaN  NaN NaN  NaN  325.0
# 46        472          77       QB  ATL  ...    NaN  NaN NaN  NaN  342.0
# 51        478          73       QB  SEA  ...    NaN  NaN NaN  NaN  339.0
# 58        509          73       QB  OAK  ...    NaN  NaN NaN  NaN  323.0
# 60        473          74       QB  TBB  ...    NaN  NaN NaN  NaN  282.0
# 61        479          77       QB  CAR  ...    NaN  NaN NaN  NaN  291.0
# 68        503          77       QB  TEN  ...    NaN  NaN NaN  NaN  281.0
# 72        498          74       QB  WAS  ...    NaN  NaN NaN  NaN  347.0
# 79        481          79       QB  PIT  ...    NaN  NaN NaN  NaN  360.0
# 81        533          73       QB  DAL  ...    NaN  NaN NaN  NaN  308.0
# 90        616          74       QB  DET  ...    NaN  NaN NaN  NaN  371.0
# 94        487          74       QB  LAC  ...    NaN  NaN NaN  NaN  360.0
# 123       620          71       QB  CIN  ...    NaN  NaN NaN  NaN  297.0
# 126       619          71       QB  NYG  ...    NaN  NaN NaN  NaN  352.0
# 151       625          63       QB  BUF  ...    NaN  NaN NaN  NaN  263.0
# 173       654          47       QB  JAC  ...    NaN  NaN NaN  NaN  315.0
# 186       633          51       QB  WAS  ...    NaN  NaN NaN  NaN  341.0
# 210       667          39       QB  LAR  ...    NaN  NaN NaN  NaN  296.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 24    8.0   35.0   25.0                5.0                3.0
# 33    8.0   20.0   33.0               13.0                8.0
# 42    7.0   22.0   40.0               22.0               13.0
# 46   12.0   24.0   32.0               25.0               14.0
# 51   11.0   43.0   95.0                2.0                1.0
# 58   13.0   20.0   23.0               33.0               18.0
# 60   11.0   33.0   33.0               38.0               19.0
# 61   16.0   35.0  139.0                3.0                2.0
# 68   15.0   27.0   60.0               29.0               17.0
# 72   13.0   41.0   49.0                8.0                5.0
# 79   14.0   21.0   28.0               16.0               10.0
# 81   13.0   32.0   57.0               15.0                9.0
# 90   10.0   47.0   29.0               10.0                6.0
# 94   10.0   18.0   18.0               11.0                7.0
# 123  12.0   39.0   38.0               28.0               16.0
# 126  13.0   31.0   12.0               50.0               20.0
# 151   4.0   46.0   84.0               26.0               15.0
# 173  13.0   24.0   57.0               20.0               12.0
# 186   5.0   35.0   60.0                6.0                4.0
# 210   7.0   25.0   28.0               19.0               11.0
#
# [20 rows x 45 columns]

# %%
rb3 = rb[(rb['FantasyPointsRank'] <= 25)]
wr3 = wr[(wr['FantasyPointsRank'] <= 25)]
te3 = te[(te['FantasyPointsRank'] <= 25)]
qb3 = qb[(qb['FantasyPointsRank'] <= 25)]
rb3
# Out:
#     Rank_x Player_x Unnamed: 2    Player_Name  Round  Min Pick  Max Pick  \
# 0        1     Bell    Le'Veon   Le'Veon Bell      1         1       469
# 6        7    McCoy     LeSean   LeSean McCoy      1         1       442
# 7        8   Gordon     Melvin  Melvin Gordon      1         1       571
# 13      14   Gurley       Todd    Todd Gurley      2         1       447
# 43      44   Ingram       Mark    Mark Ingram      4         1       461
# 44      45     Hunt     Kareem    Kareem Hunt      4         1       546
# 91     111   Kamara      Alvin   Alvin Kamara      8         1       600
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 0           76       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 6           76       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 7           72       RB  LAC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 13          78       RB  LAR  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 43          80       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 44          97       RB  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 91          78       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_rb
# 0                 4.0                2.0
# 6                23.0                7.0
# 7                18.0                5.0
# 13                1.0                1.0
# 43               21.0                6.0
# 44               12.0                4.0
# 91                9.0                3.0
#
# [7 rows x 45 columns]

# %%
wr3
# Out:
#     Rank_x Player_x Unnamed: 2      Player_Name  Round  Min Pick  Max Pick  \
# 1        2    Brown    Antonio    Antonio Brown      1         1       433
# 22      23  Hopkins    DeAndre  DeAndre Hopkins      2         1       364
# 29      30    Allen     Keenan     Keenan Allen      3         1       532
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 1           77       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 22          74       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 29          75       WR  LAC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_wr
# 1                17.0                2.0
# 22               14.0                1.0
# 29               24.0                3.0
#
# [3 rows x 45 columns]

# %%
wr3['FantasyPointsRank'].sum()
# Out:
# 55.0

# %%
te3
# Out:
# Empty DataFrame
# Columns: [Rank_x, Player_x, Unnamed: 2, Player_Name, Round, Min Pick, Max Pick, % Selected, Position, Team, PositionRank, Rank_y, Player_y, ATT, YDS, Y/A, LG, 20+, TD, REC, TGT, YDS.1, Y/R, TD.1, FL, G, FPTS, FPTS/G, OWN, FG, FGA, PCT, 1-19, 20-29, 30-39, 40-49, 50+, XPT, XPA, CMP, INT, SACKS, ATT.1, FantasyPointsRank, performance_fp_te]
# Index: []
#
# [0 rows x 45 columns]

# %%
qb3
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 24       25           Brady        Tom           Tom Brady      3         1
# 33       34           Brees       Drew          Drew Brees      3         1
# 42       43          Keenum       Case         Case Keenum      4         1
# 46       47            Ryan       Matt           Matt Ryan      4         1
# 51       52          Wilson    Russell      Russell Wilson      5         1
# 61       69          Newton        Cam          Cam Newton      6         1
# 72       82         Cousins       Kirk        Kirk Cousins      7         1
# 79       92  Roethlisberger        Ben  Ben Roethlisberger      7         1
# 81       95        Prescott        Dak        Dak Prescott      7         1
# 90      109        Stafford    Matthew    Matthew Stafford      8         1
# 94      114          Rivers     Philip       Philip Rivers      8         1
# 173     210         Bortles      Blake       Blake Bortles     15         2
# 186     229           Smith       Alex          Alex Smith     16         1
# 210     254            Goff      Jared          Jared Goff     18         2
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 24        491          76       QB  NEP  ...    NaN  NaN NaN  NaN  385.0
# 33        495          76       QB  NOS  ...    NaN  NaN NaN  NaN  386.0
# 42       1243           5       QB  MIN  ...    NaN  NaN NaN  NaN  325.0
# 46        472          77       QB  ATL  ...    NaN  NaN NaN  NaN  342.0
# 51        478          73       QB  SEA  ...    NaN  NaN NaN  NaN  339.0
# 61        479          77       QB  CAR  ...    NaN  NaN NaN  NaN  291.0
# 72        498          74       QB  WAS  ...    NaN  NaN NaN  NaN  347.0
# 79        481          79       QB  PIT  ...    NaN  NaN NaN  NaN  360.0
# 81        533          73       QB  DAL  ...    NaN  NaN NaN  NaN  308.0
# 90        616          74       QB  DET  ...    NaN  NaN NaN  NaN  371.0
# 94        487          74       QB  LAC  ...    NaN  NaN NaN  NaN  360.0
# 173       654          47       QB  JAC  ...    NaN  NaN NaN  NaN  315.0
# 186       633          51       QB  WAS  ...    NaN  NaN NaN  NaN  341.0
# 210       667          39       QB  LAR  ...    NaN  NaN NaN  NaN  296.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 24    8.0   35.0   25.0                5.0                3.0
# 33    8.0   20.0   33.0               13.0                8.0
# 42    7.0   22.0   40.0               22.0               13.0
# 46   12.0   24.0   32.0               25.0               14.0
# 51   11.0   43.0   95.0                2.0                1.0
# 61   16.0   35.0  139.0                3.0                2.0
# 72   13.0   41.0   49.0                8.0                5.0
# 79   14.0   21.0   28.0               16.0               10.0
# 81   13.0   32.0   57.0               15.0                9.0
# 90   10.0   47.0   29.0               10.0                6.0
# 94   10.0   18.0   18.0               11.0                7.0
# 173  13.0   24.0   57.0               20.0               12.0
# 186   5.0   35.0   60.0                6.0                4.0
# 210   7.0   25.0   28.0               19.0               11.0
#
# [14 rows x 45 columns]

# %%
rb_25_50 = rb2[(rb2['FantasyPointsRank'] >= 25)]
wr_25_50 = wr2[(wr2['FantasyPointsRank'] >= 25)]
te_25_50 = te2[(te2['FantasyPointsRank'] >= 25)]
qb_25_50 = qb2[(qb2['FantasyPointsRank'] >= 25)]
rb_25_50
# Out:
#     Rank_x   Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 5        6    Elliott    Ezekiel      Ezekiel Elliott      1         1
# 10      11  Fournette    Leonard    Leonard Fournette      1         1
# 18      19     Howard     Jordan        Jordan Howard      2         1
# 21      22  McCaffrey  Christian  Christian McCaffrey      2         1
# 35      36       Hyde     Carlos          Carlos Hyde      3         1
#
#     Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 5        448          71       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 10       541          98       RB  JAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 18       449          72       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 21       542          98       RB  CAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 35       530          75       RB  SFO  ...    NaN  NaN NaN  NaN NaN  NaN
#
#     SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 5     NaN    NaN               44.0               10.0
# 10    NaN    NaN               27.0                8.0
# 18    NaN    NaN               48.0               12.0
# 21    NaN    NaN               47.0               11.0
# 35    NaN    NaN               36.0                9.0
#
# [5 rows x 45 columns]

# %%
rb_25_50['FantasyPointsRank'].sum()
# Out:
# 202.0

# %%
wr_25_50
# Out:
#      Rank_x    Player_x Unnamed: 2       Player_Name  Round  Min Pick  \
# 2         3       Jones      Julio       Julio Jones      1         1
# 4         5       Green       A.J.        A.J. Green      1         1
# 12       13      Thomas    Michael    Michael Thomas      2         1
# 20       21       Cooks    Brandin     Brandin Cooks      2         1
# 23       24     Baldwin       Doug      Doug Baldwin      2         1
# 36       37        Hill     Tyreek       Tyreek Hill      4         1
# 38       39      Landry     Jarvis     Jarvis Landry      4         1
# 48       49  Fitzgerald      Larry  Larry Fitzgerald      5         1
# 95      115     Thielen       Adam      Adam Thielen      8         2
# 118     144       Jones     Marvin      Marvin Jones     10         4
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 2         438          77       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 4         395          72       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 12        392          78       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 20        389          79       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 23        528          74       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN
# 36        468          80       WR  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 38        455          75       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 48        415          76       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 95        563          75       WR  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 118       470          68       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_wr
# 2      NaN    NaN               30.0                4.0
# 4      NaN    NaN               45.0               11.0
# 12     NaN    NaN               32.0                6.0
# 20     NaN    NaN               46.0               12.0
# 23     NaN    NaN               49.0               13.0
# 36     NaN    NaN               39.0                8.0
# 38     NaN    NaN               37.0                7.0
# 48     NaN    NaN               31.0                5.0
# 95     NaN    NaN               41.0               10.0
# 118    NaN    NaN               40.0                9.0
#
# [10 rows x 45 columns]

# %%
wr_25_50['FantasyPointsRank'].sum()
# Out:
# 390.0
