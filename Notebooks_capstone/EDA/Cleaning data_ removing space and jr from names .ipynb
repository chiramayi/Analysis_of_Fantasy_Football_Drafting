# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from matplotlib import rcParams

# %matplotlib inline

# %%
adp_19 = pd.read_csv('Ranked_adp_for_merge/adp_ranked_2019 - adp_ranked_2019.csv')
fp_19 = pd.read_csv('clean_fp_data_merge/fp_data_cleaned_19 - fp_data_uncleaned - fp_data_uncleaned_19.csv')

# %%
adp_19.head(10)
# Out:
#    Rank     Player Unnamed: 2          Player_Name  Min Pick  Max Pick  \
# 0     1    Barkley     Saquon       Saquon Barkley         1       369
# 1     2  McCaffrey  Christian  Christian McCaffrey         1       205
# 2     3     Kamara      Alvin         Alvin Kamara         1       249
# 3     4    Elliott    Ezekiel      Ezekiel Elliott         1       201
# 4     5    Hopkins    DeAndre      DeAndre Hopkins         1       210
# 5     6      Adams    Davante        Davante Adams         1       207
# 6     7    Johnson      David        David Johnson         1       221
# 7     8       Bell    Le'Veon         Le'Veon Bell         1       194
# 8     9     Thomas    Michael       Michael Thomas         1       205
# 9    10     Conner      James         James Conner         1       259
#
#    % Selected Position Team  PositionRank
# 0          56       RB  NYG             1
# 1          57       RB  CAR             2
# 2          54       RB  NOS             3
# ...

# %%
adp_19.shape
# Out:
# (323, 10)

# %%
fp_19['Player'] = fp_19['Player'].str.strip()

fp_19.head()
# Out:
#    Rank               Player    ATT    YDS  Y/A    LG  20+    TD    REC  \
# 0     1        Lamar Jackson  401.0  3,127  7.8   NaN  NaN  36.0    NaN
# 1     1  Christian McCaffrey  287.0  1,387  4.8  84.0  6.0  15.0  116.0
# 2     2         Dak Prescott  596.0  4,902  8.2   NaN  NaN  30.0    NaN
# 3     3       Jameis Winston  626.0  5,109  8.2   NaN  NaN  33.0    NaN
# 4     4       Russell Wilson  516.0  4,110  8.0   NaN  NaN  31.0    NaN
#
#      TGT  ...   INT  SACKS  ATT.1  SACK  FR  FF  DEF TD SFTY  SPC TD  \
# 0    NaN  ...   6.0   23.0  176.0   NaN NaN NaN     NaN  NaN     NaN
# 1  142.0  ...   NaN    NaN    NaN   NaN NaN NaN     NaN  NaN     NaN
# 2    NaN  ...  11.0   23.0   52.0   NaN NaN NaN     NaN  NaN     NaN
# 3    NaN  ...  30.0   47.0   59.0   NaN NaN NaN     NaN  NaN     NaN
# 4    NaN  ...   5.0   48.0   75.0   NaN NaN NaN     NaN  NaN     NaN
#
#    FantasyPointsRank
# 0                1.0
# 1                2.0
# 2                3.0
# 3                4.0
# ...

# %%
fp_19['Player'] = fp_19['Player'].str.strip(' II')
#fp_19['Player'] = fp_19['Player'].str.strip(' Jr.')

# %%
lj = fp_19[fp_19['Player'] == 'Lamar Jackson']
lj.head()
# Out:
#    Rank         Player    ATT    YDS  Y/A  LG  20+    TD  REC  TGT  ...  INT  \
# 0     1  Lamar Jackson  401.0  3,127  7.8 NaN  NaN  36.0  NaN  NaN  ...  6.0
#
#    SACKS  ATT.1  SACK  FR  FF  DEF TD SFTY  SPC TD  FantasyPointsRank
# 0   23.0  176.0   NaN NaN NaN     NaN  NaN     NaN                1.0
#
# [1 rows x 39 columns]

# %%
fp_19.head()
# Out:
#    Rank               Player    ATT    YDS  Y/A    LG  20+    TD    REC  \
# 0     1        Lamar Jackson  401.0  3,127  7.8   NaN  NaN  36.0    NaN
# 1     1  Christian McCaffrey  287.0  1,387  4.8  84.0  6.0  15.0  116.0
# 2     2         Dak Prescott  596.0  4,902  8.2   NaN  NaN  30.0    NaN
# 3     3       Jameis Winston  626.0  5,109  8.2   NaN  NaN  33.0    NaN
# 4     4       Russell Wilson  516.0  4,110  8.0   NaN  NaN  31.0    NaN
#
#      TGT  ...   INT  SACKS  ATT.1  SACK  FR  FF  DEF TD SFTY  SPC TD  \
# 0    NaN  ...   6.0   23.0  176.0   NaN NaN NaN     NaN  NaN     NaN
# 1  142.0  ...   NaN    NaN    NaN   NaN NaN NaN     NaN  NaN     NaN
# 2    NaN  ...  11.0   23.0   52.0   NaN NaN NaN     NaN  NaN     NaN
# 3    NaN  ...  30.0   47.0   59.0   NaN NaN NaN     NaN  NaN     NaN
# 4    NaN  ...   5.0   48.0   75.0   NaN NaN NaN     NaN  NaN     NaN
#
#    FantasyPointsRank
# 0                1.0
# 1                2.0
# 2                3.0
# 3                4.0
# ...

# %%
rwd_19 = pd.merge(fp_19, adp_19,
                 left_on = 'Player', right_on = 'Player_Name',
                 how = 'right')
rwd_19.shape
# Out:
# (325, 49)

# %%
lwd_19 = pd.merge(fp_19, adp_19,
                 left_on = 'Player', right_on = 'Player_Name')
lwd_19.shape
# Out:
# (308, 49)

# %%
rwd_19.head(100)
# Out:
#     Rank_x             Player_x    ATT    YDS  Y/A    LG   20+    TD    REC  \
# 0      1.0        Lamar Jackson  401.0  3,127  7.8   NaN   NaN  36.0    NaN
# 1      1.0  Christian McCaffrey  287.0  1,387  4.8  84.0   6.0  15.0  116.0
# 2      2.0         Dak Prescott  596.0  4,902  8.2   NaN   NaN  30.0    NaN
# 3      3.0       Jameis Winston  626.0  5,109  8.2   NaN   NaN  33.0    NaN
# 4      4.0       Russell Wilson  516.0  4,110  8.0   NaN   NaN  31.0    NaN
# ..     ...                  ...    ...    ...  ...   ...   ...   ...    ...
# 95    26.0         Ronald Jones  172.0    724  4.2  49.0   6.0   6.0   31.0
# 96    27.0          Carlos Hyde  245.0  1,070  4.4  58.0   8.0   6.0   10.0
# 97    28.0          Sony Michel  247.0    912  3.7  26.0   3.0   7.0   12.0
# 98     5.0     Los Angeles Rams    NaN    NaN  NaN   NaN   NaN   NaN    NaN
# 99    35.0       Darius Slayton    0.0    740  NaN  55.0  12.0   8.0   48.0
#
# ...

# %%
rwd_19.tail(60)
# Out:
#      Rank_x             Player_x    ATT  YDS  Y/A    LG  20+   TD   REC   TGT  \
# 265    49.0           Josh Rosen  109.0  567  5.2   NaN  NaN  1.0   NaN   NaN
# 266    95.0         Travis Homer   18.0  114  6.3  29.0  1.0  0.0  11.0  13.0
# 267    63.0          Jesse James    0.0  142  NaN  23.0  1.0  0.0  16.0  27.0
# 268    52.0           Cam Newton   89.0  572  6.4   NaN  NaN  0.0   NaN   NaN
# 269   146.0            Deon Cain    0.0  124  NaN  35.0  3.0  0.0   9.0  20.0
# 270    75.0          Trey Burton    0.0   84  NaN  16.0  0.0  0.0  14.0  24.0
# 271   150.0      Rashard Higgins    0.0   55  NaN  35.0  1.0  1.0   4.0  11.0
# 272    82.0          David Njoku    0.0   41  NaN  18.0  0.0  1.0   5.0  10.0
# 273   158.0        Robert Foster    2.0   64  NaN  24.0  3.0  0.0   3.0  18.0
# 274   161.0         Riley Ridley    0.0   69  NaN  32.0  1.0  0.0   6.0   7.0
# 275   115.0           Mike Davis   13.0   27  2.1   8.0  0.0  0.0   7.0   8.0
# ...

# %%
rwd_19.head(15)
# Out:
#     Rank_x             Player_x    ATT    YDS  Y/A    LG   20+    TD    REC  \
# 0      1.0        Lamar Jackson  401.0  3,127  7.8   NaN   NaN  36.0    NaN
# 1      1.0  Christian McCaffrey  287.0  1,387  4.8  84.0   6.0  15.0  116.0
# 2      2.0         Dak Prescott  596.0  4,902  8.2   NaN   NaN  30.0    NaN
# 3      3.0       Jameis Winston  626.0  5,109  8.2   NaN   NaN  33.0    NaN
# 4      4.0       Russell Wilson  516.0  4,110  8.0   NaN   NaN  31.0    NaN
# 5      5.0       Deshaun Watson  495.0  3,852  7.8   NaN   NaN  26.0    NaN
# 6      1.0       Michael Thomas    1.0  1,725  NaN  49.0  17.0   9.0  149.0
# 7      6.0           Josh Allen  461.0  3,089  6.7   NaN   NaN  20.0    NaN
# 8      7.0         Kyler Murray  542.0  3,722  6.9   NaN   NaN  20.0    NaN
# 9      8.0      Patrick Mahomes  484.0  4,031  8.3   NaN   NaN  26.0    NaN
# 10     2.0          Aaron Jones  236.0  1,084  4.6  56.0   5.0  16.0   49.0
# ...

# %%
adp_19.shape
# Out:
# (323, 10)

# %%
fp_19.shape
# Out:
# (1234, 39)

# %%
#use this for corr
