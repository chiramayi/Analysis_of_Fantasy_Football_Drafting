# %%
import pandas as pd

import gc # To collect garbage values generated during running

import matplotlib.pyplot as plt

import numpy as np

import seaborn as sns

# %%
d = pd.read_csv('2015_cleaned_with_rounds.csv')

# %%
rb = d.loc[d['Position'] == 'RB']
wr = d.loc[d['Position'] == 'WR']

# %%
wr['performance_fp_wr'] = wr['FantasyPointsRank'].rank(ascending = True)
rb['performance_fp_rb'] = rb['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-4-ea88c15edb18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wr['performance_fp_wr'] = wr['FantasyPointsRank'].rank(ascending = True)
# <ipython-input-4-ea88c15edb18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rb['performance_fp_rb'] = rb['FantasyPointsRank'].rank(ascending = True)

# %%
te = d.loc[d['Position'] == 'TE']
te['performance_fp_te'] = te['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-5-c576e4e6ce8f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['performance_fp_te'] = te['FantasyPointsRank'].rank(ascending = True)

# %%
qb = d.loc[d['Position'] == 'QB']
qb['performance_fp_qb'] = qb['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-6-4882867569a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qb['performance_fp_qb'] = qb['FantasyPointsRank'].rank(ascending = True)

# %%
k = d.loc[d['Position'] == 'PK']
k['performance_fp_qb'] = k['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-7-d0b0a0dfd751>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['performance_fp_qb'] = k['FantasyPointsRank'].rank(ascending = True)

# %%
Def = d.loc[d['Position'] == 'Def']
Def['performance_fp_qb'] = Def['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-8-1cd933a4c506>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Def['performance_fp_qb'] = Def['FantasyPointsRank'].rank(ascending = True)

# %%
rb_50 = rb.head(50)
after_rb = rb_50[(rb_50['FantasyPointsRank'] <= 70)]
after_rb.head(50)
# Out:
#      Rank_x  Player_x Unnamed: 2      Player_Name  Round  Min Pick  Max Pick  \
# 4         5  Peterson     Adrian  Adrian Peterson      1         1       499
# 11       12     Forte       Matt       Matt Forte      1         1       489
# 28       29    Miller      Lamar     Lamar Miller      3         1       475
# 30       31    Gurley       Todd      Todd Gurley      3         1       884
# 34       35    Ingram       Mark      Mark Ingram      3         1       463
# 35       36      Gore      Frank       Frank Gore      3         1       479
# 43       45    Murray   Latavius  Latavius Murray      4         1       467
# 67       70    Martin       Doug      Doug Martin      6         1       516
# 81       93     Ivory      Chris      Chris Ivory      7         1       494
# 102     127   Johnson      David    David Johnson      9         1       905
# 106     130   Freeman    Devonta  Devonta Freeman      9         1       487
# 114     142  McFadden     Darren  Darren McFadden     10         1       477
# 143     181  Woodhead      Danny   Danny Woodhead     12         2       487
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 4            68       RB  MIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 11           68       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 28           72       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 30           96       RB  STL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 34           72       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 35           73       RB  IND  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 43           74       RB  OAK  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 67           75       RB  TBB  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 81           76       RB  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 102          80       RB  ARI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 106          70       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 114          73       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 143          71       RB  SDC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_rb
# 4      NaN               25.0                2.0
# 11     NaN               52.0                8.0
# 28     NaN               42.0                5.0
# 30     NaN               47.0                7.0
# 34     NaN               61.0               12.0
# 35     NaN               64.0               13.0
# 43     NaN               60.0               11.0
# 67     NaN               35.0                3.0
# 81     NaN               58.0               10.0
# 102    NaN               53.0                9.0
# 106    NaN               16.0                1.0
# 114    NaN               65.0               14.0
# 143    NaN               43.0                6.0
#
# [13 rows x 45 columns]

# %%
wr_50 = wr.head(50)
after_wr = wr_50[(wr_50['FantasyPointsRank'] <= 70)]
after_wr.head(50)
# Out:
#      Rank_x    Player_x Unnamed: 2       Player_Name  Round  Min Pick  \
# 1         2       Brown    Antonio     Antonio Brown      1         1
# 6         7       Jones      Julio       Julio Jones      1         1
# 8         9      Thomas  Demaryius  Demaryius Thomas      1         1
# 12       13     Johnson     Calvin    Calvin Johnson      2         1
# 14       15       Green       A.J.        A.J. Green      2         1
# 17       18     Beckham      Odell     Odell Beckham      2         1
# 18       19        Cobb    Randall      Randall Cobb      2         1
# 21       22      Hilton       T.Y.       T.Y. Hilton      2         1
# 24       25       Evans       Mike        Mike Evans      3         1
# 26       27       Cooks    Brandin     Brandin Cooks      3         1
# 27       28      Cooper      Amari      Amari Cooper      3         1
# 29       30     Hopkins    DeAndre   DeAndre Hopkins      3         1
# 31       32     Sanders   Emmanuel  Emmanuel Sanders      3         1
# 33       34    Matthews     Jordan   Jordan Matthews      3         1
# 47       49     Watkins      Sammy     Sammy Watkins      4         1
# 52       54      Maclin     Jeremy     Jeremy Maclin      5         1
# 53       55      Landry     Jarvis     Jarvis Landry      5         1
# 57       59    Marshall    Brandon  Brandon Marshall      5         1
# 63       66    Robinson      Allen    Allen Robinson      6         1
# 82       94  Fitzgerald      Larry  Larry Fitzgerald      7         2
# 91      110       Brown       John        John Brown      8         2
# 101     126      Decker       Eric       Eric Decker      9         2
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 1         439          68       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 6         424          68       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 8         359          69       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 12        547          68       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
# 14        387          70       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 17        466          67       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN
# 18        456          70       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN
# 21        436          70       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 24        413          70       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN
# 26        462          72       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 27        883          96       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 29        421          73       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 31        338          72       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 33        408          72       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 47        465          72       WR  BUF  ...    NaN  NaN NaN  NaN NaN  NaN
# 52        469          74       WR  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 53        472          75       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 57        307          73       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
# 63        415          76       WR  JAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 82        491          77       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 91        471          75       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 101       464          72       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_wr
# 1      NaN    NaN                5.0                1.0
# 6      NaN    NaN                7.0                2.0
# 8      NaN    NaN               36.5               11.5
# 12     NaN    NaN               34.0               10.0
# 14     NaN    NaN               28.0                7.0
# 17     NaN    NaN               20.0                5.0
# 18     NaN    NaN               69.0               25.0
# 21     NaN    NaN               62.0               21.0
# 24     NaN    NaN               67.0               24.0
# 26     NaN    NaN               40.0               14.0
# 27     NaN    NaN               63.0               22.0
# 29     NaN    NaN               17.0                4.0
# 31     NaN    NaN               59.0               20.0
# 33     NaN    NaN               57.0               19.0
# 47     NaN    NaN               55.0               17.0
# 52     NaN    NaN               46.0               15.0
# 53     NaN    NaN               36.5               11.5
# 57     NaN    NaN               14.0                3.0
# 63     NaN    NaN               23.0                6.0
# 82     NaN    NaN               32.0                9.0
# 91     NaN    NaN               66.0               23.0
# 101    NaN    NaN               39.0               13.0
#
# [22 rows x 45 columns]

# %%
te_50 = te.head(50)
after_te = te_50[(te_50['FantasyPointsRank'] <= 70)]
after_te.head(30)
# Out:
#      Rank_x    Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 7         8  Gronkowski        Rob  Rob Gronkowski      1         1       351
# 50       52       Olsen       Greg      Greg Olsen      5         1       383
# 127     160      Walker    Delanie  Delanie Walker     11         2       404
# 220     294        Reed     Jordan     Jordan Reed     19         3       506
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 7            69       TE  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 50           75       TE  CAR  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 127          72       TE  TEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 220          47       TE  WAS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_te
# 7      NaN               33.0                1.0
# 50     NaN               54.0                4.0
# 127    NaN               49.0                3.0
# 220    NaN               44.0                2.0
#
# [4 rows x 45 columns]

# %%
qb_50 = qb.head(50)
after_qb = qb_50[(qb_50['FantasyPointsRank'] <= 70)]
after_qb.head(30)
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 15       16         Rodgers      Aaron       Aaron Rodgers      2         1
# 40       42          Wilson    Russell      Russell Wilson      4         1
# 56       58           Brees       Drew          Drew Brees      5         1
# 60       63  Roethlisberger        Ben  Ben Roethlisberger      6         1
# 66       69            Ryan       Matt           Matt Ryan      6         1
# 71       77           Brady        Tom           Tom Brady      6         1
# 73       79          Newton        Cam          Cam Newton      7         1
# 78       85        Stafford    Matthew    Matthew Stafford      7         1
# 85       99       Tannehill       Ryan      Ryan Tannehill      8         1
# 107     131         Manning        Eli         Eli Manning      9         1
# 111     137          Rivers     Philip       Philip Rivers     10         1
# 112     138        Bradford        Sam        Sam Bradford     10         1
# 120     148         Winston     Jameis      Jameis Winston     11         1
# 130     164         Mariota     Marcus      Marcus Mariota     11         1
# 132     166     Bridgewater      Teddy   Teddy Bridgewater     12         1
# 181     237          Palmer     Carson       Carson Palmer     16         1
# 210     275            Carr      Derek          Derek Carr     18         1
# 212     277          Cutler        Jay          Jay Cutler     18         1
# 214     281          Dalton       Andy         Andy Dalton     18         1
# 222     296          Taylor      Tyrod        Tyrod Taylor     19         1
# 234     313         Cousins       Kirk        Kirk Cousins     20         2
# 235     314           Smith       Alex          Alex Smith     20         2
# 240     319         Bortles      Blake       Blake Bortles     21         1
# 289     378     Fitzpatrick       Ryan    Ryan Fitzpatrick     25         3
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 15        523          67       QB  GBP  ...    NaN  NaN NaN  NaN  347.0
# 40        452          70       QB  SEA  ...    NaN  NaN NaN  NaN  329.0
# 56        515          68       QB  NOS  ...    NaN  NaN NaN  NaN  428.0
# 60        587          72       QB  PIT  ...    NaN  NaN NaN  NaN  319.0
# 66        510          71       QB  ATL  ...    NaN  NaN NaN  NaN  407.0
# 71        521          72       QB  NEP  ...    NaN  NaN NaN  NaN  402.0
# 73        501          72       QB  CAR  ...    NaN  NaN NaN  NaN  296.0
# 78        522          71       QB  DET  ...    NaN  NaN NaN  NaN  398.0
# 85        526          73       QB  MIA  ...    NaN  NaN NaN  NaN  363.0
# 107       507          73       QB  NYG  ...    NaN  NaN NaN  NaN  387.0
# 111       602          72       QB  SDC  ...    NaN  NaN NaN  NaN  437.0
# 112       525          79       QB  PHI  ...    NaN  NaN NaN  NaN  346.0
# 120       892          81       QB  TBB  ...    NaN  NaN NaN  NaN  312.0
# 130       890          78       QB  TEN  ...    NaN  NaN NaN  NaN  230.0
# 132       479          72       QB  MIN  ...    NaN  NaN NaN  NaN  292.0
# 181       528          68       QB  ARI  ...    NaN  NaN NaN  NaN  342.0
# 210       472          53       QB  OAK  ...    NaN  NaN NaN  NaN  350.0
# 212       510          56       QB  CHI  ...    NaN  NaN NaN  NaN  311.0
# 214       530          53       QB  CIN  ...    NaN  NaN NaN  NaN  255.0
# 222       674          20       QB  BUF  ...    NaN  NaN NaN  NaN  242.0
# 234       792          13       QB  WAS  ...    NaN  NaN NaN  NaN  379.0
# 235       584          42       QB  KCC  ...    NaN  NaN NaN  NaN  307.0
# 240       524          41       QB  JAC  ...    NaN  NaN NaN  NaN  355.0
# 289       672          14       QB  NYJ  ...    NaN  NaN NaN  NaN  335.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 15    8.0   46.0   58.0                9.0                7.0
# 40    8.0   45.0  103.0                3.0                3.0
# 56   11.0   31.0   24.0                8.0                6.0
# 60   16.0   20.0   15.0               30.0               20.0
# 66   16.0   30.0   36.0               27.0               19.0
# 71    7.0   38.0   34.0                2.0                2.0
# 73   10.0   33.0  132.0                1.0                1.0
# 78   13.0   44.0   44.0               11.0                9.0
# 85   12.0   45.0   32.0               24.0               17.0
# 107  14.0   27.0   20.0               12.0               10.0
# 111  13.0   40.0   17.0               15.0               12.0
# 112  14.0   28.0   26.0               50.0               24.0
# 120  15.0   27.0   54.0               18.0               13.0
# 130  10.0   38.0   34.0               41.0               22.0
# 132   9.0   44.0   44.0               45.0               23.0
# 181  11.0   25.0   25.0                6.0                5.0
# 210  13.0   31.0   33.0               19.0               14.0
# 212  11.0   29.0   38.0               31.0               21.0
# 214   7.0   20.0   57.0               26.0               18.0
# 222   6.0   36.0  104.0               21.0               15.0
# 234  11.0   26.0   26.0               10.0                8.0
# 235   7.0   45.0   84.0               22.0               16.0
# 240  18.0   51.0   52.0                4.0                4.0
# 289  15.0   19.0   60.0               13.0               11.0
#
# [24 rows x 45 columns]

# %%
rb1 = rb[(rb['FantasyPointsRank'] <= 100)]
wr1 = wr[(wr['FantasyPointsRank'] <= 100)]
te1 = te[(te['FantasyPointsRank'] <= 100)]
qb1 = qb[(qb['FantasyPointsRank'] <= 100)]
rb1
# Out:
#      Rank_x  Player_x Unnamed: 2        Player_Name  Round  Min Pick  \
# 4         5  Peterson     Adrian    Adrian Peterson      1         1
# 11       12     Forte       Matt         Matt Forte      1         1
# 13       14    Murray    DeMarco     DeMarco Murray      2         1
# 16       17     McCoy     LeSean       LeSean McCoy      2         1
# 22       23      Hill     Jeremy        Jeremy Hill      2         1
# 28       29    Miller      Lamar       Lamar Miller      3         1
# 30       31    Gurley       Todd        Todd Gurley      3         1
# 34       35    Ingram       Mark        Mark Ingram      3         1
# 35       36      Gore      Frank         Frank Gore      3         1
# 43       45    Murray   Latavius    Latavius Murray      4         1
# 54       56   Stewart   Jonathan   Jonathan Stewart      5         1
# 65       68   Bernard    Giovani    Giovani Bernard      6         1
# 67       70    Martin       Doug        Doug Martin      6         1
# 81       93     Ivory      Chris        Chris Ivory      7         1
# 87      103  Jennings     Rashad    Rashad Jennings      8         3
# 102     127   Johnson      David      David Johnson      9         1
# 106     130   Freeman    Devonta    Devonta Freeman      9         1
# 114     142  McFadden     Darren    Darren McFadden     10         1
# 143     181  Woodhead      Danny     Danny Woodhead     12         2
# 172     222      Sims    Charles       Charles Sims     15         3
# 208     272   Hillman     Ronnie     Ronnie Hillman     18         2
# 211     276  Williams   DeAngelo  DeAngelo Williams     18         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 4         499          68       RB  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 11        489          68       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 13        433          68       RB  PHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 16        513          69       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN
# 22        471          70       RB  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 28        475          72       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 30        884          96       RB  STL  ...    NaN  NaN NaN  NaN NaN  NaN
# 34        463          72       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 35        479          73       RB  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 43        467          74       RB  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 54        450          77       RB  CAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 65        514          74       RB  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 67        516          75       RB  TBB  ...    NaN  NaN NaN  NaN NaN  NaN
# 81        494          76       RB  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
# 87        495          74       RB  NYG  ...    NaN  NaN NaN  NaN NaN  NaN
# 102       905          80       RB  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 106       487          70       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 114       477          73       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 143       487          71       RB  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
# 172       460          58       RB  TBB  ...    NaN  NaN NaN  NaN NaN  NaN
# 208       705          45       RB  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 211       667          60       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 4      NaN    NaN               25.0                2.0
# 11     NaN    NaN               52.0                8.0
# 13     NaN    NaN               78.5               17.0
# 16     NaN    NaN               77.0               16.0
# 22     NaN    NaN               76.0               15.0
# 28     NaN    NaN               42.0                5.0
# 30     NaN    NaN               47.0                7.0
# 34     NaN    NaN               61.0               12.0
# 35     NaN    NaN               64.0               13.0
# 43     NaN    NaN               60.0               11.0
# 54     NaN    NaN               85.0               19.0
# 65     NaN    NaN               83.0               18.0
# 67     NaN    NaN               35.0                3.0
# 81     NaN    NaN               58.0               10.0
# 87     NaN    NaN               90.0               21.0
# 102    NaN    NaN               53.0                9.0
# 106    NaN    NaN               16.0                1.0
# 114    NaN    NaN               65.0               14.0
# 143    NaN    NaN               43.0                6.0
# 172    NaN    NaN               86.0               20.0
# 208    NaN    NaN               92.0               22.0
# 211    NaN    NaN               38.0                4.0
#
# [22 rows x 45 columns]

# %%
wr1
# Out:
#      Rank_x    Player_x Unnamed: 2       Player_Name  Round  Min Pick  \
# 1         2       Brown    Antonio     Antonio Brown      1         1
# 6         7       Jones      Julio       Julio Jones      1         1
# 8         9      Thomas  Demaryius  Demaryius Thomas      1         1
# 12       13     Johnson     Calvin    Calvin Johnson      2         1
# 14       15       Green       A.J.        A.J. Green      2         1
# 17       18     Beckham      Odell     Odell Beckham      2         1
# 18       19        Cobb    Randall      Randall Cobb      2         1
# 21       22      Hilton       T.Y.       T.Y. Hilton      2         1
# 24       25       Evans       Mike        Mike Evans      3         1
# 26       27       Cooks    Brandin     Brandin Cooks      3         1
# 27       28      Cooper      Amari      Amari Cooper      3         1
# 29       30     Hopkins    DeAndre   DeAndre Hopkins      3         1
# 31       32     Sanders   Emmanuel  Emmanuel Sanders      3         1
# 33       34    Matthews     Jordan   Jordan Matthews      3         1
# 42       44        Tate     Golden       Golden Tate      4         1
# 47       49     Watkins      Sammy     Sammy Watkins      4         1
# 52       54      Maclin     Jeremy     Jeremy Maclin      5         1
# 53       55      Landry     Jarvis     Jarvis Landry      5         1
# 57       59    Marshall    Brandon  Brandon Marshall      5         1
# 62       65      Bryant   Martavis   Martavis Bryant      6         1
# 63       66    Robinson      Allen    Allen Robinson      6         1
# 82       94  Fitzgerald      Larry  Larry Fitzgerald      7         2
# 91      110       Brown       John        John Brown      8         2
# 95      116       Floyd    Michael     Michael Floyd      8         3
# 101     126      Decker       Eric       Eric Decker      9         2
# 145     183      Garcon     Pierre     Pierre Garcon     13         5
# 198     260      Randle     Rueben     Rueben Randle     17         1
# 203     266    Crabtree    Michael  Michael Crabtree     17         1
# 216     286     Baldwin       Doug      Doug Baldwin     19         1
# 241     321       Jones      James       James Jones     21         2
# 261     344       Hurns      Allen       Allen Hurns     22         8
# 293     383      Austin      Tavon      Tavon Austin     25         4
# 320     414       Aiken      Kamar       Kamar Aiken     27         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 1         439          68       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 6         424          68       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 8         359          69       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 12        547          68       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
# 14        387          70       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 17        466          67       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN
# 18        456          70       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN
# 21        436          70       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 24        413          70       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN
# 26        462          72       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 27        883          96       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 29        421          73       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 31        338          72       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 33        408          72       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 42        380          73       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
# 47        465          72       WR  BUF  ...    NaN  NaN NaN  NaN NaN  NaN
# 52        469          74       WR  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 53        472          75       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 57        307          73       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
# 62        407          76       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 63        415          76       WR  JAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 82        491          77       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 91        471          75       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 95        385          71       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 101       464          72       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
# 145       571          68       WR  WAS  ...    NaN  NaN NaN  NaN NaN  NaN
# 198       418          53       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN
# 203       474          60       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 216       467          56       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN
# 241       771          13       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN
# 261       527          32       WR  JAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 293       601          21       WR  STL  ...    NaN  NaN NaN  NaN NaN  NaN
# 320       631          10       WR  BAL  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_wr
# 1      NaN    NaN                5.0                1.0
# 6      NaN    NaN                7.0                2.0
# 8      NaN    NaN               36.5               11.5
# 12     NaN    NaN               34.0               10.0
# 14     NaN    NaN               28.0                7.0
# 17     NaN    NaN               20.0                5.0
# 18     NaN    NaN               69.0               25.0
# 21     NaN    NaN               62.0               21.0
# 24     NaN    NaN               67.0               24.0
# 26     NaN    NaN               40.0               14.0
# 27     NaN    NaN               63.0               22.0
# 29     NaN    NaN               17.0                4.0
# 31     NaN    NaN               59.0               20.0
# 33     NaN    NaN               57.0               19.0
# 42     NaN    NaN               74.0               28.0
# 47     NaN    NaN               55.0               17.0
# 52     NaN    NaN               46.0               15.0
# 53     NaN    NaN               36.5               11.5
# 57     NaN    NaN               14.0                3.0
# 62     NaN    NaN              100.0               33.0
# 63     NaN    NaN               23.0                6.0
# 82     NaN    NaN               32.0                9.0
# 91     NaN    NaN               66.0               23.0
# 95     NaN    NaN               96.0               32.0
# 101    NaN    NaN               39.0               13.0
# 145    NaN    NaN               91.0               31.0
# 198    NaN    NaN               84.0               30.0
# 203    NaN    NaN               56.0               18.0
# 216    NaN    NaN               29.0                8.0
# 241    NaN    NaN               72.0               27.0
# 261    NaN    NaN               51.0               16.0
# 293    NaN    NaN               70.0               26.0
# 320    NaN    NaN               81.0               29.0
#
# [33 rows x 45 columns]

# %%
te1
# Out:
#      Rank_x    Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 7         8  Gronkowski        Rob  Rob Gronkowski      1         1       351
# 50       52       Olsen       Greg      Greg Olsen      5         1       383
# 51       53       Kelce     Travis    Travis Kelce      5         1       467
# 117     145      Eifert      Tyler    Tyler Eifert     10         1       513
# 127     160      Walker    Delanie  Delanie Walker     11         2       404
# 220     294        Reed     Jordan     Jordan Reed     19         3       506
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 7            69       TE  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 50           75       TE  CAR  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 51           75       TE  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 117          73       TE  CIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 127          72       TE  TEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 220          47       TE  WAS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_te
# 7      NaN               33.0                1.0
# 50     NaN               54.0                4.0
# 51     NaN               87.5                6.0
# 117    NaN               73.0                5.0
# 127    NaN               49.0                3.0
# 220    NaN               44.0                2.0
#
# [6 rows x 45 columns]

# %%
qb1
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 15       16         Rodgers      Aaron       Aaron Rodgers      2         1
# 40       42          Wilson    Russell      Russell Wilson      4         1
# 56       58           Brees       Drew          Drew Brees      5         1
# 60       63  Roethlisberger        Ben  Ben Roethlisberger      6         1
# 66       69            Ryan       Matt           Matt Ryan      6         1
# 71       77           Brady        Tom           Tom Brady      6         1
# 73       79          Newton        Cam          Cam Newton      7         1
# 78       85        Stafford    Matthew    Matthew Stafford      7         1
# 85       99       Tannehill       Ryan      Ryan Tannehill      8         1
# 107     131         Manning        Eli         Eli Manning      9         1
# 111     137          Rivers     Philip       Philip Rivers     10         1
# 112     138        Bradford        Sam        Sam Bradford     10         1
# 120     148         Winston     Jameis      Jameis Winston     11         1
# 130     164         Mariota     Marcus      Marcus Mariota     11         1
# 132     166     Bridgewater      Teddy   Teddy Bridgewater     12         1
# 177     229          Flacco        Joe          Joe Flacco     15         2
# 181     237          Palmer     Carson       Carson Palmer     16         1
# 210     275            Carr      Derek          Derek Carr     18         1
# 212     277          Cutler        Jay          Jay Cutler     18         1
# 214     281          Dalton       Andy         Andy Dalton     18         1
# 222     296          Taylor      Tyrod        Tyrod Taylor     19         1
# 234     313         Cousins       Kirk        Kirk Cousins     20         2
# 235     314           Smith       Alex          Alex Smith     20         2
# 240     319         Bortles      Blake       Blake Bortles     21         1
# 289     378     Fitzpatrick       Ryan    Ryan Fitzpatrick     25         3
# 290     379           Hoyer      Brian         Brian Hoyer     25         4
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 15        523          67       QB  GBP  ...    NaN  NaN NaN  NaN  347.0
# 40        452          70       QB  SEA  ...    NaN  NaN NaN  NaN  329.0
# 56        515          68       QB  NOS  ...    NaN  NaN NaN  NaN  428.0
# 60        587          72       QB  PIT  ...    NaN  NaN NaN  NaN  319.0
# 66        510          71       QB  ATL  ...    NaN  NaN NaN  NaN  407.0
# 71        521          72       QB  NEP  ...    NaN  NaN NaN  NaN  402.0
# 73        501          72       QB  CAR  ...    NaN  NaN NaN  NaN  296.0
# 78        522          71       QB  DET  ...    NaN  NaN NaN  NaN  398.0
# 85        526          73       QB  MIA  ...    NaN  NaN NaN  NaN  363.0
# 107       507          73       QB  NYG  ...    NaN  NaN NaN  NaN  387.0
# 111       602          72       QB  SDC  ...    NaN  NaN NaN  NaN  437.0
# 112       525          79       QB  PHI  ...    NaN  NaN NaN  NaN  346.0
# 120       892          81       QB  TBB  ...    NaN  NaN NaN  NaN  312.0
# 130       890          78       QB  TEN  ...    NaN  NaN NaN  NaN  230.0
# 132       479          72       QB  MIN  ...    NaN  NaN NaN  NaN  292.0
# 177       594          67       QB  BAL  ...    NaN  NaN NaN  NaN  266.0
# 181       528          68       QB  ARI  ...    NaN  NaN NaN  NaN  342.0
# 210       472          53       QB  OAK  ...    NaN  NaN NaN  NaN  350.0
# 212       510          56       QB  CHI  ...    NaN  NaN NaN  NaN  311.0
# 214       530          53       QB  CIN  ...    NaN  NaN NaN  NaN  255.0
# 222       674          20       QB  BUF  ...    NaN  NaN NaN  NaN  242.0
# 234       792          13       QB  WAS  ...    NaN  NaN NaN  NaN  379.0
# 235       584          42       QB  KCC  ...    NaN  NaN NaN  NaN  307.0
# 240       524          41       QB  JAC  ...    NaN  NaN NaN  NaN  355.0
# 289       672          14       QB  NYJ  ...    NaN  NaN NaN  NaN  335.0
# 290       815          10       QB  HOU  ...    NaN  NaN NaN  NaN  224.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 15    8.0   46.0   58.0                9.0                7.0
# 40    8.0   45.0  103.0                3.0                3.0
# 56   11.0   31.0   24.0                8.0                6.0
# 60   16.0   20.0   15.0               30.0               20.0
# 66   16.0   30.0   36.0               27.0               19.0
# 71    7.0   38.0   34.0                2.0                2.0
# 73   10.0   33.0  132.0                1.0                1.0
# 78   13.0   44.0   44.0               11.0                9.0
# 85   12.0   45.0   32.0               24.0               17.0
# 107  14.0   27.0   20.0               12.0               10.0
# 111  13.0   40.0   17.0               15.0               12.0
# 112  14.0   28.0   26.0               50.0               24.0
# 120  15.0   27.0   54.0               18.0               13.0
# 130  10.0   38.0   34.0               41.0               22.0
# 132   9.0   44.0   44.0               45.0               23.0
# 177  12.0   16.0   13.0               78.5               26.0
# 181  11.0   25.0   25.0                6.0                5.0
# 210  13.0   31.0   33.0               19.0               14.0
# 212  11.0   29.0   38.0               31.0               21.0
# 214   7.0   20.0   57.0               26.0               18.0
# 222   6.0   36.0  104.0               21.0               15.0
# 234  11.0   26.0   26.0               10.0                8.0
# 235   7.0   45.0   84.0               22.0               16.0
# 240  18.0   51.0   52.0                4.0                4.0
# 289  15.0   19.0   60.0               13.0               11.0
# 290   7.0   25.0   15.0               71.0               25.0
#
# [26 rows x 45 columns]

# %%
rb2 = rb[(rb['FantasyPointsRank'] <= 50)]
wr2 = wr[(wr['FantasyPointsRank'] <= 50)]
te2 = te[(te['FantasyPointsRank'] <= 50)]
qb2 = qb[(qb['FantasyPointsRank'] <= 50)]
rb2
# Out:
#      Rank_x  Player_x Unnamed: 2        Player_Name  Round  Min Pick  \
# 4         5  Peterson     Adrian    Adrian Peterson      1         1
# 28       29    Miller      Lamar       Lamar Miller      3         1
# 30       31    Gurley       Todd        Todd Gurley      3         1
# 67       70    Martin       Doug        Doug Martin      6         1
# 106     130   Freeman    Devonta    Devonta Freeman      9         1
# 143     181  Woodhead      Danny     Danny Woodhead     12         2
# 211     276  Williams   DeAngelo  DeAngelo Williams     18         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 4         499          68       RB  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 28        475          72       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 30        884          96       RB  STL  ...    NaN  NaN NaN  NaN NaN  NaN
# 67        516          75       RB  TBB  ...    NaN  NaN NaN  NaN NaN  NaN
# 106       487          70       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 143       487          71       RB  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
# 211       667          60       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 4      NaN    NaN               25.0                2.0
# 28     NaN    NaN               42.0                5.0
# 30     NaN    NaN               47.0                7.0
# 67     NaN    NaN               35.0                3.0
# 106    NaN    NaN               16.0                1.0
# 143    NaN    NaN               43.0                6.0
# 211    NaN    NaN               38.0                4.0
#
# [7 rows x 45 columns]

# %%
wr2
# Out:
#      Rank_x    Player_x Unnamed: 2       Player_Name  Round  Min Pick  \
# 1         2       Brown    Antonio     Antonio Brown      1         1
# 6         7       Jones      Julio       Julio Jones      1         1
# 8         9      Thomas  Demaryius  Demaryius Thomas      1         1
# 12       13     Johnson     Calvin    Calvin Johnson      2         1
# 14       15       Green       A.J.        A.J. Green      2         1
# 17       18     Beckham      Odell     Odell Beckham      2         1
# 26       27       Cooks    Brandin     Brandin Cooks      3         1
# 29       30     Hopkins    DeAndre   DeAndre Hopkins      3         1
# 52       54      Maclin     Jeremy     Jeremy Maclin      5         1
# 53       55      Landry     Jarvis     Jarvis Landry      5         1
# 57       59    Marshall    Brandon  Brandon Marshall      5         1
# 63       66    Robinson      Allen    Allen Robinson      6         1
# 82       94  Fitzgerald      Larry  Larry Fitzgerald      7         2
# 101     126      Decker       Eric       Eric Decker      9         2
# 216     286     Baldwin       Doug      Doug Baldwin     19         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 1         439          68       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 6         424          68       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 8         359          69       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 12        547          68       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
# 14        387          70       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 17        466          67       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN
# 26        462          72       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 29        421          73       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 52        469          74       WR  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 53        472          75       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 57        307          73       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
# 63        415          76       WR  JAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 82        491          77       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 101       464          72       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
# 216       467          56       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_wr
# 1      NaN    NaN                5.0                1.0
# 6      NaN    NaN                7.0                2.0
# 8      NaN    NaN               36.5               11.5
# 12     NaN    NaN               34.0               10.0
# 14     NaN    NaN               28.0                7.0
# 17     NaN    NaN               20.0                5.0
# 26     NaN    NaN               40.0               14.0
# 29     NaN    NaN               17.0                4.0
# 52     NaN    NaN               46.0               15.0
# 53     NaN    NaN               36.5               11.5
# 57     NaN    NaN               14.0                3.0
# 63     NaN    NaN               23.0                6.0
# 82     NaN    NaN               32.0                9.0
# 101    NaN    NaN               39.0               13.0
# 216    NaN    NaN               29.0                8.0
#
# [15 rows x 45 columns]

# %%
te2
# Out:
#      Rank_x    Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 7         8  Gronkowski        Rob  Rob Gronkowski      1         1       351
# 127     160      Walker    Delanie  Delanie Walker     11         2       404
# 220     294        Reed     Jordan     Jordan Reed     19         3       506
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 7            69       TE  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 127          72       TE  TEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 220          47       TE  WAS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_te
# 7      NaN               33.0                1.0
# 127    NaN               49.0                3.0
# 220    NaN               44.0                2.0
#
# [3 rows x 45 columns]

# %%
qb2
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 15       16         Rodgers      Aaron       Aaron Rodgers      2         1
# 40       42          Wilson    Russell      Russell Wilson      4         1
# 56       58           Brees       Drew          Drew Brees      5         1
# 60       63  Roethlisberger        Ben  Ben Roethlisberger      6         1
# 66       69            Ryan       Matt           Matt Ryan      6         1
# 71       77           Brady        Tom           Tom Brady      6         1
# 73       79          Newton        Cam          Cam Newton      7         1
# 78       85        Stafford    Matthew    Matthew Stafford      7         1
# 85       99       Tannehill       Ryan      Ryan Tannehill      8         1
# 107     131         Manning        Eli         Eli Manning      9         1
# 111     137          Rivers     Philip       Philip Rivers     10         1
# 112     138        Bradford        Sam        Sam Bradford     10         1
# 120     148         Winston     Jameis      Jameis Winston     11         1
# 130     164         Mariota     Marcus      Marcus Mariota     11         1
# 132     166     Bridgewater      Teddy   Teddy Bridgewater     12         1
# 181     237          Palmer     Carson       Carson Palmer     16         1
# 210     275            Carr      Derek          Derek Carr     18         1
# 212     277          Cutler        Jay          Jay Cutler     18         1
# 214     281          Dalton       Andy         Andy Dalton     18         1
# 222     296          Taylor      Tyrod        Tyrod Taylor     19         1
# 234     313         Cousins       Kirk        Kirk Cousins     20         2
# 235     314           Smith       Alex          Alex Smith     20         2
# 240     319         Bortles      Blake       Blake Bortles     21         1
# 289     378     Fitzpatrick       Ryan    Ryan Fitzpatrick     25         3
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 15        523          67       QB  GBP  ...    NaN  NaN NaN  NaN  347.0
# 40        452          70       QB  SEA  ...    NaN  NaN NaN  NaN  329.0
# 56        515          68       QB  NOS  ...    NaN  NaN NaN  NaN  428.0
# 60        587          72       QB  PIT  ...    NaN  NaN NaN  NaN  319.0
# 66        510          71       QB  ATL  ...    NaN  NaN NaN  NaN  407.0
# 71        521          72       QB  NEP  ...    NaN  NaN NaN  NaN  402.0
# 73        501          72       QB  CAR  ...    NaN  NaN NaN  NaN  296.0
# 78        522          71       QB  DET  ...    NaN  NaN NaN  NaN  398.0
# 85        526          73       QB  MIA  ...    NaN  NaN NaN  NaN  363.0
# 107       507          73       QB  NYG  ...    NaN  NaN NaN  NaN  387.0
# 111       602          72       QB  SDC  ...    NaN  NaN NaN  NaN  437.0
# 112       525          79       QB  PHI  ...    NaN  NaN NaN  NaN  346.0
# 120       892          81       QB  TBB  ...    NaN  NaN NaN  NaN  312.0
# 130       890          78       QB  TEN  ...    NaN  NaN NaN  NaN  230.0
# 132       479          72       QB  MIN  ...    NaN  NaN NaN  NaN  292.0
# 181       528          68       QB  ARI  ...    NaN  NaN NaN  NaN  342.0
# 210       472          53       QB  OAK  ...    NaN  NaN NaN  NaN  350.0
# 212       510          56       QB  CHI  ...    NaN  NaN NaN  NaN  311.0
# 214       530          53       QB  CIN  ...    NaN  NaN NaN  NaN  255.0
# 222       674          20       QB  BUF  ...    NaN  NaN NaN  NaN  242.0
# 234       792          13       QB  WAS  ...    NaN  NaN NaN  NaN  379.0
# 235       584          42       QB  KCC  ...    NaN  NaN NaN  NaN  307.0
# 240       524          41       QB  JAC  ...    NaN  NaN NaN  NaN  355.0
# 289       672          14       QB  NYJ  ...    NaN  NaN NaN  NaN  335.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 15    8.0   46.0   58.0                9.0                7.0
# 40    8.0   45.0  103.0                3.0                3.0
# 56   11.0   31.0   24.0                8.0                6.0
# 60   16.0   20.0   15.0               30.0               20.0
# 66   16.0   30.0   36.0               27.0               19.0
# 71    7.0   38.0   34.0                2.0                2.0
# 73   10.0   33.0  132.0                1.0                1.0
# 78   13.0   44.0   44.0               11.0                9.0
# 85   12.0   45.0   32.0               24.0               17.0
# 107  14.0   27.0   20.0               12.0               10.0
# 111  13.0   40.0   17.0               15.0               12.0
# 112  14.0   28.0   26.0               50.0               24.0
# 120  15.0   27.0   54.0               18.0               13.0
# 130  10.0   38.0   34.0               41.0               22.0
# 132   9.0   44.0   44.0               45.0               23.0
# 181  11.0   25.0   25.0                6.0                5.0
# 210  13.0   31.0   33.0               19.0               14.0
# 212  11.0   29.0   38.0               31.0               21.0
# 214   7.0   20.0   57.0               26.0               18.0
# 222   6.0   36.0  104.0               21.0               15.0
# 234  11.0   26.0   26.0               10.0                8.0
# 235   7.0   45.0   84.0               22.0               16.0
# 240  18.0   51.0   52.0                4.0                4.0
# 289  15.0   19.0   60.0               13.0               11.0
#
# [24 rows x 45 columns]

# %%
rb3 = rb[(rb['FantasyPointsRank'] <= 25)]
wr3 = wr[(wr['FantasyPointsRank'] <= 25)]
te3 = te[(te['FantasyPointsRank'] <= 25)]
qb3 = qb[(qb['FantasyPointsRank'] <= 25)]
rb3
# Out:
#      Rank_x  Player_x Unnamed: 2      Player_Name  Round  Min Pick  Max Pick  \
# 4         5  Peterson     Adrian  Adrian Peterson      1         1       499
# 106     130   Freeman    Devonta  Devonta Freeman      9         1       487
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 4            68       RB  MIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 106          70       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_rb
# 4      NaN               25.0                2.0
# 106    NaN               16.0                1.0
#
# [2 rows x 45 columns]

# %%
wr3
# Out:
#     Rank_x  Player_x Unnamed: 2       Player_Name  Round  Min Pick  Max Pick  \
# 1        2     Brown    Antonio     Antonio Brown      1         1       439
# 6        7     Jones      Julio       Julio Jones      1         1       424
# 17      18   Beckham      Odell     Odell Beckham      2         1       466
# 29      30   Hopkins    DeAndre   DeAndre Hopkins      3         1       421
# 57      59  Marshall    Brandon  Brandon Marshall      5         1       307
# 63      66  Robinson      Allen    Allen Robinson      6         1       415
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 1           68       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 6           68       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 17          67       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 29          73       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 57          73       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 63          76       WR  JAC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_wr
# 1                 5.0                1.0
# 6                 7.0                2.0
# 17               20.0                5.0
# 29               17.0                4.0
# 57               14.0                3.0
# 63               23.0                6.0
#
# [6 rows x 45 columns]

# %%
wr3['FantasyPointsRank'].sum()
# Out:
# 86.0

# %%
te3
# Out:
# Empty DataFrame
# Columns: [Rank_x, Player_x, Unnamed: 2, Player_Name, Round, Min Pick, Max Pick, % Selected, Position, Team, PositionRank, Rank_y, Player_y, ATT, YDS, Y/A, LG, 20+, TD, REC, TGT, YDS.1, Y/R, TD.1, FL, G, FPTS, FPTS/G, OWN, FG, FGA, PCT, 1-19, 20-29, 30-39, 40-49, 50+, XPT, XPA, CMP, INT, SACKS, ATT.1, FantasyPointsRank, performance_fp_te]
# Index: []
#
# [0 rows x 45 columns]

# %%
qb3
# Out:
#      Rank_x     Player_x Unnamed: 2       Player_Name  Round  Min Pick  \
# 15       16      Rodgers      Aaron     Aaron Rodgers      2         1
# 40       42       Wilson    Russell    Russell Wilson      4         1
# 56       58        Brees       Drew        Drew Brees      5         1
# 71       77        Brady        Tom         Tom Brady      6         1
# 73       79       Newton        Cam        Cam Newton      7         1
# 78       85     Stafford    Matthew  Matthew Stafford      7         1
# 85       99    Tannehill       Ryan    Ryan Tannehill      8         1
# 107     131      Manning        Eli       Eli Manning      9         1
# 111     137       Rivers     Philip     Philip Rivers     10         1
# 120     148      Winston     Jameis    Jameis Winston     11         1
# 181     237       Palmer     Carson     Carson Palmer     16         1
# 210     275         Carr      Derek        Derek Carr     18         1
# 222     296       Taylor      Tyrod      Tyrod Taylor     19         1
# 234     313      Cousins       Kirk      Kirk Cousins     20         2
# 235     314        Smith       Alex        Alex Smith     20         2
# 240     319      Bortles      Blake     Blake Bortles     21         1
# 289     378  Fitzpatrick       Ryan  Ryan Fitzpatrick     25         3
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 15        523          67       QB  GBP  ...    NaN  NaN NaN  NaN  347.0
# 40        452          70       QB  SEA  ...    NaN  NaN NaN  NaN  329.0
# 56        515          68       QB  NOS  ...    NaN  NaN NaN  NaN  428.0
# 71        521          72       QB  NEP  ...    NaN  NaN NaN  NaN  402.0
# 73        501          72       QB  CAR  ...    NaN  NaN NaN  NaN  296.0
# 78        522          71       QB  DET  ...    NaN  NaN NaN  NaN  398.0
# 85        526          73       QB  MIA  ...    NaN  NaN NaN  NaN  363.0
# 107       507          73       QB  NYG  ...    NaN  NaN NaN  NaN  387.0
# 111       602          72       QB  SDC  ...    NaN  NaN NaN  NaN  437.0
# 120       892          81       QB  TBB  ...    NaN  NaN NaN  NaN  312.0
# 181       528          68       QB  ARI  ...    NaN  NaN NaN  NaN  342.0
# 210       472          53       QB  OAK  ...    NaN  NaN NaN  NaN  350.0
# 222       674          20       QB  BUF  ...    NaN  NaN NaN  NaN  242.0
# 234       792          13       QB  WAS  ...    NaN  NaN NaN  NaN  379.0
# 235       584          42       QB  KCC  ...    NaN  NaN NaN  NaN  307.0
# 240       524          41       QB  JAC  ...    NaN  NaN NaN  NaN  355.0
# 289       672          14       QB  NYJ  ...    NaN  NaN NaN  NaN  335.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 15    8.0   46.0   58.0                9.0                7.0
# 40    8.0   45.0  103.0                3.0                3.0
# 56   11.0   31.0   24.0                8.0                6.0
# 71    7.0   38.0   34.0                2.0                2.0
# 73   10.0   33.0  132.0                1.0                1.0
# 78   13.0   44.0   44.0               11.0                9.0
# 85   12.0   45.0   32.0               24.0               17.0
# 107  14.0   27.0   20.0               12.0               10.0
# 111  13.0   40.0   17.0               15.0               12.0
# 120  15.0   27.0   54.0               18.0               13.0
# 181  11.0   25.0   25.0                6.0                5.0
# 210  13.0   31.0   33.0               19.0               14.0
# 222   6.0   36.0  104.0               21.0               15.0
# 234  11.0   26.0   26.0               10.0                8.0
# 235   7.0   45.0   84.0               22.0               16.0
# 240  18.0   51.0   52.0                4.0                4.0
# 289  15.0   19.0   60.0               13.0               11.0
#
# [17 rows x 45 columns]

# %%
rb_25_50 = rb2[(rb2['FantasyPointsRank'] >= 25)]
wr_25_50 = wr2[(wr2['FantasyPointsRank'] >= 25)]
te_25_50 = te2[(te2['FantasyPointsRank'] >= 25)]
qb_25_50 = qb2[(qb2['FantasyPointsRank'] >= 25)]
rb_25_50
# Out:
#      Rank_x  Player_x Unnamed: 2        Player_Name  Round  Min Pick  \
# 4         5  Peterson     Adrian    Adrian Peterson      1         1
# 28       29    Miller      Lamar       Lamar Miller      3         1
# 30       31    Gurley       Todd        Todd Gurley      3         1
# 67       70    Martin       Doug        Doug Martin      6         1
# 143     181  Woodhead      Danny     Danny Woodhead     12         2
# 211     276  Williams   DeAngelo  DeAngelo Williams     18         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 4         499          68       RB  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 28        475          72       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 30        884          96       RB  STL  ...    NaN  NaN NaN  NaN NaN  NaN
# 67        516          75       RB  TBB  ...    NaN  NaN NaN  NaN NaN  NaN
# 143       487          71       RB  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
# 211       667          60       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 4      NaN    NaN               25.0                2.0
# 28     NaN    NaN               42.0                5.0
# 30     NaN    NaN               47.0                7.0
# 67     NaN    NaN               35.0                3.0
# 143    NaN    NaN               43.0                6.0
# 211    NaN    NaN               38.0                4.0
#
# [6 rows x 45 columns]

# %%
rb_25_50['FantasyPointsRank'].sum()
# Out:
# 230.0

# %%
wr_25_50
# Out:
#      Rank_x    Player_x Unnamed: 2       Player_Name  Round  Min Pick  \
# 8         9      Thomas  Demaryius  Demaryius Thomas      1         1
# 12       13     Johnson     Calvin    Calvin Johnson      2         1
# 14       15       Green       A.J.        A.J. Green      2         1
# 26       27       Cooks    Brandin     Brandin Cooks      3         1
# 52       54      Maclin     Jeremy     Jeremy Maclin      5         1
# 53       55      Landry     Jarvis     Jarvis Landry      5         1
# 82       94  Fitzgerald      Larry  Larry Fitzgerald      7         2
# 101     126      Decker       Eric       Eric Decker      9         2
# 216     286     Baldwin       Doug      Doug Baldwin     19         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 8         359          69       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 12        547          68       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
# 14        387          70       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 26        462          72       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 52        469          74       WR  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 53        472          75       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 82        491          77       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 101       464          72       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
# 216       467          56       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_wr
# 8      NaN    NaN               36.5               11.5
# 12     NaN    NaN               34.0               10.0
# 14     NaN    NaN               28.0                7.0
# 26     NaN    NaN               40.0               14.0
# 52     NaN    NaN               46.0               15.0
# 53     NaN    NaN               36.5               11.5
# 82     NaN    NaN               32.0                9.0
# 101    NaN    NaN               39.0               13.0
# 216    NaN    NaN               29.0                8.0
#
# [9 rows x 45 columns]

# %%
wr_25_50['FantasyPointsRank'].sum()
# Out:
# 321.0
