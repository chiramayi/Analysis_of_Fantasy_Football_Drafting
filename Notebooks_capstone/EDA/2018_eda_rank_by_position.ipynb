# %%
import pandas as pd

import gc # To collect garbage values generated during running

import matplotlib.pyplot as plt

import numpy as np

import seaborn as sns

# %%
d = pd.read_csv('2018_cleaned_with_rounds.csv')

# %%
d.head(60)
# Out:
#     Rank_x        Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 0        1            Bell    Le'Veon         Le'Veon Bell      1         1
# 1        2         Elliott    Ezekiel      Ezekiel Elliott      1         1
# 2        3         Johnson      David        David Johnson      1         1
# 3        4         Barkley     Saquon       Saquon Barkley      1         1
# 4        5           Brown    Antonio        Antonio Brown      1         1
# 5        6          Gurley       Todd          Todd Gurley      1         1
# 6        7          Kamara      Alvin         Alvin Kamara      1         1
# 7        8         Hopkins    DeAndre      DeAndre Hopkins      1         1
# 8        9       Fournette    Leonard    Leonard Fournette      1         1
# 9       10         Beckham      Odell        Odell Beckham      1         1
# 10      11            Hunt     Kareem          Kareem Hunt      1         1
# ...

# %%
rb = d.loc[d['Position'] == 'RB']
wr = d.loc[d['Position'] == 'WR']

# %%
wr['performance_fp_wr'] = wr['FantasyPointsRank'].rank(ascending = True)
rb['performance_fp_rb'] = rb['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-8-ea88c15edb18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wr['performance_fp_wr'] = wr['FantasyPointsRank'].rank(ascending = True)
# <ipython-input-8-ea88c15edb18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rb['performance_fp_rb'] = rb['FantasyPointsRank'].rank(ascending = True)

# %%
te = d.loc[d['Position'] == 'TE']
te['performance_fp_te'] = te['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-10-c576e4e6ce8f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['performance_fp_te'] = te['FantasyPointsRank'].rank(ascending = True)

# %%
qb = d.loc[d['Position'] == 'QB']
qb['performance_fp_qb'] = qb['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-12-4882867569a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qb['performance_fp_qb'] = qb['FantasyPointsRank'].rank(ascending = True)

# %%
k = d.loc[d['Position'] == 'PK']
k['performance_fp_qb'] = k['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-14-d0b0a0dfd751>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['performance_fp_qb'] = k['FantasyPointsRank'].rank(ascending = True)

# %%
Def = d.loc[d['Position'] == 'Def']
Def['performance_fp_qb'] = Def['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-15-0fe04eefa7f5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Def['performance_fp_qb'] = Def['FantasyPointsRank'].rank(ascending = True)

# %%
rb_50 = rb.head(50)
after_rb = rb_50[(rb_50['FantasyPointsRank'] <= 70)]
after_rb.head(50)
# Out:
#      Rank_x   Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 1         2    Elliott    Ezekiel      Ezekiel Elliott      1         1
# 2         3    Johnson      David        David Johnson      1         1
# 3         4    Barkley     Saquon       Saquon Barkley      1         1
# 5         6     Gurley       Todd          Todd Gurley      1         1
# 6         7     Kamara      Alvin         Alvin Kamara      1         1
# 10       11       Hunt     Kareem          Kareem Hunt      1         1
# 11       12     Gordon     Melvin        Melvin Gordon      1         1
# 15       16  McCaffrey  Christian  Christian McCaffrey      2         1
# 21       22      Mixon        Joe            Joe Mixon      2         1
# 40       41      Drake     Kenyan         Kenyan Drake      4         1
# 42       43      Henry    Derrick        Derrick Henry      4         1
# 62       65    Coleman      Tevin        Tevin Coleman      6         1
# ...

# %%
wr_50 = wr.head(50)
after_wr = wr_50[(wr_50['FantasyPointsRank'] <= 70)]
after_wr.head(50)
# Out:
#     Rank_x        Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 4        5           Brown    Antonio        Antonio Brown      1         1
# 7        8         Hopkins    DeAndre      DeAndre Hopkins      1         1
# 9       10         Beckham      Odell        Odell Beckham      1         1
# 13      14           Jones      Julio          Julio Jones      2         1
# 14      15          Thomas    Michael       Michael Thomas      2         1
# 16      17           Adams    Davante        Davante Adams      2         1
# 17      18           Allen     Keenan         Keenan Allen      2         1
# 20      21           Evans       Mike           Mike Evans      2         1
# 22      23            Hill     Tyreek          Tyreek Hill      2         1
# 25      26           Diggs     Stefon         Stefon Diggs      3         1
# 26      27          Hilton       T.Y.          T.Y. Hilton      3         1
# ...

# %%
te_50 = te.head(50)
after_te = te_50[(te_50['FantasyPointsRank'] <= 70)]
after_te.head(30)
# Out:
#      Rank_x Player_x Unnamed: 2    Player_Name  Round  Min Pick  Max Pick  \
# 23       24    Kelce     Travis   Travis Kelce      2         1       205
# 32       33     Ertz       Zach      Zach Ertz      3         1       248
# 139     169   Kittle     George  George Kittle     12         1       429
# 183     227    Ebron       Eric     Eric Ebron     16         1       519
#
#      % Selected Position Team  ...  SACKS  ATT.1 SACK  FR  FF  DEF TD  SFTY  \
# 23           72       TE  KCC  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 32           72       TE  PHI  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 139          63       TE  SFO  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 183          46       TE  IND  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
#
#      SPC TD  FantasyPointsRank  performance_fp_te
# 23      NaN               30.0                1.0
# 32      NaN               37.0                2.0
# 139     NaN               44.0                3.0
# ...

# %%
qb_50 = qb.head(50)
after_qb = qb_50[(qb_50['FantasyPointsRank'] <= 70)]
after_qb.head(30)
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 18       19         Rodgers      Aaron       Aaron Rodgers      2         1
# 29       30          Watson    Deshaun      Deshaun Watson      3         1
# 35       36          Wilson    Russell      Russell Wilson      3         1
# 37       38           Brady        Tom           Tom Brady      4         1
# 45       46          Newton        Cam          Cam Newton      4         1
# 49       50           Brees       Drew          Drew Brees      5         1
# 55       56           Wentz     Carson        Carson Wentz      5         1
# 64       68         Cousins       Kirk        Kirk Cousins      6         1
# 67       71            Luck     Andrew         Andrew Luck      6         1
# 74       83        Stafford    Matthew    Matthew Stafford      7         1
# 77       88          Rivers     Philip       Philip Rivers      7         1
# ...

# %%
rb1 = rb[(rb['FantasyPointsRank'] <= 100)]
wr1 = wr[(wr['FantasyPointsRank'] <= 100)]
te1 = te[(te['FantasyPointsRank'] <= 100)]
qb1 = qb[(qb['FantasyPointsRank'] <= 100)]
rb1
# Out:
#      Rank_x   Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 1         2    Elliott    Ezekiel      Ezekiel Elliott      1         1
# 2         3    Johnson      David        David Johnson      1         1
# 3         4    Barkley     Saquon       Saquon Barkley      1         1
# 5         6     Gurley       Todd          Todd Gurley      1         1
# 6         7     Kamara      Alvin         Alvin Kamara      1         1
# 10       11       Hunt     Kareem          Kareem Hunt      1         1
# 11       12     Gordon     Melvin        Melvin Gordon      1         1
# 15       16  McCaffrey  Christian  Christian McCaffrey      2         1
# 21       22      Mixon        Joe            Joe Mixon      2         1
# 24       25     Howard     Jordan        Jordan Howard      3         1
# 40       41      Drake     Kenyan         Kenyan Drake      4         1
# 42       43      Henry    Derrick        Derrick Henry      4         1
# ...

# %%
wr1
# Out:
#      Rank_x        Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 4         5           Brown    Antonio        Antonio Brown      1         1
# 7         8         Hopkins    DeAndre      DeAndre Hopkins      1         1
# 9        10         Beckham      Odell        Odell Beckham      1         1
# 13       14           Jones      Julio          Julio Jones      2         1
# 14       15          Thomas    Michael       Michael Thomas      2         1
# 16       17           Adams    Davante        Davante Adams      2         1
# 17       18           Allen     Keenan         Keenan Allen      2         1
# 20       21           Evans       Mike           Mike Evans      2         1
# 22       23            Hill     Tyreek          Tyreek Hill      2         1
# 25       26           Diggs     Stefon         Stefon Diggs      3         1
# 26       27          Hilton       T.Y.          T.Y. Hilton      3         1
# ...

# %%
te1
# Out:
#      Rank_x Player_x Unnamed: 2    Player_Name  Round  Min Pick  Max Pick  \
# 23       24    Kelce     Travis   Travis Kelce      2         1       205
# 32       33     Ertz       Zach      Zach Ertz      3         1       248
# 139     169   Kittle     George  George Kittle     12         1       429
# 183     227    Ebron       Eric     Eric Ebron     16         1       519
# 188     236     Cook      Jared     Jared Cook     16         3       557
#
#      % Selected Position Team  ...  SACKS  ATT.1 SACK  FR  FF  DEF TD  SFTY  \
# 23           72       TE  KCC  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 32           72       TE  PHI  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 139          63       TE  SFO  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 183          46       TE  IND  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 188          48       TE  OAK  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
#
#      SPC TD  FantasyPointsRank  performance_fp_te
# ...

# %%
qb1
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 18       19         Rodgers      Aaron       Aaron Rodgers      2         1
# 29       30          Watson    Deshaun      Deshaun Watson      3         1
# 35       36          Wilson    Russell      Russell Wilson      3         1
# 37       38           Brady        Tom           Tom Brady      4         1
# 45       46          Newton        Cam          Cam Newton      4         1
# 49       50           Brees       Drew          Drew Brees      5         1
# 55       56           Wentz     Carson        Carson Wentz      5         1
# 64       68         Cousins       Kirk        Kirk Cousins      6         1
# 67       71            Luck     Andrew         Andrew Luck      6         1
# 74       83        Stafford    Matthew    Matthew Stafford      7         1
# 77       88          Rivers     Philip       Philip Rivers      7         1
# ...

# %%
rb2 = rb[(rb['FantasyPointsRank'] <= 50)]
wr2 = wr[(wr['FantasyPointsRank'] <= 50)]
te2 = te[(te['FantasyPointsRank'] <= 50)]
qb2 = qb[(qb['FantasyPointsRank'] <= 50)]
rb2
# Out:
#      Rank_x   Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 1         2    Elliott    Ezekiel      Ezekiel Elliott      1         1
# 2         3    Johnson      David        David Johnson      1         1
# 3         4    Barkley     Saquon       Saquon Barkley      1         1
# 5         6     Gurley       Todd          Todd Gurley      1         1
# 6         7     Kamara      Alvin         Alvin Kamara      1         1
# 10       11       Hunt     Kareem          Kareem Hunt      1         1
# 11       12     Gordon     Melvin        Melvin Gordon      1         1
# 15       16  McCaffrey  Christian  Christian McCaffrey      2         1
# 21       22      Mixon        Joe            Joe Mixon      2         1
# 130     156      White      James          James White     11         2
# 186     231     Conner      James         James Conner     16         1
#
#      Max Pick  % Selected Position Team  ...  SACKS  ATT.1 SACK  FR  FF  \
# ...

# %%
wr2
# Out:
#     Rank_x        Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 4        5           Brown    Antonio        Antonio Brown      1         1
# 7        8         Hopkins    DeAndre      DeAndre Hopkins      1         1
# 13      14           Jones      Julio          Julio Jones      2         1
# 14      15          Thomas    Michael       Michael Thomas      2         1
# 16      17           Adams    Davante        Davante Adams      2         1
# 17      18           Allen     Keenan         Keenan Allen      2         1
# 20      21           Evans       Mike           Mike Evans      2         1
# 22      23            Hill     Tyreek          Tyreek Hill      2         1
# 25      26           Diggs     Stefon         Stefon Diggs      3         1
# 26      27          Hilton       T.Y.          T.Y. Hilton      3         1
# 31      32         Thielen       Adam         Adam Thielen      3         1
# ...

# %%
te2
# Out:
#      Rank_x Player_x Unnamed: 2    Player_Name  Round  Min Pick  Max Pick  \
# 23       24    Kelce     Travis   Travis Kelce      2         1       205
# 32       33     Ertz       Zach      Zach Ertz      3         1       248
# 139     169   Kittle     George  George Kittle     12         1       429
#
#      % Selected Position Team  ...  SACKS  ATT.1 SACK  FR  FF  DEF TD  SFTY  \
# 23           72       TE  KCC  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 32           72       TE  PHI  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 139          63       TE  SFO  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
#
#      SPC TD  FantasyPointsRank  performance_fp_te
# 23      NaN               30.0                1.0
# 32      NaN               37.0                2.0
# 139     NaN               44.0                3.0
#
# [3 rows x 51 columns]

# %%
qb2
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 18       19         Rodgers      Aaron       Aaron Rodgers      2         1
# 29       30          Watson    Deshaun      Deshaun Watson      3         1
# 35       36          Wilson    Russell      Russell Wilson      3         1
# 37       38           Brady        Tom           Tom Brady      4         1
# 45       46          Newton        Cam          Cam Newton      4         1
# 49       50           Brees       Drew          Drew Brees      5         1
# 64       68         Cousins       Kirk        Kirk Cousins      6         1
# 67       71            Luck     Andrew         Andrew Luck      6         1
# 74       83        Stafford    Matthew    Matthew Stafford      7         1
# 77       88          Rivers     Philip       Philip Rivers      7         1
# 79       91  Roethlisberger        Ben  Ben Roethlisberger      7         1
# ...

# %%
rb3 = rb[(rb['FantasyPointsRank'] <= 25)]
wr3 = wr[(wr['FantasyPointsRank'] <= 25)]
te3 = te[(te['FantasyPointsRank'] <= 25)]
qb3 = qb[(qb['FantasyPointsRank'] <= 25)]
rb3
# Out:
#     Rank_x   Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 1        2    Elliott    Ezekiel      Ezekiel Elliott      1         1
# 3        4    Barkley     Saquon       Saquon Barkley      1         1
# 5        6     Gurley       Todd          Todd Gurley      1         1
# 6        7     Kamara      Alvin         Alvin Kamara      1         1
# 15      16  McCaffrey  Christian  Christian McCaffrey      2         1
#
#     Max Pick  % Selected Position Team  ...  SACKS  ATT.1 SACK  FR  FF  \
# 1        186          67       RB  DAL  ...    NaN    NaN  NaN NaN NaN
# 3        451          95       RB  NYG  ...    NaN    NaN  NaN NaN NaN
# 5        360          68       RB  LAR  ...    NaN    NaN  NaN NaN NaN
# 6        208          63       RB  NOS  ...    NaN    NaN  NaN NaN NaN
# 15       156          70       RB  CAR  ...    NaN    NaN  NaN NaN NaN
#
#     DEF TD  SFTY  SPC TD  FantasyPointsRank  performance_fp_rb
# ...

# %%
wr3
# Out:
#     Rank_x Player_x Unnamed: 2      Player_Name  Round  Min Pick  Max Pick  \
# 4        5    Brown    Antonio    Antonio Brown      1         1       222
# 7        8  Hopkins    DeAndre  DeAndre Hopkins      1         1       155
# 13      14    Jones      Julio      Julio Jones      2         1       190
# 16      17    Adams    Davante    Davante Adams      2         1       175
# 22      23     Hill     Tyreek      Tyreek Hill      2         1       189
#
#     % Selected Position Team  ...  SACKS  ATT.1 SACK  FR  FF  DEF TD  SFTY  \
# 4           67       WR  PIT  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 7           67       WR  HOU  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 13          69       WR  ATL  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 16          69       WR  GBP  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 22          71       WR  KCC  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
#
#     SPC TD  FantasyPointsRank  performance_fp_wr
# ...

# %%
wr3['FantasyPointsRank'].sum()
# Out:
# 107.0

# %%
te3
# Out:
# Empty DataFrame
# Columns: [Rank_x, Player_x, Unnamed: 2, Player_Name, Round, Min Pick, Max Pick, % Selected, Position, Team, PositionRank, Rank_y, Player_y, ATT, YDS, Y/A, LG, 20+, TD, REC, TGT, YDS.1, Y/R, TD.1, FL, G, FPTS, FPTS/G, OWN, FG, FGA, PCT, 1-19, 20-29, 30-39, 40-49, 50+, XPT, XPA, CMP, INT, SACKS, ATT.1, SACK, FR, FF, DEF TD, SFTY, SPC TD, FantasyPointsRank, performance_fp_te]
# Index: []
#
# [0 rows x 51 columns]

# %%
qb3
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 18       19         Rodgers      Aaron       Aaron Rodgers      2         1
# 29       30          Watson    Deshaun      Deshaun Watson      3         1
# 35       36          Wilson    Russell      Russell Wilson      3         1
# 37       38           Brady        Tom           Tom Brady      4         1
# 45       46          Newton        Cam          Cam Newton      4         1
# 49       50           Brees       Drew          Drew Brees      5         1
# 64       68         Cousins       Kirk        Kirk Cousins      6         1
# 67       71            Luck     Andrew         Andrew Luck      6         1
# 77       88          Rivers     Philip       Philip Rivers      7         1
# 79       91  Roethlisberger        Ben  Ben Roethlisberger      7         1
# 86      100            Ryan       Matt           Matt Ryan      8         1
# ...

# %%
rb_25_50 = rb2[(rb2['FantasyPointsRank'] >= 25)]
wr_25_50 = wr2[(wr2['FantasyPointsRank'] >= 25)]
te_25_50 = te2[(te2['FantasyPointsRank'] >= 25)]
qb_25_50 = qb2[(qb2['FantasyPointsRank'] >= 25)]
rb_25_50
# Out:
#      Rank_x Player_x Unnamed: 2    Player_Name  Round  Min Pick  Max Pick  \
# 2         3  Johnson      David  David Johnson      1         1       198
# 10       11     Hunt     Kareem    Kareem Hunt      1         1       198
# 11       12   Gordon     Melvin  Melvin Gordon      1         1       194
# 21       22    Mixon        Joe      Joe Mixon      2         1       191
# 130     156    White      James    James White     11         2       406
# 186     231   Conner      James   James Conner     16         1       601
#
#      % Selected Position Team  ...  SACKS  ATT.1 SACK  FR  FF  DEF TD  SFTY  \
# 2            65       RB  ARI  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 10           65       RB  FA*  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 11           68       RB  LAC  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# 21           72       RB  CIN  ...    NaN    NaN  NaN NaN NaN     NaN   NaN
# ...

# %%
rb_25_50['FantasyPointsRank'].sum()
# Out:
# 208.0

# %%
wr_25_50
# Out:
#     Rank_x        Player_x Unnamed: 2          Player_Name  Round  Min Pick  \
# 14      15          Thomas    Michael       Michael Thomas      2         1
# 17      18           Allen     Keenan         Keenan Allen      2         1
# 20      21           Evans       Mike           Mike Evans      2         1
# 25      26           Diggs     Stefon         Stefon Diggs      3         1
# 26      27          Hilton       T.Y.          T.Y. Hilton      3         1
# 31      32         Thielen       Adam         Adam Thielen      3         1
# 33      34  Smith-Schuster       JuJu  JuJu Smith-Schuster      3         1
# 34      35           Cooks    Brandin        Brandin Cooks      3         1
# 72      76           Woods     Robert         Robert Woods      7         2
#
#     Max Pick  % Selected Position Team  ...  SACKS  ATT.1 SACK  FR  FF  \
# 14       161          68       WR  NOS  ...    NaN    NaN  NaN NaN NaN
# ...

# %%
wr_25_50['FantasyPointsRank'].sum()
# Out:
# 340.0
