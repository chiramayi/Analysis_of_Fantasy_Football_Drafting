# %%
import pandas as pd

import gc # To collect garbage values generated during running

import matplotlib.pyplot as plt

import numpy as np

import seaborn as sns

# %%
d = pd.read_csv('2014_cleaned_with_rounds.csv')

# %%
rb = d.loc[d['Position'] == 'RB']
wr = d.loc[d['Position'] == 'WR']

# %%
wr['performance_fp_wr'] = wr['FantasyPointsRank'].rank(ascending = True)
rb['performance_fp_rb'] = rb['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-5-ea88c15edb18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wr['performance_fp_wr'] = wr['FantasyPointsRank'].rank(ascending = True)
# <ipython-input-5-ea88c15edb18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rb['performance_fp_rb'] = rb['FantasyPointsRank'].rank(ascending = True)

# %%
te = d.loc[d['Position'] == 'TE']
te['performance_fp_te'] = te['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-6-c576e4e6ce8f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['performance_fp_te'] = te['FantasyPointsRank'].rank(ascending = True)

# %%
qb = d.loc[d['Position'] == 'QB']
qb['performance_fp_qb'] = qb['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-7-4882867569a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qb['performance_fp_qb'] = qb['FantasyPointsRank'].rank(ascending = True)

# %%
k = d.loc[d['Position'] == 'PK']
k['performance_fp_qb'] = k['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-8-d0b0a0dfd751>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['performance_fp_qb'] = k['FantasyPointsRank'].rank(ascending = True)

# %%
Def = d.loc[d['Position'] == 'Def']
Def['performance_fp_qb'] = Def['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-9-1cd933a4c506>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Def['performance_fp_qb'] = Def['FantasyPointsRank'].rank(ascending = True)

# %%
rb_50 = rb.head(50)
after_rb = rb_50[(rb_50['FantasyPointsRank'] <= 70)]
after_rb.head(50)
# Out:
#      Rank_x Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 0         1    McCoy     LeSean    LeSean McCoy      1         1       436
# 1         2  Charles     Jamaal  Jamaal Charles      1         1       464
# 3         4    Forte       Matt      Matt Forte      1         1       454
# 4         5     Lacy      Eddie      Eddie Lacy      1         1       473
# 10       11    Lynch   Marshawn  Marshawn Lynch      1         1       458
# 15       16   Murray    DeMarco  DeMarco Murray      2         1       454
# 21       22   Foster      Arian    Arian Foster      2         1       473
# 22       23     Bell    Le'Veon    Le'Veon Bell      2         1       476
# 67       68     Bell     Joique     Joique Bell      6         1       540
# 95      109   Miller      Lamar    Lamar Miller      8         3       547
# 101     119     Hill     Jeremy     Jeremy Hill      9         1       889
# 110     131  Jackson       Fred    Fred Jackson     10         1       514
# 155     190   Ingram       Mark     Mark Ingram     13         2       590
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 0            74       RB  PHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 1            74       RB  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 3            75       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 4            75       RB  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 10           77       RB  SEA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 15           77       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 21           77       RB  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 22           77       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 67           82       RB  DET  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 95           78       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 101          84       RB  CIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 110          77       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 155          71       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_rb
# 0      NaN               61.0               11.0
# 1      NaN               34.0                7.0
# 3      NaN                6.0                3.0
# 4      NaN               24.0                6.0
# 10     NaN               14.0                4.0
# 15     NaN                4.0                2.0
# 21     NaN               23.0                5.0
# 22     NaN                2.0                1.0
# 67     NaN               63.0               12.0
# 95     NaN               45.0                8.0
# 101    NaN               56.0               10.0
# 110    NaN               70.0               14.0
# 155    NaN               66.0               13.0
#
# [13 rows x 45 columns]

# %%
wr_50 = wr.head(50)
after_wr = wr_50[(wr_50['FantasyPointsRank'] <= 70)]
after_wr.head(50)
# Out:
#      Rank_x  Player_x Unnamed: 2       Player_Name  Round  Min Pick  Max Pick  \
# 2         3   Johnson     Calvin    Calvin Johnson      1         1       439
# 5         6    Thomas  Demaryius  Demaryius Thomas      1         1       441
# 7         8    Bryant        Dez        Dez Bryant      1         1       447
# 9        10     Green       A.J.        A.J. Green      1         1       446
# 11       12     Jones      Julio       Julio Jones      1         1       449
# 18       19    Nelson      Jordy      Jordy Nelson      2         1       460
# 19       20     Brown    Antonio     Antonio Brown      2         1       458
# 23       24   Jeffery     Alshon    Alshon Jeffery      2         1       459
# 24       25      Cobb    Randall      Randall Cobb      3         1       464
# 36       37   Johnson      Andre     Andre Johnson      4         1       478
# 42       42     White      Roddy       Roddy White      4         1       319
# 48       48   Jackson     DeSean    DeSean Jackson      5         1       427
# 52       52    Hilton       T.Y.       T.Y. Hilton      5         1       360
# 59       59   Edelman     Julian    Julian Edelman      5         1       364
# 61       61     Smith     Torrey      Torrey Smith      6         1       344
# 62       62   Watkins      Sammy     Sammy Watkins      6         1       881
# 66       66    Maclin     Jeremy     Jeremy Maclin      6         1       422
# 68       69   Sanders   Emmanuel  Emmanuel Sanders      6         1       340
# 73       76   Wallace       Mike      Mike Wallace      7         1       332
# 76       80    Decker       Eric       Eric Decker      7         1       379
# 77       83     Evans       Mike        Mike Evans      7         1       882
# 83       92      Tate     Golden       Golden Tate      7         3       342
# 84       93  Benjamin     Kelvin   Kelvin Benjamin      8         1       894
# 103     122   Hopkins    DeAndre   DeAndre Hopkins      9         1       369
# 108     129  Matthews     Jordan   Jordan Matthews     10         1       883
# 126     155    Boldin     Anquan     Anquan Boldin     11         1       379
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 2            76       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 5            76       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 7            76       WR  DAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 9            76       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 11           76       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 18           78       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 19           78       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 23           76       WR  CHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 24           79       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 36           79       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 42           80       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 48           79       WR  WAS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 52           81       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 59           83       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 61           81       WR  BAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 62           95       WR  BUF  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 66           83       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 68           83       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 73           80       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 76           79       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 77           92       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 83           81       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 84           94       WR  CAR  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 103          73       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 108          77       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 126          74       WR  SFO  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_wr
# 2      NaN               42.0               15.0
# 5      NaN                7.0                2.0
# 7      NaN               10.0                4.0
# 9      NaN               59.0               24.0
# 11     NaN               16.0                6.0
# 18     NaN                9.0                3.0
# 19     NaN                1.0                1.0
# 23     NaN               30.0               10.0
# 24     NaN               18.0                8.0
# 36     NaN               69.0               29.0
# 42     NaN               54.0               21.0
# 48     NaN               58.0               23.0
# 52     NaN               32.0               12.0
# 59     NaN               48.0               17.0
# 61     NaN               67.0               28.0
# 62     NaN               64.0               27.0
# 66     NaN               22.0                9.0
# 68     NaN               15.0                5.0
# 73     NaN               53.0               20.0
# 76     NaN               62.0               26.0
# 77     NaN               39.0               13.0
# 83     NaN               31.0               11.0
# 84     NaN               43.0               16.0
# 103    NaN               40.0               14.0
# 108    NaN               60.0               25.0
# 126    NaN               51.0               18.0
#
# [26 rows x 45 columns]

# %%
te_50 = te.head(50)
after_te = te_50[(te_50['FantasyPointsRank'] <= 70)]
after_te.head(30)
# Out:
#      Rank_x    Player_x Unnamed: 2        Player_Name  Round  Min Pick  \
# 6         7      Graham      Jimmy       Jimmy Graham      1         1
# 25       26  Gronkowski        Rob     Rob Gronkowski      3         1
# 82       91       Olsen       Greg         Greg Olsen      7         1
# 123     149     Bennett  Martellus  Martellus Bennett     11         1
# 181     225       Gates    Antonio      Antonio Gates     16         3
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 6         444          75       TE  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 25        465          78       TE  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 82        320          80       TE  CAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 123       423          75       TE  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 181       513          68       TE  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_te
# 6      NaN    NaN               41.0                2.0
# 25     NaN    NaN               26.5                1.0
# 82     NaN    NaN               50.0                5.0
# 123    NaN    NaN               49.0                4.0
# 181    NaN    NaN               46.0                3.0
#
# [5 rows x 45 columns]

# %%
qb_50 = qb.head(50)
after_qb = qb_50[(qb_50['FantasyPointsRank'] <= 70)]
after_qb.head(30)
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 8         9         Manning     Peyton      Peyton Manning      1         1
# 13       14         Rodgers      Aaron       Aaron Rodgers      2         1
# 17       18           Brees       Drew          Drew Brees      2         1
# 32       33            Luck     Andrew         Andrew Luck      3         1
# 33       34        Stafford    Matthew    Matthew Stafford      3         1
# 56       56           Brady        Tom           Tom Brady      5         1
# 64       64            Ryan       Matt           Matt Ryan      6         1
# 70       72          Newton        Cam          Cam Newton      6         1
# 80       87      Kaepernick      Colin    Colin Kaepernick      7         1
# 87       96          Cutler        Jay          Jay Cutler      8         1
# 89       98          Wilson    Russell      Russell Wilson      8         1
# 92      101            Romo       Tony           Tony Romo      8         1
# 102     120          Rivers     Philip       Philip Rivers      9         1
# 117     139          Dalton       Andy         Andy Dalton     10         1
# 135     165  Roethlisberger        Ben  Ben Roethlisberger     12         1
# 144     178            Carr      Derek          Derek Carr     13         1
# 188     234       Tannehill       Ryan      Ryan Tannehill     16         1
# 193     244           Smith       Alex          Alex Smith     17         1
# 202     256          Flacco        Joe          Joe Flacco     17         1
# 204     259         Manning        Eli         Eli Manning     18         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 8         498          73       QB  DEN  ...    NaN  NaN NaN  NaN  395.0
# 13        484          74       QB  GBP  ...    NaN  NaN NaN  NaN  341.0
# 17        493          74       QB  NOS  ...    NaN  NaN NaN  NaN  456.0
# 32        485          75       QB  IND  ...    NaN  NaN NaN  NaN  380.0
# 33        472          76       QB  DET  ...    NaN  NaN NaN  NaN  363.0
# 56        487          77       QB  NEP  ...    NaN  NaN NaN  NaN  373.0
# 64        482          77       QB  ATL  ...    NaN  NaN NaN  NaN  415.0
# 70        478          76       QB  CAR  ...    NaN  NaN NaN  NaN  262.0
# 80        490          77       QB  SFO  ...    NaN  NaN NaN  NaN  289.0
# 87        483          80       QB  CHI  ...    NaN  NaN NaN  NaN  370.0
# 89        486          78       QB  SEA  ...    NaN  NaN NaN  NaN  285.0
# 92        471          79       QB  DAL  ...    NaN  NaN NaN  NaN  304.0
# 102       494          78       QB  SDC  ...    NaN  NaN NaN  NaN  379.0
# 117       481          78       QB  CIN  ...    NaN  NaN NaN  NaN  309.0
# 135       566          76       QB  PIT  ...    NaN  NaN NaN  NaN  408.0
# 144       919          25       QB  OAK  ...    NaN  NaN NaN  NaN  348.0
# 188       470          62       QB  MIA  ...    NaN  NaN NaN  NaN  392.0
# 193       465          59       QB  KCC  ...    NaN  NaN NaN  NaN  303.0
# 202       567          56       QB  BAL  ...    NaN  NaN NaN  NaN  344.0
# 204       610          55       QB  NYG  ...    NaN  NaN NaN  NaN  379.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 8    15.0   17.0   24.0               11.0                4.0
# 13    5.0   28.0   43.0                3.0                1.0
# 17   17.0   29.0   27.0               13.0                6.0
# 32   16.0   27.0   64.0                5.0                2.0
# 33   12.0   45.0   43.0               35.0               15.0
# 56    9.0   21.0   36.0               21.0                9.0
# 64   14.0   31.0   29.0               19.0                7.0
# 70   12.0   38.0  103.0               37.0               17.0
# 80   10.0   52.0  104.0               36.0               16.0
# 87   18.0   38.0   39.0               33.0               14.0
# 89    7.0   42.0  118.0                8.0                3.0
# 92    9.0   29.0   26.0               26.5               11.0
# 102  18.0   36.0   37.0               28.0               12.0
# 117  17.0   21.0   60.0               44.0               18.0
# 135   9.0   33.0   33.0               12.0                5.0
# 144  12.0   24.0   29.0               68.0               20.0
# 188  12.0   46.0   56.0               20.0                8.0
# 193   6.0   45.0   49.0               47.0               19.0
# 202  12.0   19.0   39.0               29.0               13.0
# 204  14.0   28.0   12.0               25.0               10.0
#
# [20 rows x 45 columns]

# %%
rb1 = rb[(rb['FantasyPointsRank'] <= 100)]
wr1 = wr[(wr['FantasyPointsRank'] <= 100)]
te1 = te[(te['FantasyPointsRank'] <= 100)]
qb1 = qb[(qb['FantasyPointsRank'] <= 100)]
rb1
# Out:
#      Rank_x   Player_x Unnamed: 2      Player_Name  Round  Min Pick  Max Pick  \
# 0         1      McCoy     LeSean     LeSean McCoy      1         1       436
# 1         2    Charles     Jamaal   Jamaal Charles      1         1       464
# 3         4      Forte       Matt       Matt Forte      1         1       454
# 4         5       Lacy      Eddie       Eddie Lacy      1         1       473
# 10       11      Lynch   Marshawn   Marshawn Lynch      1         1       458
# 15       16     Murray    DeMarco   DeMarco Murray      2         1       454
# 16       17    Bernard    Giovani  Giovani Bernard      2         1       456
# 21       22     Foster      Arian     Arian Foster      2         1       473
# 22       23       Bell    Le'Veon     Le'Veon Bell      2         1       476
# 27       28     Morris     Alfred    Alfred Morris      3         1       469
# 28       29  Ellington      Andre  Andre Ellington      3         1       850
# 43       43     Vereen      Shane     Shane Vereen      4         1       415
# 67       68       Bell     Joique      Joique Bell      6         1       540
# 95      109     Miller      Lamar     Lamar Miller      8         3       547
# 101     119       Hill     Jeremy      Jeremy Hill      9         1       889
# 110     131    Jackson       Fred     Fred Jackson     10         1       514
# 155     190     Ingram       Mark      Mark Ingram     13         2       590
# 237     312   Anderson       C.J.    C.J. Anderson     20         1       662
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 0            74       RB  PHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 1            74       RB  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 3            75       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 4            75       RB  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 10           77       RB  SEA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 15           77       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 16           77       RB  CIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 21           77       RB  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 22           77       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 27           77       RB  WAS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 28           79       RB  ARI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 43           82       RB  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 67           82       RB  DET  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 95           78       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 101          84       RB  CIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 110          77       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 155          71       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 237          25       RB  DEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_rb
# 0      NaN               61.0               11.0
# 1      NaN               34.0                7.0
# 3      NaN                6.0                3.0
# 4      NaN               24.0                6.0
# 10     NaN               14.0                4.0
# 15     NaN                4.0                2.0
# 16     NaN               71.5               15.5
# 21     NaN               23.0                5.0
# 22     NaN                2.0                1.0
# 27     NaN               71.5               15.5
# 28     NaN               81.0               17.0
# 43     NaN               95.0               18.0
# 67     NaN               63.0               12.0
# 95     NaN               45.0                8.0
# 101    NaN               56.0               10.0
# 110    NaN               70.0               14.0
# 155    NaN               66.0               13.0
# 237    NaN               55.0                9.0
#
# [18 rows x 45 columns]

# %%
wr1
# Out:
#      Rank_x  Player_x Unnamed: 2       Player_Name  Round  Min Pick  Max Pick  \
# 2         3   Johnson     Calvin    Calvin Johnson      1         1       439
# 5         6    Thomas  Demaryius  Demaryius Thomas      1         1       441
# 7         8    Bryant        Dez        Dez Bryant      1         1       447
# 9        10     Green       A.J.        A.J. Green      1         1       446
# 11       12     Jones      Julio       Julio Jones      1         1       449
# 12       13  Marshall    Brandon  Brandon Marshall      2         1       690
# 18       19    Nelson      Jordy      Jordy Nelson      2         1       460
# 19       20     Brown    Antonio     Antonio Brown      2         1       458
# 23       24   Jeffery     Alshon    Alshon Jeffery      2         1       459
# 24       25      Cobb    Randall      Randall Cobb      3         1       464
# 30       31     Allen     Keenan      Keenan Allen      3         1       494
# 35       36   Jackson    Vincent   Vincent Jackson      3         1       479
# 36       37   Johnson      Andre     Andre Johnson      4         1       478
# 42       42     White      Roddy       Roddy White      4         1       319
# 46       46  Crabtree    Michael  Michael Crabtree      4         1       370
# 48       48   Jackson     DeSean    DeSean Jackson      5         1       427
# 49       49     Floyd    Michael     Michael Floyd      5         1       350
# 52       52    Hilton       T.Y.       T.Y. Hilton      5         1       360
# 59       59   Edelman     Julian    Julian Edelman      5         1       364
# 61       61     Smith     Torrey      Torrey Smith      6         1       344
# 62       62   Watkins      Sammy     Sammy Watkins      6         1       881
# 66       66    Maclin     Jeremy     Jeremy Maclin      6         1       422
# 68       69   Sanders   Emmanuel  Emmanuel Sanders      6         1       340
# 72       75   Colston    Marques   Marques Colston      7         3       476
# 73       76   Wallace       Mike      Mike Wallace      7         1       332
# 74       77    Wright    Kendall    Kendall Wright      7         1       347
# 76       80    Decker       Eric       Eric Decker      7         1       379
# 77       83     Evans       Mike        Mike Evans      7         1       882
# 83       92      Tate     Golden       Golden Tate      7         3       342
# 84       93  Benjamin     Kelvin   Kelvin Benjamin      8         1       894
# 103     122   Hopkins    DeAndre   DeAndre Hopkins      9         1       369
# 108     129  Matthews     Jordan   Jordan Matthews     10         1       883
# 114     135    Randle     Rueben     Rueben Randle     10         4       564
# 126     155    Boldin     Anquan     Anquan Boldin     11         1       379
# 142     176    Landry     Jarvis     Jarvis Landry     12         3       911
# 154     189   Beckham      Odell     Odell Beckham     13         1       886
# 179     220    Stills      Kenny      Kenny Stills     15         6       413
# 186     231  Jennings       Greg     Greg Jennings     16         7       465
# 192     241     Smith      Steve       Steve Smith     17         1       497
# 205     260     Jones      James       James Jones     18         7       491
# 215     275   Baldwin       Doug      Doug Baldwin     18         1       469
# 232     304     Woods     Robert      Robert Woods     20         7       467
# 255     337    LaFell    Brandon    Brandon LaFell     22         4       605
# 258     340     Floyd     Malcom      Malcom Floyd     22         3       580
# 260     342      Sanu    Mohamed      Mohamed Sanu     22         8       665
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 2            76       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 5            76       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 7            76       WR  DAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 9            76       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 11           76       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 12           76       WR  CHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 18           78       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 19           78       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 23           76       WR  CHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 24           79       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 30           79       WR  SDC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 35           79       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 36           79       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 42           80       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 46           80       WR  SFO  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 48           79       WR  WAS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 49           81       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 52           81       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 59           83       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 61           81       WR  BAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 62           95       WR  BUF  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 66           83       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 68           83       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 72           81       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 73           80       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 74           79       WR  TEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 76           79       WR  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 77           92       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 83           81       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 84           94       WR  CAR  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 103          73       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 108          77       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 114          73       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 126          74       WR  SFO  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 142          22       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 154          55       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 179          61       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 186          62       WR  MIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 192          63       WR  BAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 205          55       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 215          48       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 232          34       WR  BUF  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 255          22       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 258          27       WR  SDC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 260          18       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_wr
# 2      NaN               42.0               15.0
# 5      NaN                7.0                2.0
# 7      NaN               10.0                4.0
# 9      NaN               59.0               24.0
# 11     NaN               16.0                6.0
# 12     NaN               80.0               34.0
# 18     NaN                9.0                3.0
# 19     NaN                1.0                1.0
# 23     NaN               30.0               10.0
# 24     NaN               18.0                8.0
# 30     NaN               87.0               36.0
# 35     NaN               76.5               32.0
# 36     NaN               69.0               29.0
# 42     NaN               54.0               21.0
# 46     NaN              100.0               45.0
# 48     NaN               58.0               23.0
# 49     NaN               96.0               43.0
# 52     NaN               32.0               12.0
# 59     NaN               48.0               17.0
# 61     NaN               67.0               28.0
# 62     NaN               64.0               27.0
# 66     NaN               22.0                9.0
# 68     NaN               15.0                5.0
# 72     NaN               82.5               35.0
# 73     NaN               53.0               20.0
# 74     NaN               93.0               41.0
# 76     NaN               62.0               26.0
# 77     NaN               39.0               13.0
# 83     NaN               31.0               11.0
# 84     NaN               43.0               16.0
# 103    NaN               40.0               14.0
# 108    NaN               60.0               25.0
# 114    NaN               73.0               30.0
# 126    NaN               51.0               18.0
# 142    NaN               74.0               31.0
# 154    NaN               17.0                7.0
# 179    NaN               88.0               37.0
# 186    NaN               91.0               40.0
# 192    NaN               52.0               19.0
# 205    NaN               89.5               38.5
# 215    NaN               94.0               42.0
# 232    NaN               97.0               44.0
# 255    NaN               57.0               22.0
# 258    NaN               89.5               38.5
# 260    NaN               79.0               33.0
#
# [45 rows x 45 columns]

# %%
te1
# Out:
#      Rank_x    Player_x Unnamed: 2        Player_Name  Round  Min Pick  \
# 6         7      Graham      Jimmy       Jimmy Graham      1         1
# 25       26  Gronkowski        Rob     Rob Gronkowski      3         1
# 26       27      Thomas     Julius      Julius Thomas      3         1
# 69       71      Witten      Jason       Jason Witten      6         1
# 82       91       Olsen       Greg         Greg Olsen      7         1
# 123     149     Bennett  Martellus  Martellus Bennett     11         1
# 181     225       Gates    Antonio      Antonio Gates     16         3
# 201     255       Kelce     Travis       Travis Kelce     17         2
# 211     267      Walker    Delanie     Delanie Walker     18         3
# 226     292     Fleener       Coby       Coby Fleener     19         6
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 6         444          75       TE  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 25        465          78       TE  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 26        467          79       TE  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 69        428          81       TE  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 82        320          80       TE  CAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 123       423          75       TE  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 181       513          68       TE  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
# 201       592          52       TE  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 211       480          53       TE  TEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 226       567          40       TE  IND  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_te
# 6      NaN    NaN               41.0                2.0
# 25     NaN    NaN               26.5                1.0
# 26     NaN    NaN               99.0               10.0
# 69     NaN    NaN               98.0                9.0
# 82     NaN    NaN               50.0                5.0
# 123    NaN    NaN               49.0                4.0
# 181    NaN    NaN               46.0                3.0
# 201    NaN    NaN               82.5                6.0
# 211    NaN    NaN               86.0                8.0
# 226    NaN    NaN               84.0                7.0
#
# [10 rows x 45 columns]

# %%
qb1
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 8         9         Manning     Peyton      Peyton Manning      1         1
# 13       14         Rodgers      Aaron       Aaron Rodgers      2         1
# 17       18           Brees       Drew          Drew Brees      2         1
# 32       33            Luck     Andrew         Andrew Luck      3         1
# 33       34        Stafford    Matthew    Matthew Stafford      3         1
# 56       56           Brady        Tom           Tom Brady      5         1
# 64       64            Ryan       Matt           Matt Ryan      6         1
# 70       72          Newton        Cam          Cam Newton      6         1
# 80       87      Kaepernick      Colin    Colin Kaepernick      7         1
# 87       96          Cutler        Jay          Jay Cutler      8         1
# 89       98          Wilson    Russell      Russell Wilson      8         1
# 92      101            Romo       Tony           Tony Romo      8         1
# 102     120          Rivers     Philip       Philip Rivers      9         1
# 117     139          Dalton       Andy         Andy Dalton     10         1
# 135     165  Roethlisberger        Ben  Ben Roethlisberger     12         1
# 144     178            Carr      Derek          Derek Carr     13         1
# 156     191         Bortles      Blake       Blake Bortles     14         1
# 165     200     Bridgewater      Teddy   Teddy Bridgewater     14         1
# 188     234       Tannehill       Ryan      Ryan Tannehill     16         1
# 193     244           Smith       Alex          Alex Smith     17         1
# 202     256          Flacco        Joe          Joe Flacco     17         1
# 204     259         Manning        Eli         Eli Manning     18         1
# 273     357     Fitzpatrick       Ryan    Ryan Fitzpatrick     23         9
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 8         498          73       QB  DEN  ...    NaN  NaN NaN  NaN  395.0
# 13        484          74       QB  GBP  ...    NaN  NaN NaN  NaN  341.0
# 17        493          74       QB  NOS  ...    NaN  NaN NaN  NaN  456.0
# 32        485          75       QB  IND  ...    NaN  NaN NaN  NaN  380.0
# 33        472          76       QB  DET  ...    NaN  NaN NaN  NaN  363.0
# 56        487          77       QB  NEP  ...    NaN  NaN NaN  NaN  373.0
# 64        482          77       QB  ATL  ...    NaN  NaN NaN  NaN  415.0
# 70        478          76       QB  CAR  ...    NaN  NaN NaN  NaN  262.0
# 80        490          77       QB  SFO  ...    NaN  NaN NaN  NaN  289.0
# 87        483          80       QB  CHI  ...    NaN  NaN NaN  NaN  370.0
# 89        486          78       QB  SEA  ...    NaN  NaN NaN  NaN  285.0
# 92        471          79       QB  DAL  ...    NaN  NaN NaN  NaN  304.0
# 102       494          78       QB  SDC  ...    NaN  NaN NaN  NaN  379.0
# 117       481          78       QB  CIN  ...    NaN  NaN NaN  NaN  309.0
# 135       566          76       QB  PIT  ...    NaN  NaN NaN  NaN  408.0
# 144       919          25       QB  OAK  ...    NaN  NaN NaN  NaN  348.0
# 156       903          42       QB  JAC  ...    NaN  NaN NaN  NaN  280.0
# 165       892          46       QB  MIN  ...    NaN  NaN NaN  NaN  259.0
# 188       470          62       QB  MIA  ...    NaN  NaN NaN  NaN  392.0
# 193       465          59       QB  KCC  ...    NaN  NaN NaN  NaN  303.0
# 202       567          56       QB  BAL  ...    NaN  NaN NaN  NaN  344.0
# 204       610          55       QB  NYG  ...    NaN  NaN NaN  NaN  379.0
# 273       813          17       QB  HOU  ...    NaN  NaN NaN  NaN  197.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 8    15.0   17.0   24.0               11.0                4.0
# 13    5.0   28.0   43.0                3.0                1.0
# 17   17.0   29.0   27.0               13.0                6.0
# 32   16.0   27.0   64.0                5.0                2.0
# 33   12.0   45.0   43.0               35.0               15.0
# 56    9.0   21.0   36.0               21.0                9.0
# 64   14.0   31.0   29.0               19.0                7.0
# 70   12.0   38.0  103.0               37.0               17.0
# 80   10.0   52.0  104.0               36.0               16.0
# 87   18.0   38.0   39.0               33.0               14.0
# 89    7.0   42.0  118.0                8.0                3.0
# 92    9.0   29.0   26.0               26.5               11.0
# 102  18.0   36.0   37.0               28.0               12.0
# 117  17.0   21.0   60.0               44.0               18.0
# 135   9.0   33.0   33.0               12.0                5.0
# 144  12.0   24.0   29.0               68.0               20.0
# 156  17.0   55.0   56.0               92.0               23.0
# 165  12.0   39.0   47.0               78.0               22.0
# 188  12.0   46.0   56.0               20.0                8.0
# 193   6.0   45.0   49.0               47.0               19.0
# 202  12.0   19.0   39.0               29.0               13.0
# 204  14.0   28.0   12.0               25.0               10.0
# 273   8.0   21.0   50.0               76.5               21.0
#
# [23 rows x 45 columns]

# %%
rb2 = rb[(rb['FantasyPointsRank'] <= 50)]
wr2 = wr[(wr['FantasyPointsRank'] <= 50)]
te2 = te[(te['FantasyPointsRank'] <= 50)]
qb2 = qb[(qb['FantasyPointsRank'] <= 50)]
rb2
# Out:
#     Rank_x Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 1        2  Charles     Jamaal  Jamaal Charles      1         1       464
# 3        4    Forte       Matt      Matt Forte      1         1       454
# 4        5     Lacy      Eddie      Eddie Lacy      1         1       473
# 10      11    Lynch   Marshawn  Marshawn Lynch      1         1       458
# 15      16   Murray    DeMarco  DeMarco Murray      2         1       454
# 21      22   Foster      Arian    Arian Foster      2         1       473
# 22      23     Bell    Le'Veon    Le'Veon Bell      2         1       476
# 95     109   Miller      Lamar    Lamar Miller      8         3       547
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 1           74       RB  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 3           75       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 4           75       RB  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 10          77       RB  SEA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 15          77       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 21          77       RB  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 22          77       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 95          78       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_rb
# 1                34.0                7.0
# 3                 6.0                3.0
# 4                24.0                6.0
# 10               14.0                4.0
# 15                4.0                2.0
# 21               23.0                5.0
# 22                2.0                1.0
# 95               45.0                8.0
#
# [8 rows x 45 columns]

# %%
wr2
# Out:
#      Rank_x  Player_x Unnamed: 2       Player_Name  Round  Min Pick  Max Pick  \
# 2         3   Johnson     Calvin    Calvin Johnson      1         1       439
# 5         6    Thomas  Demaryius  Demaryius Thomas      1         1       441
# 7         8    Bryant        Dez        Dez Bryant      1         1       447
# 11       12     Jones      Julio       Julio Jones      1         1       449
# 18       19    Nelson      Jordy      Jordy Nelson      2         1       460
# 19       20     Brown    Antonio     Antonio Brown      2         1       458
# 23       24   Jeffery     Alshon    Alshon Jeffery      2         1       459
# 24       25      Cobb    Randall      Randall Cobb      3         1       464
# 52       52    Hilton       T.Y.       T.Y. Hilton      5         1       360
# 59       59   Edelman     Julian    Julian Edelman      5         1       364
# 66       66    Maclin     Jeremy     Jeremy Maclin      6         1       422
# 68       69   Sanders   Emmanuel  Emmanuel Sanders      6         1       340
# 77       83     Evans       Mike        Mike Evans      7         1       882
# 83       92      Tate     Golden       Golden Tate      7         3       342
# 84       93  Benjamin     Kelvin   Kelvin Benjamin      8         1       894
# 103     122   Hopkins    DeAndre   DeAndre Hopkins      9         1       369
# 154     189   Beckham      Odell     Odell Beckham     13         1       886
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 2            76       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 5            76       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 7            76       WR  DAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 11           76       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 18           78       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 19           78       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 23           76       WR  CHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 24           79       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 52           81       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 59           83       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 66           83       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 68           83       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 77           92       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 83           81       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 84           94       WR  CAR  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 103          73       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 154          55       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_wr
# 2      NaN               42.0               15.0
# 5      NaN                7.0                2.0
# 7      NaN               10.0                4.0
# 11     NaN               16.0                6.0
# 18     NaN                9.0                3.0
# 19     NaN                1.0                1.0
# 23     NaN               30.0               10.0
# 24     NaN               18.0                8.0
# 52     NaN               32.0               12.0
# 59     NaN               48.0               17.0
# 66     NaN               22.0                9.0
# 68     NaN               15.0                5.0
# 77     NaN               39.0               13.0
# 83     NaN               31.0               11.0
# 84     NaN               43.0               16.0
# 103    NaN               40.0               14.0
# 154    NaN               17.0                7.0
#
# [17 rows x 45 columns]

# %%
te2
# Out:
#      Rank_x    Player_x Unnamed: 2        Player_Name  Round  Min Pick  \
# 6         7      Graham      Jimmy       Jimmy Graham      1         1
# 25       26  Gronkowski        Rob     Rob Gronkowski      3         1
# 82       91       Olsen       Greg         Greg Olsen      7         1
# 123     149     Bennett  Martellus  Martellus Bennett     11         1
# 181     225       Gates    Antonio      Antonio Gates     16         3
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 6         444          75       TE  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 25        465          78       TE  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 82        320          80       TE  CAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 123       423          75       TE  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 181       513          68       TE  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_te
# 6      NaN    NaN               41.0                2.0
# 25     NaN    NaN               26.5                1.0
# 82     NaN    NaN               50.0                5.0
# 123    NaN    NaN               49.0                4.0
# 181    NaN    NaN               46.0                3.0
#
# [5 rows x 45 columns]

# %%
qb2
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 8         9         Manning     Peyton      Peyton Manning      1         1
# 13       14         Rodgers      Aaron       Aaron Rodgers      2         1
# 17       18           Brees       Drew          Drew Brees      2         1
# 32       33            Luck     Andrew         Andrew Luck      3         1
# 33       34        Stafford    Matthew    Matthew Stafford      3         1
# 56       56           Brady        Tom           Tom Brady      5         1
# 64       64            Ryan       Matt           Matt Ryan      6         1
# 70       72          Newton        Cam          Cam Newton      6         1
# 80       87      Kaepernick      Colin    Colin Kaepernick      7         1
# 87       96          Cutler        Jay          Jay Cutler      8         1
# 89       98          Wilson    Russell      Russell Wilson      8         1
# 92      101            Romo       Tony           Tony Romo      8         1
# 102     120          Rivers     Philip       Philip Rivers      9         1
# 117     139          Dalton       Andy         Andy Dalton     10         1
# 135     165  Roethlisberger        Ben  Ben Roethlisberger     12         1
# 188     234       Tannehill       Ryan      Ryan Tannehill     16         1
# 193     244           Smith       Alex          Alex Smith     17         1
# 202     256          Flacco        Joe          Joe Flacco     17         1
# 204     259         Manning        Eli         Eli Manning     18         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 8         498          73       QB  DEN  ...    NaN  NaN NaN  NaN  395.0
# 13        484          74       QB  GBP  ...    NaN  NaN NaN  NaN  341.0
# 17        493          74       QB  NOS  ...    NaN  NaN NaN  NaN  456.0
# 32        485          75       QB  IND  ...    NaN  NaN NaN  NaN  380.0
# 33        472          76       QB  DET  ...    NaN  NaN NaN  NaN  363.0
# 56        487          77       QB  NEP  ...    NaN  NaN NaN  NaN  373.0
# 64        482          77       QB  ATL  ...    NaN  NaN NaN  NaN  415.0
# 70        478          76       QB  CAR  ...    NaN  NaN NaN  NaN  262.0
# 80        490          77       QB  SFO  ...    NaN  NaN NaN  NaN  289.0
# 87        483          80       QB  CHI  ...    NaN  NaN NaN  NaN  370.0
# 89        486          78       QB  SEA  ...    NaN  NaN NaN  NaN  285.0
# 92        471          79       QB  DAL  ...    NaN  NaN NaN  NaN  304.0
# 102       494          78       QB  SDC  ...    NaN  NaN NaN  NaN  379.0
# 117       481          78       QB  CIN  ...    NaN  NaN NaN  NaN  309.0
# 135       566          76       QB  PIT  ...    NaN  NaN NaN  NaN  408.0
# 188       470          62       QB  MIA  ...    NaN  NaN NaN  NaN  392.0
# 193       465          59       QB  KCC  ...    NaN  NaN NaN  NaN  303.0
# 202       567          56       QB  BAL  ...    NaN  NaN NaN  NaN  344.0
# 204       610          55       QB  NYG  ...    NaN  NaN NaN  NaN  379.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 8    15.0   17.0   24.0               11.0                4.0
# 13    5.0   28.0   43.0                3.0                1.0
# 17   17.0   29.0   27.0               13.0                6.0
# 32   16.0   27.0   64.0                5.0                2.0
# 33   12.0   45.0   43.0               35.0               15.0
# 56    9.0   21.0   36.0               21.0                9.0
# 64   14.0   31.0   29.0               19.0                7.0
# 70   12.0   38.0  103.0               37.0               17.0
# 80   10.0   52.0  104.0               36.0               16.0
# 87   18.0   38.0   39.0               33.0               14.0
# 89    7.0   42.0  118.0                8.0                3.0
# 92    9.0   29.0   26.0               26.5               11.0
# 102  18.0   36.0   37.0               28.0               12.0
# 117  17.0   21.0   60.0               44.0               18.0
# 135   9.0   33.0   33.0               12.0                5.0
# 188  12.0   46.0   56.0               20.0                8.0
# 193   6.0   45.0   49.0               47.0               19.0
# 202  12.0   19.0   39.0               29.0               13.0
# 204  14.0   28.0   12.0               25.0               10.0
#
# [19 rows x 45 columns]

# %%
rb3 = rb[(rb['FantasyPointsRank'] <= 25)]
wr3 = wr[(wr['FantasyPointsRank'] <= 25)]
te3 = te[(te['FantasyPointsRank'] <= 25)]
qb3 = qb[(qb['FantasyPointsRank'] <= 25)]
rb3
# Out:
#     Rank_x Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 3        4    Forte       Matt      Matt Forte      1         1       454
# 4        5     Lacy      Eddie      Eddie Lacy      1         1       473
# 10      11    Lynch   Marshawn  Marshawn Lynch      1         1       458
# 15      16   Murray    DeMarco  DeMarco Murray      2         1       454
# 21      22   Foster      Arian    Arian Foster      2         1       473
# 22      23     Bell    Le'Veon    Le'Veon Bell      2         1       476
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 3           75       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 4           75       RB  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 10          77       RB  SEA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 15          77       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 21          77       RB  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 22          77       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_rb
# 3                 6.0                3.0
# 4                24.0                6.0
# 10               14.0                4.0
# 15                4.0                2.0
# 21               23.0                5.0
# 22                2.0                1.0
#
# [6 rows x 45 columns]

# %%
wr3
# Out:
#      Rank_x Player_x Unnamed: 2       Player_Name  Round  Min Pick  Max Pick  \
# 5         6   Thomas  Demaryius  Demaryius Thomas      1         1       441
# 7         8   Bryant        Dez        Dez Bryant      1         1       447
# 11       12    Jones      Julio       Julio Jones      1         1       449
# 18       19   Nelson      Jordy      Jordy Nelson      2         1       460
# 19       20    Brown    Antonio     Antonio Brown      2         1       458
# 24       25     Cobb    Randall      Randall Cobb      3         1       464
# 66       66   Maclin     Jeremy     Jeremy Maclin      6         1       422
# 68       69  Sanders   Emmanuel  Emmanuel Sanders      6         1       340
# 154     189  Beckham      Odell     Odell Beckham     13         1       886
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 5            76       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 7            76       WR  DAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 11           76       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 18           78       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 19           78       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 24           79       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 66           83       WR  PHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 68           83       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 154          55       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_wr
# 5      NaN                7.0                2.0
# 7      NaN               10.0                4.0
# 11     NaN               16.0                6.0
# 18     NaN                9.0                3.0
# 19     NaN                1.0                1.0
# 24     NaN               18.0                8.0
# 66     NaN               22.0                9.0
# 68     NaN               15.0                5.0
# 154    NaN               17.0                7.0
#
# [9 rows x 45 columns]

# %%
wr3['FantasyPointsRank'].sum()
# Out:
# 115.0

# %%
te3
# Out:
# Empty DataFrame
# Columns: [Rank_x, Player_x, Unnamed: 2, Player_Name, Round, Min Pick, Max Pick, % Selected, Position, Team, PositionRank, Rank_y, Player_y, ATT, YDS, Y/A, LG, 20+, TD, REC, TGT, YDS.1, Y/R, TD.1, FL, G, FPTS, FPTS/G, OWN, FG, FGA, PCT, 1-19, 20-29, 30-39, 40-49, 50+, XPT, XPA, CMP, INT, SACKS, ATT.1, FantasyPointsRank, performance_fp_te]
# Index: []
#
# [0 rows x 45 columns]

# %%
qb3
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 8         9         Manning     Peyton      Peyton Manning      1         1
# 13       14         Rodgers      Aaron       Aaron Rodgers      2         1
# 17       18           Brees       Drew          Drew Brees      2         1
# 32       33            Luck     Andrew         Andrew Luck      3         1
# 56       56           Brady        Tom           Tom Brady      5         1
# 64       64            Ryan       Matt           Matt Ryan      6         1
# 89       98          Wilson    Russell      Russell Wilson      8         1
# 135     165  Roethlisberger        Ben  Ben Roethlisberger     12         1
# 188     234       Tannehill       Ryan      Ryan Tannehill     16         1
# 204     259         Manning        Eli         Eli Manning     18         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 8         498          73       QB  DEN  ...    NaN  NaN NaN  NaN  395.0
# 13        484          74       QB  GBP  ...    NaN  NaN NaN  NaN  341.0
# 17        493          74       QB  NOS  ...    NaN  NaN NaN  NaN  456.0
# 32        485          75       QB  IND  ...    NaN  NaN NaN  NaN  380.0
# 56        487          77       QB  NEP  ...    NaN  NaN NaN  NaN  373.0
# 64        482          77       QB  ATL  ...    NaN  NaN NaN  NaN  415.0
# 89        486          78       QB  SEA  ...    NaN  NaN NaN  NaN  285.0
# 135       566          76       QB  PIT  ...    NaN  NaN NaN  NaN  408.0
# 188       470          62       QB  MIA  ...    NaN  NaN NaN  NaN  392.0
# 204       610          55       QB  NYG  ...    NaN  NaN NaN  NaN  379.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 8    15.0   17.0   24.0               11.0                4.0
# 13    5.0   28.0   43.0                3.0                1.0
# 17   17.0   29.0   27.0               13.0                6.0
# 32   16.0   27.0   64.0                5.0                2.0
# 56    9.0   21.0   36.0               21.0                9.0
# 64   14.0   31.0   29.0               19.0                7.0
# 89    7.0   42.0  118.0                8.0                3.0
# 135   9.0   33.0   33.0               12.0                5.0
# 188  12.0   46.0   56.0               20.0                8.0
# 204  14.0   28.0   12.0               25.0               10.0
#
# [10 rows x 45 columns]

# %%
rb_25_50 = rb2[(rb2['FantasyPointsRank'] >= 25)]
wr_25_50 = wr2[(wr2['FantasyPointsRank'] >= 25)]
te_25_50 = te2[(te2['FantasyPointsRank'] >= 25)]
qb_25_50 = qb2[(qb2['FantasyPointsRank'] >= 25)]
rb_25_50
# Out:
#     Rank_x Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 1        2  Charles     Jamaal  Jamaal Charles      1         1       464
# 95     109   Miller      Lamar    Lamar Miller      8         3       547
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 1           74       RB  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 95          78       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_rb
# 1                34.0                7.0
# 95               45.0                8.0
#
# [2 rows x 45 columns]

# %%
rb_25_50['FantasyPointsRank'].sum()
# Out:
# 79.0

# %%
wr_25_50
# Out:
#      Rank_x  Player_x Unnamed: 2      Player_Name  Round  Min Pick  Max Pick  \
# 2         3   Johnson     Calvin   Calvin Johnson      1         1       439
# 23       24   Jeffery     Alshon   Alshon Jeffery      2         1       459
# 52       52    Hilton       T.Y.      T.Y. Hilton      5         1       360
# 59       59   Edelman     Julian   Julian Edelman      5         1       364
# 77       83     Evans       Mike       Mike Evans      7         1       882
# 83       92      Tate     Golden      Golden Tate      7         3       342
# 84       93  Benjamin     Kelvin  Kelvin Benjamin      8         1       894
# 103     122   Hopkins    DeAndre  DeAndre Hopkins      9         1       369
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 2            76       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 23           76       WR  CHI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 52           81       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 59           83       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 77           92       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 83           81       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 84           94       WR  CAR  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 103          73       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_wr
# 2      NaN               42.0               15.0
# 23     NaN               30.0               10.0
# 52     NaN               32.0               12.0
# 59     NaN               48.0               17.0
# 77     NaN               39.0               13.0
# 83     NaN               31.0               11.0
# 84     NaN               43.0               16.0
# 103    NaN               40.0               14.0
#
# [8 rows x 45 columns]

# %%
wr_25_50['FantasyPointsRank'].sum()
# Out:
# 305.0
