# %%
import pandas as pd

import gc # To collect garbage values generated during running

import matplotlib.pyplot as plt

import numpy as np

import seaborn as sns

# %%
d = pd.read_csv('2016_cleaned_with_rounds.csv')

# %%
rb = d.loc[d['Position'] == 'RB']
wr = d.loc[d['Position'] == 'WR']

# %%
wr['performance_fp_wr'] = wr['FantasyPointsRank'].rank(ascending = True)
rb['performance_fp_rb'] = rb['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-4-ea88c15edb18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wr['performance_fp_wr'] = wr['FantasyPointsRank'].rank(ascending = True)
# <ipython-input-4-ea88c15edb18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rb['performance_fp_rb'] = rb['FantasyPointsRank'].rank(ascending = True)

# %%
te = d.loc[d['Position'] == 'TE']
te['performance_fp_te'] = te['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-5-c576e4e6ce8f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   te['performance_fp_te'] = te['FantasyPointsRank'].rank(ascending = True)

# %%
qb = d.loc[d['Position'] == 'QB']
qb['performance_fp_qb'] = qb['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-6-4882867569a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qb['performance_fp_qb'] = qb['FantasyPointsRank'].rank(ascending = True)

# %%
k = d.loc[d['Position'] == 'PK']
k['performance_fp_qb'] = k['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-7-d0b0a0dfd751>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k['performance_fp_qb'] = k['FantasyPointsRank'].rank(ascending = True)

# %%
Def = d.loc[d['Position'] == 'Def']
Def['performance_fp_qb'] = Def['FantasyPointsRank'].rank(ascending = True)
# Out:
# <ipython-input-8-1cd933a4c506>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Def['performance_fp_qb'] = Def['FantasyPointsRank'].rank(ascending = True)

# %%
rb_50 = rb.head(50)
after_rb = rb_50[(rb_50['FantasyPointsRank'] <= 70)]
after_rb.head(50)
# Out:
#      Rank_x Player_x  Unnamed: 2        Player_Name  Round  Min Pick  \
# 1         2  Elliott     Ezekiel    Ezekiel Elliott      1         1
# 3         4   Gurley        Todd        Todd Gurley      1         1
# 7         8     Bell     Le'Veon       Le'Veon Bell      1         1
# 10       11  Johnson       David      David Johnson      1         1
# 12       12   Miller       Lamar       Lamar Miller      2         1
# 16       16  Freeman     Devonta    Devonta Freeman      2         1
# 24       24   Ingram        Mark        Mark Ingram      3         1
# 26       26    McCoy      LeSean       LeSean McCoy      3         1
# 36       36     Hyde      Carlos        Carlos Hyde      4         1
# 43       43   Murray    Latavius    Latavius Murray      4         1
# 48       48   Murray     DeMarco     DeMarco Murray      5         1
# 60       65   Gordon      Melvin      Melvin Gordon      6         1
# 81       97     Gore       Frank         Frank Gore      7         1
# 97      119    Ajayi         Jay          Jay Ajayi      9         2
# 143     181  Crowell      Isaiah     Isaiah Crowell     12         2
# 147     185   Blount  LeGarrette  LeGarrette Blount     13         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 1         743          98       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 3         830          70       RB  RAM  ...    NaN  NaN NaN  NaN NaN  NaN
# 7         457          74       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 10        425          71       RB  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 12        447          75       RB  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 16        458          74       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 24        455          74       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 26        419          74       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN
# 36        424          75       RB  SFO  ...    NaN  NaN NaN  NaN NaN  NaN
# 43        465          77       RB  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 48        431          75       RB  TEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 60        461          75       RB  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
# 81        475          77       RB  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 97        450          74       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 143       560          71       RB  CLE  ...    NaN  NaN NaN  NaN NaN  NaN
# 147       597          77       RB  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 1      NaN    NaN                5.0                2.0
# 3      NaN    NaN               65.0               17.0
# 7      NaN    NaN                9.0                3.0
# 10     NaN    NaN                2.0                1.0
# 12     NaN    NaN               66.5               18.5
# 16     NaN    NaN               21.0                6.0
# 24     NaN    NaN               37.0                9.0
# 26     NaN    NaN               11.0                4.0
# 36     NaN    NaN               62.0               15.0
# 43     NaN    NaN               49.0               13.0
# 48     NaN    NaN               16.0                5.0
# 60     NaN    NaN               31.0                7.0
# 81     NaN    NaN               47.0               12.0
# 97     NaN    NaN               45.0               11.0
# 143    NaN    NaN               55.0               14.0
# 147    NaN    NaN               32.0                8.0
#
# [16 rows x 45 columns]

# %%
wr_50 = wr.head(50)
after_wr = wr_50[(wr_50['FantasyPointsRank'] <= 70)]
after_wr.head(50)
# Out:
#     Rank_x    Player_x Unnamed: 2       Player_Name  Round  Min Pick  \
# 0        1       Brown    Antonio     Antonio Brown      1         1
# 2        3       Jones      Julio       Julio Jones      1         1
# 4        5     Beckham      Odell     Odell Beckham      1         1
# 15      15       Evans       Mike        Mike Evans      2         1
# 17      17      Cooper      Amari      Amari Cooper      2         1
# 20      20      Nelson      Jordy      Jordy Nelson      2         1
# 23      23       Cooks    Brandin     Brandin Cooks      2         1
# 25      25      Hilton       T.Y.       T.Y. Hilton      3         1
# 30      30      Thomas  Demaryius  Demaryius Thomas      3         1
# 31      31      Landry     Jarvis     Jarvis Landry      3         1
# 35      35     Edelman     Julian    Julian Edelman      3         1
# 41      41        Tate     Golden       Golden Tate      4         1
# 47      47     Baldwin       Doug      Doug Baldwin      4         1
# 53      56  Fitzgerald      Larry  Larry Fitzgerald      5         2
# 62      68     Sanders   Emmanuel  Emmanuel Sanders      6         1
# 78      92    Crabtree    Michael  Michael Crabtree      7         2
# 90     111      Thomas    Michael    Michael Thomas      8         1
#
#     Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 0        436          73       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 2        367          73       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 4        363          73       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN
# 15       697          73       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN
# 17       464          75       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 20       345          75       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN
# 23       534          74       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 25       356          75       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 30       357          74       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 31       460          77       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 35       381          78       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 41       393          79       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
# 47       400          79       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN
# 53       724          77       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 62       353          76       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 78       497          78       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 90       748          84       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
#
#     SACKS  ATT.1  FantasyPointsRank  performance_fp_wr
# 0     NaN    NaN               25.5                3.0
# 2     NaN    NaN               38.0                6.0
# 4     NaN    NaN               28.0                4.0
# 15    NaN    NaN               24.0                2.0
# 17    NaN    NaN               53.0               13.0
# 20    NaN    NaN               23.0                1.0
# 23    NaN    NaN               43.0                9.0
# 25    NaN    NaN               33.0                5.0
# 30    NaN    NaN               57.5               16.5
# 31    NaN    NaN               54.0               14.0
# 35    NaN    NaN               57.5               16.5
# 41    NaN    NaN               63.0               19.0
# 47    NaN    NaN               44.0               10.0
# 53    NaN    NaN               51.0               12.0
# 62    NaN    NaN               70.0               21.0
# 78    NaN    NaN               48.0               11.0
# 90    NaN    NaN               41.0                7.0
#
# [17 rows x 45 columns]

# %%
te_50 = te.head(50)
after_te = te_50[(te_50['FantasyPointsRank'] <= 70)]
after_te.head(30)
# Out:
#     Rank_x Player_x Unnamed: 2   Player_Name  Round  Min Pick  Max Pick  \
# 54      58    Kelce     Travis  Travis Kelce      5         2       348
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 54          78       TE  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_te
# 54               59.0                1.0
#
# [1 rows x 45 columns]

# %%
qb_50 = qb.head(50)
after_qb = qb_50[(qb_50['FantasyPointsRank'] <= 70)]
after_qb.head(30)
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 27       27          Newton        Cam          Cam Newton      3         1
# 29       29         Rodgers      Aaron       Aaron Rodgers      3         1
# 40       40            Luck     Andrew         Andrew Luck      4         1
# 42       42          Wilson    Russell      Russell Wilson      4         1
# 51       52           Brees       Drew          Drew Brees      5         1
# 57       61  Roethlisberger        Ben  Ben Roethlisberger      5         1
# 66       73           Brady        Tom           Tom Brady      6         1
# 83      101          Palmer     Carson       Carson Palmer      7         1
# 85      105         Bortles      Blake       Blake Bortles      8         1
# 92      113         Manning        Eli         Eli Manning      8         1
# 99      121          Rivers     Philip       Philip Rivers      9         1
# 122     155         Winston     Jameis      Jameis Winston     11         1
# 125     160         Cousins       Kirk        Kirk Cousins     11         1
# 144     182           Wentz     Carson        Carson Wentz     13         1
# 148     186        Stafford    Matthew    Matthew Stafford     13         1
# 157     196        Prescott        Dak        Dak Prescott     14         1
# 165     205          Taylor      Tyrod        Tyrod Taylor     14         1
# 174     215         Mariota     Marcus      Marcus Mariota     15         2
# 177     224          Dalton       Andy         Andy Dalton     15         1
# 185     236            Ryan       Matt           Matt Ryan     16         1
# 206     266       Tannehill       Ryan      Ryan Tannehill     18         2
# 230     295          Flacco        Joe          Joe Flacco     20         1
# 231     296           Smith       Alex          Alex Smith     20         1
# 256     326         Siemian     Trevor      Trevor Siemian     22         3
# 283     352        Bradford        Sam        Sam Bradford     24         2
# 322     391      Kaepernick      Colin    Colin Kaepernick     27         4
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 27        476          70       QB  CAR  ...    NaN  NaN NaN  NaN  270.0
# 29        481          72       QB  GBP  ...    NaN  NaN NaN  NaN  401.0
# 40        486          71       QB  IND  ...    NaN  NaN NaN  NaN  346.0
# 42        475          74       QB  SEA  ...    NaN  NaN NaN  NaN  353.0
# 51        479          73       QB  NOS  ...    NaN  NaN NaN  NaN  471.0
# 57        476          76       QB  PIT  ...    NaN  NaN NaN  NaN  328.0
# 66        496          75       QB  NEP  ...    NaN  NaN NaN  NaN  291.0
# 83        483          75       QB  ARI  ...    NaN  NaN NaN  NaN  364.0
# 85        495          74       QB  JAC  ...    NaN  NaN NaN  NaN  368.0
# 92        468          77       QB  NYG  ...    NaN  NaN NaN  NaN  377.0
# 99        474          75       QB  SDC  ...    NaN  NaN NaN  NaN  349.0
# 122       465          73       QB  TBB  ...    NaN  NaN NaN  NaN  345.0
# 125       544          75       QB  WAS  ...    NaN  NaN NaN  NaN  406.0
# 144       829          39       QB  PHI  ...    NaN  NaN NaN  NaN  379.0
# 148       454          75       QB  DET  ...    NaN  NaN NaN  NaN  388.0
# 157       802          54       QB  DAL  ...    NaN  NaN NaN  NaN  311.0
# 165       473          73       QB  BUF  ...    NaN  NaN NaN  NaN  269.0
# 174       473          70       QB  TEN  ...    NaN  NaN NaN  NaN  276.0
# 177       574          72       QB  CIN  ...    NaN  NaN NaN  NaN  364.0
# 185       478          71       QB  ATL  ...    NaN  NaN NaN  NaN  373.0
# 206       467          60       QB  MIA  ...    NaN  NaN NaN  NaN  261.0
# 230       723          47       QB  BAL  ...    NaN  NaN NaN  NaN  436.0
# 231       505          45       QB  KCC  ...    NaN  NaN NaN  NaN  328.0
# 256       813          12       QB  DEN  ...    NaN  NaN NaN  NaN  289.0
# 283       606          26       QB  MIN  ...    NaN  NaN NaN  NaN  395.0
# 322      1098          10       QB  SFO  ...    NaN  NaN NaN  NaN  196.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 27   14.0   36.0   90.0               25.5               16.0
# 29    7.0   35.0   67.0                1.0                1.0
# 40   13.0   41.0   64.0                6.0                4.0
# 42   11.0   41.0   72.0               14.0               10.0
# 51   15.0   27.0   23.0                4.0                3.0
# 57   13.0   17.0   16.0               27.0               17.0
# 66    2.0   15.0   28.0               20.0               14.0
# 83   14.0   40.0   14.0               29.0               18.0
# 85   16.0   34.0   58.0               13.0                9.0
# 92   16.0   21.0   21.0               35.0               21.0
# 99   21.0   36.0   14.0               19.0               13.0
# 122  18.0   35.0   53.0               22.0               15.0
# 125  12.0   23.0   34.0                7.0                5.0
# 144  14.0   33.0   46.0               40.0               23.0
# 148  10.0   37.0   37.0               10.0                7.0
# 157   4.0   25.0   57.0                8.0                6.0
# 165   6.0   42.0   95.0               12.0                8.0
# 174   9.0   23.0   60.0               17.0               11.0
# 177   8.0   41.0   46.0               18.0               12.0
# 185   7.0   37.0   35.0                3.0                2.0
# 206  12.0   29.0   39.0               52.0               26.0
# 230  15.0   33.0   21.0               30.0               19.0
# 231   8.0   28.0   48.0               34.0               20.0
# 256  10.0   31.0   28.0               50.0               25.0
# 283   5.0   37.0   20.0               36.0               22.0
# 322   4.0   36.0   69.0               46.0               24.0
#
# [26 rows x 45 columns]

# %%
rb1 = rb[(rb['FantasyPointsRank'] <= 100)]
wr1 = wr[(wr['FantasyPointsRank'] <= 100)]
te1 = te[(te['FantasyPointsRank'] <= 100)]
qb1 = qb[(qb['FantasyPointsRank'] <= 100)]
rb1
# Out:
#      Rank_x Player_x  Unnamed: 2        Player_Name  Round  Min Pick  \
# 1         2  Elliott     Ezekiel    Ezekiel Elliott      1         1
# 3         4   Gurley        Todd        Todd Gurley      1         1
# 7         8     Bell     Le'Veon       Le'Veon Bell      1         1
# 10       11  Johnson       David      David Johnson      1         1
# 12       12   Miller       Lamar       Lamar Miller      2         1
# 16       16  Freeman     Devonta    Devonta Freeman      2         1
# 24       24   Ingram        Mark        Mark Ingram      3         1
# 26       26    McCoy      LeSean       LeSean McCoy      3         1
# 36       36     Hyde      Carlos        Carlos Hyde      4         1
# 38       38    Forte        Matt         Matt Forte      4         1
# 43       43   Murray    Latavius    Latavius Murray      4         1
# 48       48   Murray     DeMarco     DeMarco Murray      5         1
# 52       53     Hill      Jeremy        Jeremy Hill      5         1
# 60       65   Gordon      Melvin      Melvin Gordon      6         1
# 81       97     Gore       Frank         Frank Gore      7         1
# 97      119    Ajayi         Jay          Jay Ajayi      9         2
# 143     181  Crowell      Isaiah     Isaiah Crowell     12         2
# 147     185   Blount  LeGarrette  LeGarrette Blount     13         1
# 155     194  Coleman       Tevin      Tevin Coleman     13         4
# 162     202   Howard      Jordan      Jordan Howard     14         1
# 184     235   Powell       Bilal       Bilal Powell     16         1
# 189     243     Ware     Spencer       Spencer Ware     16         1
# 216     279     West    Terrance      Terrance West     19         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 1         743          98       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 3         830          70       RB  RAM  ...    NaN  NaN NaN  NaN NaN  NaN
# 7         457          74       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 10        425          71       RB  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 12        447          75       RB  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 16        458          74       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 24        455          74       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 26        419          74       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN
# 36        424          75       RB  SFO  ...    NaN  NaN NaN  NaN NaN  NaN
# 38        747          75       RB  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
# 43        465          77       RB  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 48        431          75       RB  TEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 52        443          75       RB  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 60        461          75       RB  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
# 81        475          77       RB  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 97        450          74       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 143       560          71       RB  CLE  ...    NaN  NaN NaN  NaN NaN  NaN
# 147       597          77       RB  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 155       474          70       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 162       760          62       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
# 184       570          65       RB  NYJ  ...    NaN  NaN NaN  NaN NaN  NaN
# 189       606          64       RB  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 216       923          36       RB  BAL  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 1      NaN    NaN                5.0                2.0
# 3      NaN    NaN               65.0               17.0
# 7      NaN    NaN                9.0                3.0
# 10     NaN    NaN                2.0                1.0
# 12     NaN    NaN               66.5               18.5
# 16     NaN    NaN               21.0                6.0
# 24     NaN    NaN               37.0                9.0
# 26     NaN    NaN               11.0                4.0
# 36     NaN    NaN               62.0               15.0
# 38     NaN    NaN               71.0               20.0
# 43     NaN    NaN               49.0               13.0
# 48     NaN    NaN               16.0                5.0
# 52     NaN    NaN               78.0               22.0
# 60     NaN    NaN               31.0                7.0
# 81     NaN    NaN               47.0               12.0
# 97     NaN    NaN               45.0               11.0
# 143    NaN    NaN               55.0               14.0
# 147    NaN    NaN               32.0                8.0
# 155    NaN    NaN               66.5               18.5
# 162    NaN    NaN               39.0               10.0
# 184    NaN    NaN               74.0               21.0
# 189    NaN    NaN               64.0               16.0
# 216    NaN    NaN               90.5               23.0
#
# [23 rows x 45 columns]

# %%
wr1
# Out:
#      Rank_x    Player_x Unnamed: 2       Player_Name  Round  Min Pick  \
# 0         1       Brown    Antonio     Antonio Brown      1         1
# 2         3       Jones      Julio       Julio Jones      1         1
# 4         5     Beckham      Odell     Odell Beckham      1         1
# 5         6       Green       A.J.        A.J. Green      1         1
# 6         7     Hopkins    DeAndre   DeAndre Hopkins      1         1
# 9        10      Bryant        Dez        Dez Bryant      1         1
# 13       13    Robinson      Allen    Allen Robinson      2         1
# 15       15       Evans       Mike        Mike Evans      2         1
# 17       17      Cooper      Amari      Amari Cooper      2         1
# 20       20      Nelson      Jordy      Jordy Nelson      2         1
# 23       23       Cooks    Brandin     Brandin Cooks      2         1
# 25       25      Hilton       T.Y.       T.Y. Hilton      3         1
# 30       30      Thomas  Demaryius  Demaryius Thomas      3         1
# 31       31      Landry     Jarvis     Jarvis Landry      3         1
# 35       35     Edelman     Julian    Julian Edelman      3         1
# 37       37    Benjamin     Kelvin   Kelvin Benjamin      4         1
# 41       41        Tate     Golden       Golden Tate      4         1
# 47       47     Baldwin       Doug      Doug Baldwin      4         1
# 53       56  Fitzgerald      Larry  Larry Fitzgerald      5         2
# 62       68     Sanders   Emmanuel  Emmanuel Sanders      6         1
# 64       70     Shepard   Sterling  Sterling Shepard      6         1
# 77       90     Jackson     DeSean    DeSean Jackson      7         1
# 78       92    Crabtree    Michael  Michael Crabtree      7         2
# 90      111      Thomas    Michael    Michael Thomas      8         1
# 96      118       Diggs     Stefon      Stefon Diggs      9         2
# 98      120       Snead     Willie      Willie Snead      9         6
# 105     131        Hill     Tyreek       Tyreek Hill      9         3
# 190     244       Smith      Steve       Steve Smith     16         1
# 200     256    Matthews    Rishard  Rishard Matthews     17         3
# 214     277     Wallace       Mike      Mike Wallace     18         3
# 225     289       Pryor   Terrelle    Terrelle Pryor     19         1
# 234     300      Garcon     Pierre     Pierre Garcon     20         7
# 255     325       Adams    Davante     Davante Adams     22         1
# 271     341    Williams     Tyrell   Tyrell Williams     23         3
# 276     345     Beasley       Cole      Cole Beasley     24         3
# 305     374     Crowder    Jamison   Jamison Crowder     26         9
# 314     383      LaFell    Brandon    Brandon LaFell     27         7
# 318     387       Britt      Kenny       Kenny Britt     27         5
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 0         436          73       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 2         367          73       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 4         363          73       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN
# 5         368          72       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 6         397          73       WR  HOU  ...    NaN  NaN NaN  NaN NaN  NaN
# 9         433          74       WR  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 13        481          72       WR  JAC  ...    NaN  NaN NaN  NaN NaN  NaN
# 15        697          73       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN
# 17        464          75       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 20        345          75       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN
# 23        534          74       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 25        356          75       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 30        357          74       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 31        460          77       WR  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 35        381          78       WR  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 37        394          75       WR  CAR  ...    NaN  NaN NaN  NaN NaN  NaN
# 41        393          79       WR  DET  ...    NaN  NaN NaN  NaN NaN  NaN
# 47        400          79       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN
# 53        724          77       WR  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 62        353          76       WR  DEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 64        747          96       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN
# 77        423          77       WR  WAS  ...    NaN  NaN NaN  NaN NaN  NaN
# 78        497          78       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 90        748          84       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 96        631          74       WR  MIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 98        428          73       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 105       900           5       WR  KCC  ...    NaN  NaN NaN  NaN NaN  NaN
# 190       516          63       WR   FA  ...    NaN  NaN NaN  NaN NaN  NaN
# 200       488          57       WR  TEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 214       594          52       WR  BAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 225       780          32       WR  CLE  ...    NaN  NaN NaN  NaN NaN  NaN
# 234       783          50       WR  WAS  ...    NaN  NaN NaN  NaN NaN  NaN
# 255       479          40       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN
# 271       901          11       WR  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
# 276       699          13       WR  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 305       597          22       WR  WAS  ...    NaN  NaN NaN  NaN NaN  NaN
# 314       597          25       WR  CIN  ...    NaN  NaN NaN  NaN NaN  NaN
# 318       580          19       WR  RAM  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_wr
# 0      NaN    NaN               25.5                3.0
# 2      NaN    NaN               38.0                6.0
# 4      NaN    NaN               28.0                4.0
# 5      NaN    NaN               92.0               33.0
# 6      NaN    NaN               84.0               28.0
# 9      NaN    NaN               89.0               31.0
# 13     NaN    NaN               80.0               25.0
# 15     NaN    NaN               24.0                2.0
# 17     NaN    NaN               53.0               13.0
# 20     NaN    NaN               23.0                1.0
# 23     NaN    NaN               43.0                9.0
# 25     NaN    NaN               33.0                5.0
# 30     NaN    NaN               57.5               16.5
# 31     NaN    NaN               54.0               14.0
# 35     NaN    NaN               57.5               16.5
# 37     NaN    NaN               79.0               24.0
# 41     NaN    NaN               63.0               19.0
# 47     NaN    NaN               44.0               10.0
# 53     NaN    NaN               51.0               12.0
# 62     NaN    NaN               70.0               21.0
# 64     NaN    NaN               94.0               35.0
# 77     NaN    NaN               93.0               34.0
# 78     NaN    NaN               48.0               11.0
# 90     NaN    NaN               41.0                7.0
# 96     NaN    NaN               96.0               37.0
# 98     NaN    NaN               88.0               30.0
# 105    NaN    NaN               72.0               22.0
# 190    NaN    NaN              100.0               38.0
# 200    NaN    NaN               60.5               18.0
# 214    NaN    NaN               77.0               23.0
# 225    NaN    NaN               69.0               20.0
# 234    NaN    NaN               82.0               27.0
# 255    NaN    NaN               42.0                8.0
# 271    NaN    NaN               56.0               15.0
# 276    NaN    NaN               95.0               36.0
# 305    NaN    NaN               85.0               29.0
# 314    NaN    NaN               90.5               32.0
# 318    NaN    NaN               81.0               26.0
#
# [38 rows x 45 columns]

# %%
te1
# Out:
#      Rank_x Player_x Unnamed: 2     Player_Name  Round  Min Pick  Max Pick  \
# 45       45    Olsen       Greg      Greg Olsen      4         1       318
# 54       58    Kelce     Travis    Travis Kelce      5         2       348
# 68       75   Walker    Delanie  Delanie Walker      6         2       397
# 141     178   Graham      Jimmy    Jimmy Graham     12         2       389
# 251     321  Rudolph       Kyle    Kyle Rudolph     21         3       451
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 45           75       TE  CAR  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 54           78       TE  KCC  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 68           76       TE  TEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 141          76       TE  SEA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 251          47       TE  MIN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_te
# 45     NaN               76.0                3.0
# 54     NaN               59.0                1.0
# 68     NaN               87.0                5.0
# 141    NaN               86.0                4.0
# 251    NaN               75.0                2.0
#
# [5 rows x 45 columns]

# %%
qb1
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 27       27          Newton        Cam          Cam Newton      3         1
# 29       29         Rodgers      Aaron       Aaron Rodgers      3         1
# 40       40            Luck     Andrew         Andrew Luck      4         1
# 42       42          Wilson    Russell      Russell Wilson      4         1
# 51       52           Brees       Drew          Drew Brees      5         1
# 57       61  Roethlisberger        Ben  Ben Roethlisberger      5         1
# 66       73           Brady        Tom           Tom Brady      6         1
# 83      101          Palmer     Carson       Carson Palmer      7         1
# 85      105         Bortles      Blake       Blake Bortles      8         1
# 92      113         Manning        Eli         Eli Manning      8         1
# 99      121          Rivers     Philip       Philip Rivers      9         1
# 122     155         Winston     Jameis      Jameis Winston     11         1
# 125     160         Cousins       Kirk        Kirk Cousins     11         1
# 144     182           Wentz     Carson        Carson Wentz     13         1
# 148     186        Stafford    Matthew    Matthew Stafford     13         1
# 157     196        Prescott        Dak        Dak Prescott     14         1
# 165     205          Taylor      Tyrod        Tyrod Taylor     14         1
# 174     215         Mariota     Marcus      Marcus Mariota     15         2
# 177     224          Dalton       Andy         Andy Dalton     15         1
# 185     236            Ryan       Matt           Matt Ryan     16         1
# 206     266       Tannehill       Ryan      Ryan Tannehill     18         2
# 226     290        Osweiler      Brock      Brock Osweiler     19         1
# 230     295          Flacco        Joe          Joe Flacco     20         1
# 231     296           Smith       Alex          Alex Smith     20         1
# 256     326         Siemian     Trevor      Trevor Siemian     22         3
# 283     352        Bradford        Sam        Sam Bradford     24         2
# 322     391      Kaepernick      Colin    Colin Kaepernick     27         4
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 27        476          70       QB  CAR  ...    NaN  NaN NaN  NaN  270.0
# 29        481          72       QB  GBP  ...    NaN  NaN NaN  NaN  401.0
# 40        486          71       QB  IND  ...    NaN  NaN NaN  NaN  346.0
# 42        475          74       QB  SEA  ...    NaN  NaN NaN  NaN  353.0
# 51        479          73       QB  NOS  ...    NaN  NaN NaN  NaN  471.0
# 57        476          76       QB  PIT  ...    NaN  NaN NaN  NaN  328.0
# 66        496          75       QB  NEP  ...    NaN  NaN NaN  NaN  291.0
# 83        483          75       QB  ARI  ...    NaN  NaN NaN  NaN  364.0
# 85        495          74       QB  JAC  ...    NaN  NaN NaN  NaN  368.0
# 92        468          77       QB  NYG  ...    NaN  NaN NaN  NaN  377.0
# 99        474          75       QB  SDC  ...    NaN  NaN NaN  NaN  349.0
# 122       465          73       QB  TBB  ...    NaN  NaN NaN  NaN  345.0
# 125       544          75       QB  WAS  ...    NaN  NaN NaN  NaN  406.0
# 144       829          39       QB  PHI  ...    NaN  NaN NaN  NaN  379.0
# 148       454          75       QB  DET  ...    NaN  NaN NaN  NaN  388.0
# 157       802          54       QB  DAL  ...    NaN  NaN NaN  NaN  311.0
# 165       473          73       QB  BUF  ...    NaN  NaN NaN  NaN  269.0
# 174       473          70       QB  TEN  ...    NaN  NaN NaN  NaN  276.0
# 177       574          72       QB  CIN  ...    NaN  NaN NaN  NaN  364.0
# 185       478          71       QB  ATL  ...    NaN  NaN NaN  NaN  373.0
# 206       467          60       QB  MIA  ...    NaN  NaN NaN  NaN  261.0
# 226       551          54       QB  HOU  ...    NaN  NaN NaN  NaN  301.0
# 230       723          47       QB  BAL  ...    NaN  NaN NaN  NaN  436.0
# 231       505          45       QB  KCC  ...    NaN  NaN NaN  NaN  328.0
# 256       813          12       QB  DEN  ...    NaN  NaN NaN  NaN  289.0
# 283       606          26       QB  MIN  ...    NaN  NaN NaN  NaN  395.0
# 322      1098          10       QB  SFO  ...    NaN  NaN NaN  NaN  196.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 27   14.0   36.0   90.0               25.5               16.0
# 29    7.0   35.0   67.0                1.0                1.0
# 40   13.0   41.0   64.0                6.0                4.0
# 42   11.0   41.0   72.0               14.0               10.0
# 51   15.0   27.0   23.0                4.0                3.0
# 57   13.0   17.0   16.0               27.0               17.0
# 66    2.0   15.0   28.0               20.0               14.0
# 83   14.0   40.0   14.0               29.0               18.0
# 85   16.0   34.0   58.0               13.0                9.0
# 92   16.0   21.0   21.0               35.0               21.0
# 99   21.0   36.0   14.0               19.0               13.0
# 122  18.0   35.0   53.0               22.0               15.0
# 125  12.0   23.0   34.0                7.0                5.0
# 144  14.0   33.0   46.0               40.0               23.0
# 148  10.0   37.0   37.0               10.0                7.0
# 157   4.0   25.0   57.0                8.0                6.0
# 165   6.0   42.0   95.0               12.0                8.0
# 174   9.0   23.0   60.0               17.0               11.0
# 177   8.0   41.0   46.0               18.0               12.0
# 185   7.0   37.0   35.0                3.0                2.0
# 206  12.0   29.0   39.0               52.0               26.0
# 226  16.0   27.0   30.0               73.0               27.0
# 230  15.0   33.0   21.0               30.0               19.0
# 231   8.0   28.0   48.0               34.0               20.0
# 256  10.0   31.0   28.0               50.0               25.0
# 283   5.0   37.0   20.0               36.0               22.0
# 322   4.0   36.0   69.0               46.0               24.0
#
# [27 rows x 45 columns]

# %%
rb2 = rb[(rb['FantasyPointsRank'] <= 50)]
wr2 = wr[(wr['FantasyPointsRank'] <= 50)]
te2 = te[(te['FantasyPointsRank'] <= 50)]
qb2 = qb[(qb['FantasyPointsRank'] <= 50)]
rb2
# Out:
#      Rank_x Player_x  Unnamed: 2        Player_Name  Round  Min Pick  \
# 1         2  Elliott     Ezekiel    Ezekiel Elliott      1         1
# 7         8     Bell     Le'Veon       Le'Veon Bell      1         1
# 10       11  Johnson       David      David Johnson      1         1
# 16       16  Freeman     Devonta    Devonta Freeman      2         1
# 24       24   Ingram        Mark        Mark Ingram      3         1
# 26       26    McCoy      LeSean       LeSean McCoy      3         1
# 43       43   Murray    Latavius    Latavius Murray      4         1
# 48       48   Murray     DeMarco     DeMarco Murray      5         1
# 60       65   Gordon      Melvin      Melvin Gordon      6         1
# 81       97     Gore       Frank         Frank Gore      7         1
# 97      119    Ajayi         Jay          Jay Ajayi      9         2
# 147     185   Blount  LeGarrette  LeGarrette Blount     13         1
# 162     202   Howard      Jordan      Jordan Howard     14         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 1         743          98       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN
# 7         457          74       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN
# 10        425          71       RB  ARI  ...    NaN  NaN NaN  NaN NaN  NaN
# 16        458          74       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN
# 24        455          74       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 26        419          74       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN
# 43        465          77       RB  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 48        431          75       RB  TEN  ...    NaN  NaN NaN  NaN NaN  NaN
# 60        461          75       RB  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
# 81        475          77       RB  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 97        450          74       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 147       597          77       RB  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 162       760          62       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 1      NaN    NaN                5.0                2.0
# 7      NaN    NaN                9.0                3.0
# 10     NaN    NaN                2.0                1.0
# 16     NaN    NaN               21.0                6.0
# 24     NaN    NaN               37.0                9.0
# 26     NaN    NaN               11.0                4.0
# 43     NaN    NaN               49.0               13.0
# 48     NaN    NaN               16.0                5.0
# 60     NaN    NaN               31.0                7.0
# 81     NaN    NaN               47.0               12.0
# 97     NaN    NaN               45.0               11.0
# 147    NaN    NaN               32.0                8.0
# 162    NaN    NaN               39.0               10.0
#
# [13 rows x 45 columns]

# %%
wr2
# Out:
#      Rank_x  Player_x Unnamed: 2       Player_Name  Round  Min Pick  Max Pick  \
# 0         1     Brown    Antonio     Antonio Brown      1         1       436
# 2         3     Jones      Julio       Julio Jones      1         1       367
# 4         5   Beckham      Odell     Odell Beckham      1         1       363
# 15       15     Evans       Mike        Mike Evans      2         1       697
# 20       20    Nelson      Jordy      Jordy Nelson      2         1       345
# 23       23     Cooks    Brandin     Brandin Cooks      2         1       534
# 25       25    Hilton       T.Y.       T.Y. Hilton      3         1       356
# 47       47   Baldwin       Doug      Doug Baldwin      4         1       400
# 78       92  Crabtree    Michael  Michael Crabtree      7         2       497
# 90      111    Thomas    Michael    Michael Thomas      8         1       748
# 255     325     Adams    Davante     Davante Adams     22         1       479
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 0            73       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 2            73       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 4            73       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 15           73       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 20           75       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 23           74       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 25           75       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 47           79       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 78           78       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 90           84       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 255          40       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_wr
# 0      NaN               25.5                3.0
# 2      NaN               38.0                6.0
# 4      NaN               28.0                4.0
# 15     NaN               24.0                2.0
# 20     NaN               23.0                1.0
# 23     NaN               43.0                9.0
# 25     NaN               33.0                5.0
# 47     NaN               44.0               10.0
# 78     NaN               48.0               11.0
# 90     NaN               41.0                7.0
# 255    NaN               42.0                8.0
#
# [11 rows x 45 columns]

# %%
te2
# Out:
# Empty DataFrame
# Columns: [Rank_x, Player_x, Unnamed: 2, Player_Name, Round, Min Pick, Max Pick, % Selected, Position, Team, PositionRank, Rank_y, Player_y, ATT, YDS, Y/A, LG, 20+, TD, REC, TGT, YDS.1, Y/R, TD.1, FL, G, FPTS, FPTS/G, OWN, FG, FGA, PCT, 1-19, 20-29, 30-39, 40-49, 50+, XPT, XPA, CMP, INT, SACKS, ATT.1, FantasyPointsRank, performance_fp_te]
# Index: []
#
# [0 rows x 45 columns]

# %%
qb2
# Out:
#      Rank_x        Player_x Unnamed: 2         Player_Name  Round  Min Pick  \
# 27       27          Newton        Cam          Cam Newton      3         1
# 29       29         Rodgers      Aaron       Aaron Rodgers      3         1
# 40       40            Luck     Andrew         Andrew Luck      4         1
# 42       42          Wilson    Russell      Russell Wilson      4         1
# 51       52           Brees       Drew          Drew Brees      5         1
# 57       61  Roethlisberger        Ben  Ben Roethlisberger      5         1
# 66       73           Brady        Tom           Tom Brady      6         1
# 83      101          Palmer     Carson       Carson Palmer      7         1
# 85      105         Bortles      Blake       Blake Bortles      8         1
# 92      113         Manning        Eli         Eli Manning      8         1
# 99      121          Rivers     Philip       Philip Rivers      9         1
# 122     155         Winston     Jameis      Jameis Winston     11         1
# 125     160         Cousins       Kirk        Kirk Cousins     11         1
# 144     182           Wentz     Carson        Carson Wentz     13         1
# 148     186        Stafford    Matthew    Matthew Stafford     13         1
# 157     196        Prescott        Dak        Dak Prescott     14         1
# 165     205          Taylor      Tyrod        Tyrod Taylor     14         1
# 174     215         Mariota     Marcus      Marcus Mariota     15         2
# 177     224          Dalton       Andy         Andy Dalton     15         1
# 185     236            Ryan       Matt           Matt Ryan     16         1
# 230     295          Flacco        Joe          Joe Flacco     20         1
# 231     296           Smith       Alex          Alex Smith     20         1
# 256     326         Siemian     Trevor      Trevor Siemian     22         3
# 283     352        Bradford        Sam        Sam Bradford     24         2
# 322     391      Kaepernick      Colin    Colin Kaepernick     27         4
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP  \
# 27        476          70       QB  CAR  ...    NaN  NaN NaN  NaN  270.0
# 29        481          72       QB  GBP  ...    NaN  NaN NaN  NaN  401.0
# 40        486          71       QB  IND  ...    NaN  NaN NaN  NaN  346.0
# 42        475          74       QB  SEA  ...    NaN  NaN NaN  NaN  353.0
# 51        479          73       QB  NOS  ...    NaN  NaN NaN  NaN  471.0
# 57        476          76       QB  PIT  ...    NaN  NaN NaN  NaN  328.0
# 66        496          75       QB  NEP  ...    NaN  NaN NaN  NaN  291.0
# 83        483          75       QB  ARI  ...    NaN  NaN NaN  NaN  364.0
# 85        495          74       QB  JAC  ...    NaN  NaN NaN  NaN  368.0
# 92        468          77       QB  NYG  ...    NaN  NaN NaN  NaN  377.0
# 99        474          75       QB  SDC  ...    NaN  NaN NaN  NaN  349.0
# 122       465          73       QB  TBB  ...    NaN  NaN NaN  NaN  345.0
# 125       544          75       QB  WAS  ...    NaN  NaN NaN  NaN  406.0
# 144       829          39       QB  PHI  ...    NaN  NaN NaN  NaN  379.0
# 148       454          75       QB  DET  ...    NaN  NaN NaN  NaN  388.0
# 157       802          54       QB  DAL  ...    NaN  NaN NaN  NaN  311.0
# 165       473          73       QB  BUF  ...    NaN  NaN NaN  NaN  269.0
# 174       473          70       QB  TEN  ...    NaN  NaN NaN  NaN  276.0
# 177       574          72       QB  CIN  ...    NaN  NaN NaN  NaN  364.0
# 185       478          71       QB  ATL  ...    NaN  NaN NaN  NaN  373.0
# 230       723          47       QB  BAL  ...    NaN  NaN NaN  NaN  436.0
# 231       505          45       QB  KCC  ...    NaN  NaN NaN  NaN  328.0
# 256       813          12       QB  DEN  ...    NaN  NaN NaN  NaN  289.0
# 283       606          26       QB  MIN  ...    NaN  NaN NaN  NaN  395.0
# 322      1098          10       QB  SFO  ...    NaN  NaN NaN  NaN  196.0
#
#       INT  SACKS  ATT.1  FantasyPointsRank  performance_fp_qb
# 27   14.0   36.0   90.0               25.5               16.0
# 29    7.0   35.0   67.0                1.0                1.0
# 40   13.0   41.0   64.0                6.0                4.0
# 42   11.0   41.0   72.0               14.0               10.0
# 51   15.0   27.0   23.0                4.0                3.0
# 57   13.0   17.0   16.0               27.0               17.0
# 66    2.0   15.0   28.0               20.0               14.0
# 83   14.0   40.0   14.0               29.0               18.0
# 85   16.0   34.0   58.0               13.0                9.0
# 92   16.0   21.0   21.0               35.0               21.0
# 99   21.0   36.0   14.0               19.0               13.0
# 122  18.0   35.0   53.0               22.0               15.0
# 125  12.0   23.0   34.0                7.0                5.0
# 144  14.0   33.0   46.0               40.0               23.0
# 148  10.0   37.0   37.0               10.0                7.0
# 157   4.0   25.0   57.0                8.0                6.0
# 165   6.0   42.0   95.0               12.0                8.0
# 174   9.0   23.0   60.0               17.0               11.0
# 177   8.0   41.0   46.0               18.0               12.0
# 185   7.0   37.0   35.0                3.0                2.0
# 230  15.0   33.0   21.0               30.0               19.0
# 231   8.0   28.0   48.0               34.0               20.0
# 256  10.0   31.0   28.0               50.0               25.0
# 283   5.0   37.0   20.0               36.0               22.0
# 322   4.0   36.0   69.0               46.0               24.0
#
# [25 rows x 45 columns]

# %%
rb3 = rb[(rb['FantasyPointsRank'] <= 25)]
wr3 = wr[(wr['FantasyPointsRank'] <= 25)]
te3 = te[(te['FantasyPointsRank'] <= 25)]
qb3 = qb[(qb['FantasyPointsRank'] <= 25)]
rb3
# Out:
#     Rank_x Player_x Unnamed: 2      Player_Name  Round  Min Pick  Max Pick  \
# 1        2  Elliott    Ezekiel  Ezekiel Elliott      1         1       743
# 7        8     Bell    Le'Veon     Le'Veon Bell      1         1       457
# 10      11  Johnson      David    David Johnson      1         1       425
# 16      16  Freeman    Devonta  Devonta Freeman      2         1       458
# 26      26    McCoy     LeSean     LeSean McCoy      3         1       419
# 48      48   Murray    DeMarco   DeMarco Murray      5         1       431
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 1           98       RB  DAL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 7           74       RB  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 10          71       RB  ARI  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 16          74       RB  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 26          74       RB  BUF  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 48          75       RB  TEN  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_rb
# 1                 5.0                2.0
# 7                 9.0                3.0
# 10                2.0                1.0
# 16               21.0                6.0
# 26               11.0                4.0
# 48               16.0                5.0
#
# [6 rows x 45 columns]

# %%
wr3
# Out:
#     Rank_x Player_x Unnamed: 2   Player_Name  Round  Min Pick  Max Pick  \
# 15      15    Evans       Mike    Mike Evans      2         1       697
# 20      20   Nelson      Jordy  Jordy Nelson      2         1       345
#
#     % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  ATT.1  \
# 15          73       WR  TBB  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
# 20          75       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN    NaN
#
#     FantasyPointsRank  performance_fp_wr
# 15               24.0                2.0
# 20               23.0                1.0
#
# [2 rows x 45 columns]

# %%
wr3['FantasyPointsRank'].sum()
# Out:
# 47.0

# %%
te3
# Out:
# Empty DataFrame
# Columns: [Rank_x, Player_x, Unnamed: 2, Player_Name, Round, Min Pick, Max Pick, % Selected, Position, Team, PositionRank, Rank_y, Player_y, ATT, YDS, Y/A, LG, 20+, TD, REC, TGT, YDS.1, Y/R, TD.1, FL, G, FPTS, FPTS/G, OWN, FG, FGA, PCT, 1-19, 20-29, 30-39, 40-49, 50+, XPT, XPA, CMP, INT, SACKS, ATT.1, FantasyPointsRank, performance_fp_te]
# Index: []
#
# [0 rows x 45 columns]

# %%
qb3
# Out:
#      Rank_x  Player_x Unnamed: 2       Player_Name  Round  Min Pick  Max Pick  \
# 29       29   Rodgers      Aaron     Aaron Rodgers      3         1       481
# 40       40      Luck     Andrew       Andrew Luck      4         1       486
# 42       42    Wilson    Russell    Russell Wilson      4         1       475
# 51       52     Brees       Drew        Drew Brees      5         1       479
# 66       73     Brady        Tom         Tom Brady      6         1       496
# 85      105   Bortles      Blake     Blake Bortles      8         1       495
# 99      121    Rivers     Philip     Philip Rivers      9         1       474
# 122     155   Winston     Jameis    Jameis Winston     11         1       465
# 125     160   Cousins       Kirk      Kirk Cousins     11         1       544
# 148     186  Stafford    Matthew  Matthew Stafford     13         1       454
# 157     196  Prescott        Dak      Dak Prescott     14         1       802
# 165     205    Taylor      Tyrod      Tyrod Taylor     14         1       473
# 174     215   Mariota     Marcus    Marcus Mariota     15         2       473
# 177     224    Dalton       Andy       Andy Dalton     15         1       574
# 185     236      Ryan       Matt         Matt Ryan     16         1       478
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA    CMP   INT  SACKS  \
# 29           72       QB  GBP  ...    NaN  NaN NaN  NaN  401.0   7.0   35.0
# 40           71       QB  IND  ...    NaN  NaN NaN  NaN  346.0  13.0   41.0
# 42           74       QB  SEA  ...    NaN  NaN NaN  NaN  353.0  11.0   41.0
# 51           73       QB  NOS  ...    NaN  NaN NaN  NaN  471.0  15.0   27.0
# 66           75       QB  NEP  ...    NaN  NaN NaN  NaN  291.0   2.0   15.0
# 85           74       QB  JAC  ...    NaN  NaN NaN  NaN  368.0  16.0   34.0
# 99           75       QB  SDC  ...    NaN  NaN NaN  NaN  349.0  21.0   36.0
# 122          73       QB  TBB  ...    NaN  NaN NaN  NaN  345.0  18.0   35.0
# 125          75       QB  WAS  ...    NaN  NaN NaN  NaN  406.0  12.0   23.0
# 148          75       QB  DET  ...    NaN  NaN NaN  NaN  388.0  10.0   37.0
# 157          54       QB  DAL  ...    NaN  NaN NaN  NaN  311.0   4.0   25.0
# 165          73       QB  BUF  ...    NaN  NaN NaN  NaN  269.0   6.0   42.0
# 174          70       QB  TEN  ...    NaN  NaN NaN  NaN  276.0   9.0   23.0
# 177          72       QB  CIN  ...    NaN  NaN NaN  NaN  364.0   8.0   41.0
# 185          71       QB  ATL  ...    NaN  NaN NaN  NaN  373.0   7.0   37.0
#
#      ATT.1  FantasyPointsRank  performance_fp_qb
# 29    67.0                1.0                1.0
# 40    64.0                6.0                4.0
# 42    72.0               14.0               10.0
# 51    23.0                4.0                3.0
# 66    28.0               20.0               14.0
# 85    58.0               13.0                9.0
# 99    14.0               19.0               13.0
# 122   53.0               22.0               15.0
# 125   34.0                7.0                5.0
# 148   37.0               10.0                7.0
# 157   57.0                8.0                6.0
# 165   95.0               12.0                8.0
# 174   60.0               17.0               11.0
# 177   46.0               18.0               12.0
# 185   35.0                3.0                2.0
#
# [15 rows x 45 columns]

# %%
rb_25_50 = rb2[(rb2['FantasyPointsRank'] >= 25)]
wr_25_50 = wr2[(wr2['FantasyPointsRank'] >= 25)]
te_25_50 = te2[(te2['FantasyPointsRank'] >= 25)]
qb_25_50 = qb2[(qb2['FantasyPointsRank'] >= 25)]
rb_25_50
# Out:
#      Rank_x Player_x  Unnamed: 2        Player_Name  Round  Min Pick  \
# 24       24   Ingram        Mark        Mark Ingram      3         1
# 43       43   Murray    Latavius    Latavius Murray      4         1
# 60       65   Gordon      Melvin      Melvin Gordon      6         1
# 81       97     Gore       Frank         Frank Gore      7         1
# 97      119    Ajayi         Jay          Jay Ajayi      9         2
# 147     185   Blount  LeGarrette  LeGarrette Blount     13         1
# 162     202   Howard      Jordan      Jordan Howard     14         1
#
#      Max Pick  % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  \
# 24        455          74       RB  NOS  ...    NaN  NaN NaN  NaN NaN  NaN
# 43        465          77       RB  OAK  ...    NaN  NaN NaN  NaN NaN  NaN
# 60        461          75       RB  SDC  ...    NaN  NaN NaN  NaN NaN  NaN
# 81        475          77       RB  IND  ...    NaN  NaN NaN  NaN NaN  NaN
# 97        450          74       RB  MIA  ...    NaN  NaN NaN  NaN NaN  NaN
# 147       597          77       RB  NEP  ...    NaN  NaN NaN  NaN NaN  NaN
# 162       760          62       RB  CHI  ...    NaN  NaN NaN  NaN NaN  NaN
#
#      SACKS  ATT.1  FantasyPointsRank  performance_fp_rb
# 24     NaN    NaN               37.0                9.0
# 43     NaN    NaN               49.0               13.0
# 60     NaN    NaN               31.0                7.0
# 81     NaN    NaN               47.0               12.0
# 97     NaN    NaN               45.0               11.0
# 147    NaN    NaN               32.0                8.0
# 162    NaN    NaN               39.0               10.0
#
# [7 rows x 45 columns]

# %%
rb_25_50['FantasyPointsRank'].sum()
# Out:
# 280.0

# %%
wr_25_50
# Out:
#      Rank_x  Player_x Unnamed: 2       Player_Name  Round  Min Pick  Max Pick  \
# 0         1     Brown    Antonio     Antonio Brown      1         1       436
# 2         3     Jones      Julio       Julio Jones      1         1       367
# 4         5   Beckham      Odell     Odell Beckham      1         1       363
# 23       23     Cooks    Brandin     Brandin Cooks      2         1       534
# 25       25    Hilton       T.Y.       T.Y. Hilton      3         1       356
# 47       47   Baldwin       Doug      Doug Baldwin      4         1       400
# 78       92  Crabtree    Michael  Michael Crabtree      7         2       497
# 90      111    Thomas    Michael    Michael Thomas      8         1       748
# 255     325     Adams    Davante     Davante Adams     22         1       479
#
#      % Selected Position Team  ...  40-49  50+ XPT  XPA CMP  INT  SACKS  \
# 0            73       WR  PIT  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 2            73       WR  ATL  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 4            73       WR  NYG  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 23           74       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 25           75       WR  IND  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 47           79       WR  SEA  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 78           78       WR  OAK  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 90           84       WR  NOS  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
# 255          40       WR  GBP  ...    NaN  NaN NaN  NaN NaN  NaN    NaN
#
#      ATT.1  FantasyPointsRank  performance_fp_wr
# 0      NaN               25.5                3.0
# 2      NaN               38.0                6.0
# 4      NaN               28.0                4.0
# 23     NaN               43.0                9.0
# 25     NaN               33.0                5.0
# 47     NaN               44.0               10.0
# 78     NaN               48.0               11.0
# 90     NaN               41.0                7.0
# 255    NaN               42.0                8.0
#
# [9 rows x 45 columns]

# %%
wr_25_50['FantasyPointsRank'].sum()
# Out:
# 342.5
