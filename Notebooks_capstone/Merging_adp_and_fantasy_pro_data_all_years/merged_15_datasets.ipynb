# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from matplotlib import rcParams

# %matplotlib inline

# %%
adp = pd.read_csv('Data/Ranked_adp_for_merge/adp_ranked_2015 - adp_ranked_2015.csv')

# %%
fp = pd.read_csv('Data/clean_fp_data_merge/fp_data_cleaned_15 - fp_data_uncleaned_15 - fp_data_uncleaned_15.csv')

# %%
adp.shape
# Out:
# (358, 10)

# %%
fp['Player'] = fp['Player'].str.strip()

fp.head()
# Out:
#    Rank          Player    ATT    YDS  Y/A    LG   20+    TD    REC    TGT  \
# 0     1      Cam Newton  495.0  3,837  7.8   NaN   NaN  35.0    NaN    NaN
# 1     2       Tom Brady  624.0  4,770  7.6   NaN   NaN  36.0    NaN    NaN
# 2     3  Russell Wilson  483.0  4,024  8.3   NaN   NaN  34.0    NaN    NaN
# 3     4   Blake Bortles  606.0  4,428  7.3   NaN   NaN  35.0    NaN    NaN
# 4     1   Antonio Brown    3.0  1,834  NaN  59.0  25.0  10.0  136.0  193.0
#
#    ...  30-39  40-49  50+  XPT  XPA    CMP   INT SACKS  ATT.1  \
# 0  ...    NaN    NaN  NaN  NaN  NaN  296.0  10.0  33.0  132.0
# 1  ...    NaN    NaN  NaN  NaN  NaN  402.0   7.0  38.0   34.0
# 2  ...    NaN    NaN  NaN  NaN  NaN  329.0   8.0  45.0  103.0
# 3  ...    NaN    NaN  NaN  NaN  NaN  355.0  18.0  51.0   52.0
# 4  ...    NaN    NaN  NaN  NaN  NaN    NaN   NaN   NaN    NaN
#
#    FantasyPointsRank
# 0                1.0
# 1                2.0
# 2                3.0
# 3                4.0
# 4                5.0
#
# ...

# %%
rwd = pd.merge(adp, fp, 
                 left_on = 'Player_Name', right_on = 'Player',
                 how = 'left')
rwd.shape
# Out:
# (362, 43)

# %%
rwd.tail(50)
#defense's are no longer in the data so we have an extra 32 missing data links
# Out:
#      Rank_x    Player_x    Unnamed: 2           Player_Name  Min Pick  \
# 312     405  Taliaferro       Lorenzo    Lorenzo Taliaferro        13
# 313     406      Browns     Cleveland      Cleveland Browns         8
# 314     407       Brown         Corey           Corey Brown        10
# 315     408     Suisham         Shaun         Shaun Suisham         3
# 316     409        Rice           Ray              Ray Rice         4
# 317     411     Bullock         Randy         Randy Bullock         2
# 318     412    Williams        Damien       Damien Williams         3
# 319     413        Cook         Jared            Jared Cook         8
# 320     414       Aiken         Kamar           Kamar Aiken         1
# 321     415       Smith          Geno            Geno Smith        11
# 322     416       Pryor      Terrelle        Terrelle Pryor         3
# 323     417      Kearse      Jermaine       Jermaine Kearse         2
# ...

# %%
rounds_4 = rwd.head(48)
rounds_4['Position'].value_counts()
# Out:
# RB    22
# WR    21
# QB     3
# TE     2
# Name: Position, dtype: int64

# %%
df = rwd.iloc[0:24]
df['Position'].value_counts()
# Out:
# RB    11
# WR    10
# QB     2
# TE     1
# Name: Position, dtype: int64

# %%
first = rwd.iloc[0:12]
first['Position'].value_counts()
# Out:
# RB    6
# WR    4
# QB    1
# TE    1
# Name: Position, dtype: int64

# %%
second = rwd.iloc[12:24]
second['Position'].value_counts()
# Out:
# WR    6
# RB    5
# QB    1
# Name: Position, dtype: int64

# %%
third = rwd.iloc[24:36]
third['Position'].value_counts()
# Out:
# WR    6
# RB    5
# TE    1
# Name: Position, dtype: int64

# %%
fourth = rwd.iloc[36:48]
fourth['Position'].value_counts()
# Out:
# RB    6
# WR    5
# QB    1
# Name: Position, dtype: int64

# %%
rwd.to_csv('merged_data_15.csv', index = False)
